# %%
import numpy as np
import pandas as pd
import seaborn as sb
import io
import requests
import datetime
import ondemand
from scipy.stats import pearsonr
from pandas.io.common import EmptyDataError
from requests.exceptions import HTTPError
import time
import os
import json
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from multiprocessing import Pool as ThreadPool
from multiprocessing import Manager
class Generate_Leaders():
    def __init__(self): 
        self.pageview_change = dict()
        self.my_date = None
    def get_mkt_cap(self, symbol, start_date, end_date):
        file = pd.read_csv('Highest_change_total.csv')
        try:
            mktcap = float(file.loc[file['Symbol'] == symbol]['Market_Cap(billion)'])
        except:
            return
        return mktcap
    def parallel(self, item):
        try:
            pageview_price = pd.read_csv('pageview_price/pageview_price_{}.csv'.format(item.lower()))
        except FileNotFoundError:
            print('{} has no pageview data!!!'.format(item))
            return
        if pageview_price.empty:
            return
        #print(datetime.datetime.now())
        temp_res = pageview_price.set_index(['Date'])
        try:
            temp_res = temp_res.loc[[self.my_date]]
            temp_res.reset_index(col_fill = 'Date', inplace = True)
        except:
            print('{} has no trading on {}!!!'.format(item, self.my_date))
            return
        if temp_res.loc[0, 'PageView'] < 10:
            print('{} pageview on {} less than 10, skip it.'.format(item, self.my_date))
            return
        temp_res.loc[0, 'Market_Cap(billion)'] = self.get_mkt_cap(item, self.my_date, self.my_date)
        if temp_res['Market_Cap(billion)'].isnull().values.any():
            pass
        else:
            temp_res['Market_Cap(billion)'] = temp_res['Market_Cap(billion)'].round(2)
        self.pageview_change[item] = temp_res 
    def highest_change(self, my_date):
        midcap = pd.read_csv('mid_cap_symbols.csv')
        symbols = list(midcap['Symbol'])
        self.my_date = my_date
        for i, item in enumerate(symbols):
            if i % 300 == 0:
                print('run well')
                print(i)
            self.parallel(item)

# %%
midcap = pd.read_csv('mid_cap_symbols.csv')
all_symbols = list(midcap['Symbol'])

# %%
#from 2018-01-01 to 2018-12-31
#start = '2018-01-01'
daterange = pd.date_range(start = '2018-01-01', end = '2018-12-31')
daterange = daterange.strftime('%Y-%m-%d')

# %%
#Generate highest change for each day
for i, date in enumerate(daterange):
    print(i)
    print(date)
    leader = Generate_Leaders()
    highest_change = leader.highest_change(date)
    to_combine = pd.DataFrame([])
    for item in all_symbols:
        try:
            temp = leader.pageview_change[item]
        except:
            continue
        to_combine = pd.concat([to_combine, temp], sort = False, ignore_index = True)
    if not os.path.exists(os.path.dirname('leaderlist {}/'.format(date))):
        os.makedirs(os.path.dirname('leaderlist {}/'.format(date)))
    if to_combine.empty:
        print('{} is not trading day!!!'.format(date))
        continue
    highest_change_window1 = to_combine.drop(['PageView_Change_in_Std_3'], axis = 1)
    highest_change_window1['Time_Window'] = 1
    highest_change_window1.sort_values(by = ['PageView_Change_in_Std_1'], ascending = False, inplace = True)
    highest_change_window3 = to_combine.drop(['PageView_Change_in_Std_1'], axis = 1)
    highest_change_window3['Time_Window'] = 3
    highest_change_window3.sort_values(by = ['PageView_Change_in_Std_3'], ascending = False, inplace = True)
    highest_change_window1.to_csv('leaderlist {}/mid_highest_change_window1.csv'.format(date), index = False)
    highest_change_window3.to_csv('leaderlist {}/mid_highest_change_window3.csv'.format(date), index = False)
# AAN has no trading on 2018-01-01!!!
# MCHI has no trading on 2018-01-01!!!
# NS has no trading on 2018-01-01!!!
# TEN has no trading on 2018-01-01!!!
# CRI has no trading on 2018-01-01!!!
# EEFT has no trading on 2018-01-01!!!
# ZNH has no trading on 2018-01-01!!!
# MAT has no trading on 2018-01-01!!!
# GEL has no trading on 2018-01-01!!!
# EBIX has no trading on 2018-01-01!!!
# CG has no trading on 2018-01-01!!!
# CLH has no trading on 2018-01-01!!!
# ESNT has no trading on 2018-01-01!!!
# ESRT has no trading on 2018-01-01!!!
# WPX has no trading on 2018-01-01!!!
# BG has no trading on 2018-01-01!!!
# LEG has no trading on 2018-01-01!!!
# AYX has no trading on 2018-01-01!!!
# SCI has no trading on 2018-01-01!!!
# ALNY has no trading on 2018-01-01!!!
# PAYC has no trading on 2018-01-01!!!
# GBCI has no trading on 2018-01-01!!!
# BLKB has no trading on 2018-01-01!!!
# AR has no trading on 2018-01-01!!!
# FOXF has no trading on 2018-01-01!!!
# SRCL has no trading on 2018-01-01!!!
# HUN has no trading on 2018-01-01!!!
# GNTX has no trading on 2018-01-01!!!
# EBS has no trading on 2018-01-01!!!
# GVA has no trading on 2018-01-01!!!
# UTHR has no trading on 2018-01-01!!!
# GHC has no trading on 2018-01-01!!!
# KMT has no trading on 2018-01-01!!!
# MUR has no trading on 2018-01-01!!!
# TREE has no trading on 2018-01-01!!!
# NVR has no trading on 2018-01-01!!!
# WPM has no trading on 2018-01-01!!!
# ADT has no trading on 2018-01-01!!!
# APHA has no pageview data!!!
# APY has no trading on 2018-01-01!!!
# AVNS has no pageview data!!!
# BH.A has no pageview data!!!
# BHC has no pageview data!!!
# CDAY has no pageview data!!!
# CLNC has no pageview data!!!
# COLD has no pageview data!!!
# CWEN has no pageview data!!!
# EAF has no pageview data!!!
# GTES has no pageview data!!!
# HUD has no pageview data!!!
# HUYA has no pageview data!!!
# JW.B has no trading on 2018-01-01!!!
# LBRT has no pageview data!!!
# MGY has no pageview data!!!
# NVT has no pageview data!!!
# PAGS has no pageview data!!!
# PRSP has no pageview data!!!
# PVTL has no pageview data!!!
# RAMP has no pageview data!!!
# ROAN has no pageview data!!!
# SITC has no pageview data!!!
# SMAR has no pageview data!!!
# WH has no trading on 2018-01-01!!!
# WHD has no pageview data!!!
# WYND has no pageview data!!!
# ZUO has no pageview data!!!
# BILI has no pageview data!!!
# DOCU has no pageview data!!!
# GLIBA has no pageview data!!!
# GSKY has no pageview data!!!
# HWC has no pageview data!!!
# IGIB has no pageview data!!!
# MOR has no pageview data!!!
# OZK has no pageview data!!!
# PS has no pageview data!!!
# USIG has no pageview data!!!
# ZS has no trading on 2018-01-01!!!
# 2018-01-01 is not trading day!!!
# 1
# 2018-01-02
# run well
# 0
# NUS pageview on 2018-01-02 less than 10, skip it.
# CVCO pageview on 2018-01-02 less than 10, skip it.
# OMAB pageview on 2018-01-02 less than 10, skip it.
# JEF pageview on 2018-01-02 less than 10, skip it.
# LIVN pageview on 2018-01-02 less than 10, skip it.
# JJSF pageview on 2018-01-02 less than 10, skip it.
# IRDM pageview on 2018-01-02 less than 10, skip it.
# BAH pageview on 2018-01-02 less than 10, skip it.
# STAY pageview on 2018-01-02 less than 10, skip it.
# UHAL pageview on 2018-01-02 less than 10, skip it.
# ASND pageview on 2018-01-02 less than 10, skip it.
# GIII pageview on 2018-01-02 less than 10, skip it.
# MMYT pageview on 2018-01-02 less than 10, skip it.
# VICI pageview on 2018-01-02 less than 10, skip it.
# TPX pageview on 2018-01-02 less than 10, skip it.
# ASH pageview on 2018-01-02 less than 10, skip it.
# CUZ pageview on 2018-01-02 less than 10, skip it.
# ENBL pageview on 2018-01-02 less than 10, skip it.
# SAM pageview on 2018-01-02 less than 10, skip it.
# XHR pageview on 2018-01-02 less than 10, skip it.
# BCO pageview on 2018-01-02 less than 10, skip it.
# CBPO pageview on 2018-01-02 less than 10, skip it.
# FHB pageview on 2018-01-02 less than 10, skip it.
# TFSL pageview on 2018-01-02 less than 10, skip it.
# SRC pageview on 2018-01-02 less than 10, skip it.
# LAUR pageview on 2018-01-02 less than 10, skip it.
# DSGX pageview on 2018-01-02 less than 10, skip it.
# OKTA pageview on 2018-01-02 less than 10, skip it.
# GHDX pageview on 2018-01-02 less than 10, skip it.
# ICUI pageview on 2018-01-02 less than 10, skip it.
# DM pageview on 2018-01-02 less than 10, skip it.
# CVI pageview on 2018-01-02 less than 10, skip it.
# SMTC pageview on 2018-01-02 less than 10, skip it.
# CMD pageview on 2018-01-02 less than 10, skip it.
# POST pageview on 2018-01-02 less than 10, skip it.
# SLAB pageview on 2018-01-02 less than 10, skip it.
# HNP pageview on 2018-01-02 less than 10, skip it.
# PHI pageview on 2018-01-02 less than 10, skip it.
# GWR pageview on 2018-01-02 less than 10, skip it.
# OGS pageview on 2018-01-02 less than 10, skip it.
# AXTA pageview on 2018-01-02 less than 10, skip it.
# APPF pageview on 2018-01-02 less than 10, skip it.
# PAC pageview on 2018-01-02 less than 10, skip it.
# ELS pageview on 2018-01-02 less than 10, skip it.
# BRKS pageview on 2018-01-02 less than 10, skip it.
# ALE pageview on 2018-01-02 less than 10, skip it.
# SUI pageview on 2018-01-02 less than 10, skip it.
# RGA pageview on 2018-01-02 less than 10, skip it.
# STAG pageview on 2018-01-02 less than 10, skip it.
# ROLL pageview on 2018-01-02 less than 10, skip it.
# GLPI pageview on 2018-01-02 less than 10, skip it.
# PODD pageview on 2018-01-02 less than 10, skip it.
# PEB pageview on 2018-01-02 less than 10, skip it.
# AMRX has no pageview data!!!
# COTY pageview on 2018-01-02 less than 10, skip it.
# INDB pageview on 2018-01-02 less than 10, skip it.
# KOS pageview on 2018-01-02 less than 10, skip it.
# CADE pageview on 2018-01-02 less than 10, skip it.
# MAN pageview on 2018-01-02 less than 10, skip it.
# VRNT pageview on 2018-01-02 less than 10, skip it.
# BSMX pageview on 2018-01-02 less than 10, skip it.
# HDS pageview on 2018-01-02 less than 10, skip it.
# TECD pageview on 2018-01-02 less than 10, skip it.
# RBA pageview on 2018-01-02 less than 10, skip it.
# HXL pageview on 2018-01-02 less than 10, skip it.
# AGIO pageview on 2018-01-02 less than 10, skip it.
# TTEK pageview on 2018-01-02 less than 10, skip it.
# FELE pageview on 2018-01-02 less than 10, skip it.
# DCI pageview on 2018-01-02 less than 10, skip it.
# TERP pageview on 2018-01-02 less than 10, skip it.
# SCS pageview on 2018-01-02 less than 10, skip it.
# DNLI pageview on 2018-01-02 less than 10, skip it.
# GSH pageview on 2018-01-02 less than 10, skip it.
# RARE pageview on 2018-01-02 less than 10, skip it.
# JBT pageview on 2018-01-02 less than 10, skip it.
# ESLT pageview on 2018-01-02 less than 10, skip it.
# LPL pageview on 2018-01-02 less than 10, skip it.
# OUT pageview on 2018-01-02 less than 10, skip it.
# BSM pageview on 2018-01-02 less than 10, skip it.
# MIME pageview on 2018-01-02 less than 10, skip it.
# MMSI pageview on 2018-01-02 less than 10, skip it.
# THG pageview on 2018-01-02 less than 10, skip it.
# QRTEA has no pageview data!!!
# EXPO pageview on 2018-01-02 less than 10, skip it.
# JBGS pageview on 2018-01-02 less than 10, skip it.
# ASR pageview on 2018-01-02 less than 10, skip it.
# BFR pageview on 2018-01-02 less than 10, skip it.
# PB pageview on 2018-01-02 less than 10, skip it.
# ACH pageview on 2018-01-02 less than 10, skip it.
# MED pageview on 2018-01-02 less than 10, skip it.
# MC pageview on 2018-01-02 less than 10, skip it.
# USM pageview on 2018-01-02 less than 10, skip it.
# FIBK pageview on 2018-01-02 less than 10, skip it.
# LCII pageview on 2018-01-02 less than 10, skip it.
# STAA pageview on 2018-01-02 less than 10, skip it.
# WBC pageview on 2018-01-02 less than 10, skip it.
# FR pageview on 2018-01-02 less than 10, skip it.
# CACI pageview on 2018-01-02 less than 10, skip it.
# KW pageview on 2018-01-02 less than 10, skip it.
# AIZ pageview on 2018-01-02 less than 10, skip it.
# FII pageview on 2018-01-02 less than 10, skip it.
# TYL pageview on 2018-01-02 less than 10, skip it.
# EPAY pageview on 2018-01-02 less than 10, skip it.
# FSV pageview on 2018-01-02 less than 10, skip it.
# COLM pageview on 2018-01-02 less than 10, skip it.
# STL pageview on 2018-01-02 less than 10, skip it.
# FICO pageview on 2018-01-02 less than 10, skip it.
# TOWN pageview on 2018-01-02 less than 10, skip it.
# BCPC pageview on 2018-01-02 less than 10, skip it.
# IJT pageview on 2018-01-02 less than 10, skip it.
# VET pageview on 2018-01-02 less than 10, skip it.
# HQY pageview on 2018-01-02 less than 10, skip it.
# CHGG pageview on 2018-01-02 less than 10, skip it.
# QDEL pageview on 2018-01-02 less than 10, skip it.
# ITCB pageview on 2018-01-02 less than 10, skip it.
# HAIN pageview on 2018-01-02 less than 10, skip it.
# NGHC pageview on 2018-01-02 less than 10, skip it.
# ALTR pageview on 2018-01-02 less than 10, skip it.
# TKC pageview on 2018-01-02 less than 10, skip it.
# ELY pageview on 2018-01-02 less than 10, skip it.
# CRS pageview on 2018-01-02 less than 10, skip it.
# JW.A pageview on 2018-01-02 less than 10, skip it.
# MOH pageview on 2018-01-02 less than 10, skip it.
# CIT pageview on 2018-01-02 less than 10, skip it.
# CISN pageview on 2018-01-02 less than 10, skip it.
# BSTI pageview on 2018-01-02 less than 10, skip it.
# IBOC pageview on 2018-01-02 less than 10, skip it.
# STE pageview on 2018-01-02 less than 10, skip it.
# MSA pageview on 2018-01-02 less than 10, skip it.
# LOXO pageview on 2018-01-02 less than 10, skip it.
# OGE pageview on 2018-01-02 less than 10, skip it.
# SSD pageview on 2018-01-02 less than 10, skip it.
# VRNS pageview on 2018-01-02 less than 10, skip it.
# STN pageview on 2018-01-02 less than 10, skip it.
# HTA pageview on 2018-01-02 less than 10, skip it.
# ...
# AVAL pageview on 2018-01-04 less than 10, skip it.
# MRCY pageview on 2018-01-04 less than 10, skip it.
# RGEN pageview on 2018-01-04 less than 10, skip it.
# WAFD pageview on 2018-01-04 less than 10, skip it.
# AVYA pageview on 2018-01-04 less than 10, skip it.
# AVX pageview on 2018-01-04 less than 10, skip it.
# QTWO pageview on 2018-01-04 less than 10, skip it.
# CMPR pageview on 2018-01-04 less than 10, skip it.
# CCMP pageview on 2018-01-04 less than 10, skip it.
# CATY pageview on 2018-01-04 less than 10, skip it.
# BOKF pageview on 2018-01-04 less than 10, skip it.
# NAV pageview on 2018-01-04 less than 10, skip it.
# CNO pageview on 2018-01-04 less than 10, skip it.
# BID pageview on 2018-01-04 less than 10, skip it.
# TVPT pageview on 2018-01-04 less than 10, skip it.
# LPLA pageview on 2018-01-04 less than 10, skip it.
# XLRN pageview on 2018-01-04 less than 10, skip it.
# CHFC pageview on 2018-01-04 less than 10, skip it.
# IUSG pageview on 2018-01-04 less than 10, skip it.
# PE pageview on 2018-01-04 less than 10, skip it.
# GIL pageview on 2018-01-04 less than 10, skip it.
# HCSG pageview on 2018-01-04 less than 10, skip it.
# THS pageview on 2018-01-04 less than 10, skip it.
# SHLX pageview on 2018-01-04 less than 10, skip it.
# UE pageview on 2018-01-04 less than 10, skip it.
# NNN pageview on 2018-01-04 less than 10, skip it.
# AIN pageview on 2018-01-04 less than 10, skip it.
# SERV pageview on 2018-01-04 less than 10, skip it.
# run well
# 900
# POL pageview on 2018-01-04 less than 10, skip it.
# LTM pageview on 2018-01-04 less than 10, skip it.
# UBSH pageview on 2018-01-04 less than 10, skip it.
# AMH pageview on 2018-01-04 less than 10, skip it.
# ACWX pageview on 2018-01-04 less than 10, skip it.
# TCO pageview on 2018-01-04 less than 10, skip it.
# EYE pageview on 2018-01-04 less than 10, skip it.
# SJI pageview on 2018-01-04 less than 10, skip it.
# NUVA pageview on 2018-01-04 less than 10, skip it.
# AUO pageview on 2018-01-04 less than 10, skip it.
# SBNY pageview on 2018-01-04 less than 10, skip it.
# EQC pageview on 2018-01-04 less than 10, skip it.
# MNRO pageview on 2018-01-04 less than 10, skip it.
# CHH pageview on 2018-01-04 less than 10, skip it.
# CXP pageview on 2018-01-04 less than 10, skip it.
# POOL pageview on 2018-01-04 less than 10, skip it.
# PACW pageview on 2018-01-04 less than 10, skip it.
# RDN pageview on 2018-01-04 less than 10, skip it.
# AMN pageview on 2018-01-04 less than 10, skip it.
# BLD pageview on 2018-01-04 less than 10, skip it.
# XEC pageview on 2018-01-04 less than 10, skip it.
# EXLS pageview on 2018-01-04 less than 10, skip it.
# WGP pageview on 2018-01-04 less than 10, skip it.
# LANC pageview on 2018-01-04 less than 10, skip it.
# SIGI pageview on 2018-01-04 less than 10, skip it.
# AAXJ pageview on 2018-01-04 less than 10, skip it.
# PPBI pageview on 2018-01-04 less than 10, skip it.
# SFNC pageview on 2018-01-04 less than 10, skip it.
# TLND pageview on 2018-01-04 less than 10, skip it.
# MSM pageview on 2018-01-04 less than 10, skip it.
# CNDT pageview on 2018-01-04 less than 10, skip it.
# WSBC pageview on 2018-01-04 less than 10, skip it.
# AKO.B pageview on 2018-01-04 less than 10, skip it.
# HGV pageview on 2018-01-04 less than 10, skip it.
# BRKR pageview on 2018-01-04 less than 10, skip it.
# ITT pageview on 2018-01-04 less than 10, skip it.
# DGRW pageview on 2018-01-04 less than 10, skip it.
# PFPT pageview on 2018-01-04 less than 10, skip it.
# SMI pageview on 2018-01-04 less than 10, skip it.
# RLGY pageview on 2018-01-04 less than 10, skip it.
# ESL pageview on 2018-01-04 less than 10, skip it.
# SPR pageview on 2018-01-04 less than 10, skip it.
# DLB pageview on 2018-01-04 less than 10, skip it.
# ABCB pageview on 2018-01-04 less than 10, skip it.
# CARG pageview on 2018-01-04 less than 10, skip it.
# AIT pageview on 2018-01-04 less than 10, skip it.
# RNG pageview on 2018-01-04 less than 10, skip it.
# ROIC pageview on 2018-01-04 less than 10, skip it.
# SHO pageview on 2018-01-04 less than 10, skip it.
# HOMB pageview on 2018-01-04 less than 10, skip it.
# PINC pageview on 2018-01-04 less than 10, skip it.
# CBU pageview on 2018-01-04 less than 10, skip it.
# MEOH pageview on 2018-01-04 less than 10, skip it.
# ERIE pageview on 2018-01-04 less than 10, skip it.
# WAL pageview on 2018-01-04 less than 10, skip it.
# PEGA pageview on 2018-01-04 less than 10, skip it.
# IEI pageview on 2018-01-04 less than 10, skip it.
# OFC pageview on 2018-01-04 less than 10, skip it.
# PRI pageview on 2018-01-04 less than 10, skip it.
# MGEE pageview on 2018-01-04 less than 10, skip it.
# CBD pageview on 2018-01-04 less than 10, skip it.
# INXN pageview on 2018-01-04 less than 10, skip it.
# TCBI pageview on 2018-01-04 less than 10, skip it.
# AXS pageview on 2018-01-04 less than 10, skip it.
# WERN pageview on 2018-01-04 less than 10, skip it.
# LILA pageview on 2018-01-04 less than 10, skip it.
# UCBI pageview on 2018-01-04 less than 10, skip it.
# TSU pageview on 2018-01-04 less than 10, skip it.
# EXP pageview on 2018-01-04 less than 10, skip it.
# AER pageview on 2018-01-04 less than 10, skip it.
# ADSW pageview on 2018-01-04 less than 10, skip it.
# MTDR pageview on 2018-01-04 less than 10, skip it.
# FWONK pageview on 2018-01-04 less than 10, skip it.
# FLOW pageview on 2018-01-04 less than 10, skip it.
# NATI pageview on 2018-01-04 less than 10, skip it.
# CIB pageview on 2018-01-04 less than 10, skip it.
# MYOK pageview on 2018-01-04 less than 10, skip it.
# TECH pageview on 2018-01-04 less than 10, skip it.
# MANT pageview on 2018-01-04 less than 10, skip it.
# AZUL pageview on 2018-01-04 less than 10, skip it.
# SFM pageview on 2018-01-04 less than 10, skip it.
# LII pageview on 2018-01-04 less than 10, skip it.
# HPP pageview on 2018-01-04 less than 10, skip it.
# WOR pageview on 2018-01-04 less than 10, skip it.
# EME pageview on 2018-01-04 less than 10, skip it.
# KAR pageview on 2018-01-04 less than 10, skip it.
# QLYS pageview on 2018-01-04 less than 10, skip it.
# OMCL pageview on 2018-01-04 less than 10, skip it.
# AAN pageview on 2018-01-04 less than 10, skip it.
# MCHI pageview on 2018-01-04 less than 10, skip it.
# CLH pageview on 2018-01-04 less than 10, skip it.
# ESRT pageview on 2018-01-04 less than 10, skip it.
# LEG pageview on 2018-01-04 less than 10, skip it.
# AYX pageview on 2018-01-04 less than 10, skip it.
# GBCI pageview on 2018-01-04 less than 10, skip it.
# BLKB pageview on 2018-01-04 less than 10, skip it.
# FOXF pageview on 2018-01-04 less than 10, skip it.
# GVA pageview on 2018-01-04 less than 10, skip it.
# GHC pageview on 2018-01-04 less than 10, skip it.
# ADT has no trading on 2018-01-04!!!
# APHA has no pageview data!!!
# APY has no trading on 2018-01-04!!!
# AVNS has no pageview data!!!
# BH.A has no pageview data!!!
# BHC has no pageview data!!!
# CDAY has no pageview data!!!
# CLNC has no pageview data!!!
# COLD has no pageview data!!!
# CWEN has no pageview data!!!
# EAF has no pageview data!!!
# GTES has no pageview data!!!
# HUD has no pageview data!!!
# HUYA has no pageview data!!!
# JW.B has no trading on 2018-01-04!!!
# LBRT has no pageview data!!!
# MGY has no pageview data!!!
# NVT has no pageview data!!!
# PAGS has no pageview data!!!
# PRSP has no pageview data!!!
# PVTL has no pageview data!!!
# RAMP has no pageview data!!!
# ROAN has no pageview data!!!
# SITC has no pageview data!!!
# SMAR has no pageview data!!!
# WH has no trading on 2018-01-04!!!
# WHD has no pageview data!!!
# WYND has no pageview data!!!
# ZUO has no pageview data!!!
# BILI has no pageview data!!!
# DOCU has no pageview data!!!
# GLIBA has no pageview data!!!
# GSKY has no pageview data!!!
# HWC has no pageview data!!!
# IGIB has no pageview data!!!
# MOR has no pageview data!!!
# OZK has no pageview data!!!
# PS has no pageview data!!!
# USIG has no pageview data!!!
# ZS has no trading on 2018-01-04!!!
# 4
# 2018-01-05
# run well
# 0
# NUS pageview on 2018-01-05 less than 10, skip it.
# CVCO pageview on 2018-01-05 less than 10, skip it.
# OMAB pageview on 2018-01-05 less than 10, skip it.
# JEF pageview on 2018-01-05 less than 10, skip it.
# LIVN pageview on 2018-01-05 less than 10, skip it.
# JJSF pageview on 2018-01-05 less than 10, skip it.
# IRDM pageview on 2018-01-05 less than 10, skip it.
# BAH pageview on 2018-01-05 less than 10, skip it.
# STAY pageview on 2018-01-05 less than 10, skip it.
# UHAL pageview on 2018-01-05 less than 10, skip it.
# ASND pageview on 2018-01-05 less than 10, skip it.
# CVA pageview on 2018-01-05 less than 10, skip it.
# MMYT pageview on 2018-01-05 less than 10, skip it.
# VICI pageview on 2018-01-05 less than 10, skip it.
# TPX pageview on 2018-01-05 less than 10, skip it.
# ASH pageview on 2018-01-05 less than 10, skip it.
# CUZ pageview on 2018-01-05 less than 10, skip it.
# ENBL pageview on 2018-01-05 less than 10, skip it.
# YPF pageview on 2018-01-05 less than 10, skip it.
# DSW pageview on 2018-01-05 less than 10, skip it.
# SAM pageview on 2018-01-05 less than 10, skip it.
# BCO pageview on 2018-01-05 less than 10, skip it.
# BXMT pageview on 2018-01-05 less than 10, skip it.
# FHB pageview on 2018-01-05 less than 10, skip it.
# TFSL pageview on 2018-01-05 less than 10, skip it.
# LAUR pageview on 2018-01-05 less than 10, skip it.
# DSGX pageview on 2018-01-05 less than 10, skip it.
# OKTA pageview on 2018-01-05 less than 10, skip it.
# GHDX pageview on 2018-01-05 less than 10, skip it.
# ICUI pageview on 2018-01-05 less than 10, skip it.
# DM pageview on 2018-01-05 less than 10, skip it.
# SMTC pageview on 2018-01-05 less than 10, skip it.
# FIVN pageview on 2018-01-05 less than 10, skip it.
# CMD pageview on 2018-01-05 less than 10, skip it.
# SLAB pageview on 2018-01-05 less than 10, skip it.
# SEAS pageview on 2018-01-05 less than 10, skip it.
# UFS pageview on 2018-01-05 less than 10, skip it.
# HNP pageview on 2018-01-05 less than 10, skip it.
# PHI pageview on 2018-01-05 less than 10, skip it.
# NXST pageview on 2018-01-05 less than 10, skip it.
# GWR pageview on 2018-01-05 less than 10, skip it.
# PBF pageview on 2018-01-05 less than 10, skip it.
# WWW pageview on 2018-01-05 less than 10, skip it.
# NEOG pageview on 2018-01-05 less than 10, skip it.
# OGS pageview on 2018-01-05 less than 10, skip it.
# AXTA pageview on 2018-01-05 less than 10, skip it.
# Y pageview on 2018-01-05 less than 10, skip it.
# PRLB pageview on 2018-01-05 less than 10, skip it.
# PAC pageview on 2018-01-05 less than 10, skip it.
# ELS pageview on 2018-01-05 less than 10, skip it.
# ALE pageview on 2018-01-05 less than 10, skip it.
# SUI pageview on 2018-01-05 less than 10, skip it.
# RGA pageview on 2018-01-05 less than 10, skip it.
# CBM pageview on 2018-01-05 less than 10, skip it.
# PNFP pageview on 2018-01-05 less than 10, skip it.
# ROLL pageview on 2018-01-05 less than 10, skip it.
# GLPI pageview on 2018-01-05 less than 10, skip it.
# PEB pageview on 2018-01-05 less than 10, skip it.
# AMRX has no pageview data!!!
# INDB pageview on 2018-01-05 less than 10, skip it.
# KOS pageview on 2018-01-05 less than 10, skip it.
# CADE pageview on 2018-01-05 less than 10, skip it.
# VRNT pageview on 2018-01-05 less than 10, skip it.
# BSMX pageview on 2018-01-05 less than 10, skip it.
# TECD pageview on 2018-01-05 less than 10, skip it.
# RBA pageview on 2018-01-05 less than 10, skip it.
# AGIO pageview on 2018-01-05 less than 10, skip it.
# TTEK pageview on 2018-01-05 less than 10, skip it.
# FELE pageview on 2018-01-05 less than 10, skip it.
# DCI pageview on 2018-01-05 less than 10, skip it.
# SAIL pageview on 2018-01-05 less than 10, skip it.
# GMED pageview on 2018-01-05 less than 10, skip it.
# TERP pageview on 2018-01-05 less than 10, skip it.
# MPWR pageview on 2018-01-05 less than 10, skip it.
# SCS pageview on 2018-01-05 less than 10, skip it.
# GSH pageview on 2018-01-05 less than 10, skip it.
# RARE pageview on 2018-01-05 less than 10, skip it.
# JBT pageview on 2018-01-05 less than 10, skip it.
# TNDM pageview on 2018-01-05 less than 10, skip it.
# ESLT pageview on 2018-01-05 less than 10, skip it.
# OUT pageview on 2018-01-05 less than 10, skip it.
# BSM pageview on 2018-01-05 less than 10, skip it.
# NSP pageview on 2018-01-05 less than 10, skip it.
# YEXT pageview on 2018-01-05 less than 10, skip it.
# MMSI pageview on 2018-01-05 less than 10, skip it.
# THG pageview on 2018-01-05 less than 10, skip it.
# QRTEA has no pageview data!!!
# EXPO pageview on 2018-01-05 less than 10, skip it.
# JBGS pageview on 2018-01-05 less than 10, skip it.
# ASR pageview on 2018-01-05 less than 10, skip it.
# BFR pageview on 2018-01-05 less than 10, skip it.
# DLX pageview on 2018-01-05 less than 10, skip it.
# PB pageview on 2018-01-05 less than 10, skip it.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-073c8a831b8c> in <module>
#       4     print(date)
#       5     leader = Generate_Leaders()
# ----> 6     highest_change = leader.highest_change(date)
#       7     to_combine = pd.DataFrame([])
#       8     for item in all_symbols:
#
# <ipython-input-2-478d4061a729> in highest_change(self, my_date)
#      45                 print('run well')
#      46                 print(i)
# ---> 47             self.parallel(item)
#
# <ipython-input-2-478d4061a729> in parallel(self, item)
#      31             print('{} pageview on {} less than 10, skip it.'.format(item, self.my_date))
#      32             return
# ---> 33         temp_res.loc[0, 'Market_Cap(billion)'] = self.get_mkt_cap(item, self.my_date, self.my_date)
#      34         if temp_res['Market_Cap(billion)'].isnull().values.any():
#      35             pass
#
# <ipython-input-2-478d4061a729> in get_mkt_cap(self, symbol, start_date, end_date)
#       6         self.my_date = None
#       7     def get_mkt_cap(self, symbol, start_date, end_date):
# ----> 8         file = pd.read_csv('Highest_change_total.csv')
#       9         try:
#      10             mktcap = float(file.loc[file['Symbol'] == symbol]['Market_Cap(billion)'])
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_integer_dtype(arr_or_dtype)
#     809
#     810
# --> 811 def is_integer_dtype(arr_or_dtype):
#     812     """
#     813     Check whether the provided array or dtype is of an integer dtype.
#
# KeyboardInterrupt:

# %%
#separate group for equities
for win in [1, 3]:
    for each in daterange1:
        try:
            highest_change = pd.read_csv('leaderlist {}/highest_change_window{}.csv'.format(each, win))
        except FileNotFoundError:
            continue
        small_cap_highest_change = highest_change.loc[highest_change['Market_Cap(billion)'] < 2]
        temp = highest_change.loc[highest_change['Market_Cap(billion)'] >= 2]
        mid_cap_highest_change = temp.loc[temp['Market_Cap(billion)'] < 10]
        large_cap_highest_change = temp.loc[temp['Market_Cap(billion)'] >= 10]
        if not os.path.exists(os.path.dirname('leaderlist {}/small_cap/window_{}_day/'.format(each, win))):
            os.makedirs(os.path.dirname('leaderlist {}/small_cap/window_{}_day/'.format(each, win)))
        if not os.path.exists(os.path.dirname('leaderlist {}/mid_cap/window_{}_day/'.format(each, win))):
            os.makedirs(os.path.dirname('leaderlist {}/mid_cap/window_{}_day/'.format(each, win)))
        if not os.path.exists(os.path.dirname('leaderlist {}/large_cap/window_{}_day/'.format(each, win))):
            os.makedirs(os.path.dirname('leaderlist {}/large_cap/window_{}_day/'.format(each, win)))
        mid_cap_highest_change.to_csv('leaderlist {}/mid_cap/window_{}_day/mid_cap_highest_change_time_window_{}.csv'.format(each, win, win), index = False)

# %%
url_price = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=OnDemand&symbol={}&type=daily&startDate={}&endDate={}&maxRecords=1000&interval=60&order=asc&sessionFilter=EFK&splits=true&dividends=true&volume=sum&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ&backAdjust=false&daysToExpiration=1&contractRoll=expiration'

# %%
test = pd.read_csv(url_price.format('DM', '2018-12-01', '2018-12-30'))

# %%
test
# Out:
#    symbol                  timestamp  tradingDay   open    high     low  \
# 0      DM  2018-12-03T00:00:00-05:00  2018-12-03  18.61  18.750  18.450
# 1      DM  2018-12-04T00:00:00-05:00  2018-12-04  18.74  19.020  18.660
# 2      DM  2018-12-06T00:00:00-05:00  2018-12-06  18.62  18.840  18.420
# 3      DM  2018-12-07T00:00:00-05:00  2018-12-07  18.74  19.210  18.740
# 4      DM  2018-12-10T00:00:00-05:00  2018-12-10  19.00  19.200  18.600
# 5      DM  2018-12-11T00:00:00-05:00  2018-12-11  19.21  19.320  19.130
# 6      DM  2018-12-12T00:00:00-05:00  2018-12-12  19.25  19.280  18.940
# 7      DM  2018-12-13T00:00:00-05:00  2018-12-13  18.94  19.230  18.940
# 8      DM  2018-12-14T00:00:00-05:00  2018-12-14  19.02  19.425  19.000
# 9      DM  2018-12-17T00:00:00-05:00  2018-12-17  19.19  19.420  18.540
# 10     DM  2018-12-18T00:00:00-05:00  2018-12-18  18.70  18.970  18.495
# 11     DM  2018-12-19T00:00:00-05:00  2018-12-19  18.65  18.850  18.480
# 12     DM  2018-12-20T00:00:00-05:00  2018-12-20  18.65  19.050  18.620
# 13     DM  2018-12-21T00:00:00-05:00  2018-12-21  18.85  19.330  18.770
# 14     DM  2018-12-24T00:00:00-05:00  2018-12-24  19.02  19.020  17.870
# 15     DM  2018-12-26T00:00:00-05:00  2018-12-26  17.91  18.220  17.720
# 16     DM  2018-12-27T00:00:00-05:00  2018-12-27  18.11  18.350  17.970
# 17     DM  2018-12-28T00:00:00-05:00  2018-12-28  18.44  18.650  18.370
#
#     close   volume  openInterest
# 0   18.74  1671400           NaN
# 1   18.75  1094600           NaN
# 2   18.81  1653300           NaN
# 3   19.05  1260300           NaN
# 4   19.17   493000           NaN
# 5   19.21  1379100           NaN
# 6   18.97   898700           NaN
# 7   19.14  3512700           NaN
# 8   19.36  1333800           NaN
# 9   18.65  2490700           NaN
# 10  18.55  1598600           NaN
# 11  18.71  1270800           NaN
# 12  18.85  1687400           NaN
# 13  19.06  1967200           NaN
# 14  17.98   434300           NaN
# 15  18.17  2153100           NaN
# 16  18.35  5838100           NaN
# 17  18.50  1442400           NaN

# %% [markdown]
# Also, for "average pageview" please update this to = the 100 day average, not the average for the window.  For window 3, multiple the 100 day daily average by 3, and provide that value as the average.
#
# Additional filters:
#
# 1.  Eliminate stocks with earnings release dates within +\- 5 days of the window end date.
# 2.  Expand the gap up/down filter to the past 10 days.
# 3.  Eliminate stocks with a 7% or greater percentage change (positive or negative) over the past 10 days from the window start date.
# 4.  Only include results for stocks with greater or equal to a 3 for actual pageviews in sd

# %%
#get business days
from pandas.tseries.offsets import *
daterange1 = pd.date_range('2017-12-01', '2019-01-20', freq=BDay())
daterange1 = list(daterange1.strftime('%Y-%m-%d'))
holidays = ['2017-12-25', '2018-01-01', '2018-01-15', '2018-02-19', '2018-03-30', '2018-05-28', '2018-07-04', '2018-09-03',\
            '2018-11-22', '2018-12-05', '2018-12-25', '2019-01-01']
for each in holidays:
    if each in daterange1:
        daterange1.remove(each)

# %%
daterange2 = daterange1[20:271]

# %%
#Pick the top 10 symbols with highest PageView_Change_in_std and PageView > 10
"""
Filters:
<1> Remove stocks with a gap up or down day within the window period
<2> Remove stocks that have a significantly greater high low range within the window period compared to normal.
"""
url_price = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=OnDemand&symbol={}&type=daily&startDate={}&endDate={}&maxRecords=1000&interval=60&order=asc&sessionFilter=EFK&splits=true&dividends=true&volume=sum&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ&backAdjust=false&daysToExpiration=1&contractRoll=expiration'
#get earning dates
def get_earning_date(symbol, start_date, end_date):
    url_earning = 'https://ondemand.websol.barchart.com/getCorporateActions.csv?apikey=ondemand&symbols={}&startDate={}&endDate={}&eventType=earnings&maxRecords=5'.\
                   format(symbol, start_date, end_date)
    try:
        return pd.read_csv(url_earning)
    except EmptyDataError as ede:
        #print(symbol + ' does not have earning_date during this period!!!')
        return pd.DataFrame([])
    except ConnectionResetError:
        print("getearning API problem")
        return get_earning_date(symbol, start_date, end_date)
def my_parallel(args):# filter for volatility.
    date = args[0]
    win_end = args[1]
    to_drop = args[2]
    window_days = args[3]
    gap_up_days = args[4]
    item = args[5]
    flag = True
    while flag:
        try:
            price = pd.read_csv(url_price.format(item, '2017-12-01', str(win_end)[:10]))
            flag = False
        except EmptyDataError:
            to_drop.append(item) # If the symbol has no trading for this window, drop it.
            print('EmptyData Error, {} has no trading on this window, drop it.'.format(item))
            flag = False
            return
        except ConnectionResetError:
            print('API Problem')
            continue
    price['high_loc_diff'] = price['high'] - price['low']
    price['H_L_20day_moving_avg'] = price['high_loc_diff'].rolling(20).mean()
    benchmark_index = price.loc[price['tradingDay'] == str(win_end)[:10]].index.item() - 1
    try:
        high_low_benchmark = price.iloc[benchmark_index, 10]
    except IndexError:
        print('Index Error')
        print(price)
    win_low = 0
    win_high = 0
    #filter for past 10 days percentage change > 7%
    win_start_index = daterange1.index(str(window_days[0])[:10])
    big_change_end = daterange1[win_start_index - 1]
    big_change_start = daterange1[win_start_index - 10]
    flag1 = True
    while flag1:  
        try:
            last_10_days_open = pd.read_csv(url_price.format(item, big_change_start, big_change_start))
            flag1 = False
        except EmptyDataError:
            to_drop.append(item)
            flag1 = False
            return
        except ConnectionResetError:
            print('API Problem')
            continue
    flag2 = True
    while flag2:
        try:
            last_10_days_close = pd.read_csv(url_price.format(item, big_change_end, big_change_end))
            flag2 = False
        except EmptyDataError:
            to_drop.append(item)
            flag2 = False
            return
        except ConnectionResetError:
            print('API Problem')
            continue
    if abs((last_10_days_close['close'][0] - last_10_days_open['open'][0])/last_10_days_open['open'][0]) > 0.07:
        print('prior 10 days open ' + str(last_10_days_open['open'][0]))
        print('close ' + str(last_10_days_close['close'][0]))
        print('change > 0.07, drop {}'.format(item))
        to_drop.append(item)
        return
    #filter for earning dates
    win_end_index = daterange1.index(str(window_days[-1])[:10])
    earning_start = daterange1[win_end_index - 5]
    earning_end = daterange1[win_end_index + 5]
    if get_earning_date(item, earning_start, earning_end).empty is False:
        print(item + ' has earning date, drop')
        to_drop.append(item)
        return
    for each in gap_up_days:#expand to the past 10 days.
        temp_price = price.loc[price['tradingDay'] == str(each)[:10]]
        try:
            last_day_index = temp_price.index.item() - 1
        except:
            print(temp_price)
        try:
            last_day_price = price.iloc[last_day_index]
        except IndexError:
            print('Index Error')
            print(price)
        try:
            if float(temp_price['open']) > float(last_day_price['high']) or\
            float(temp_price['open']) < float(last_day_price['low']):
                to_drop.append(item)
                return
        except TypeError:
            continue
    #processing window part
    for each in window_days:
        temp_price = price.loc[price['tradingDay'] == str(each)[:10]]
        try:
            last_day_index = temp_price.index.item() - 1
        except:
            print(temp_price)
        try:
            last_day_price = price.iloc[last_day_index]
        except IndexError:
            print('Index Error')
            print(price)
        try:
            if float(temp_price['open']) > float(last_day_price['high']) or\
            float(temp_price['open']) < float(last_day_price['low']):
                to_drop.append(item)
                return
        except TypeError:
            to_drop.append(item) # If the symbol has no trading for this window, drop it.
            print('TypeError, {} has no trading on this window, drop it.'.format(item))
            return
        if win_low == 0:
            win_low = float(temp_price['low'])
        else:
            win_low = min(float(temp_price['low']), win_low)
        if win_high == 0:
            win_high = float(temp_price['high'])
        else:
            win_high = max(float(temp_price['high']), win_high)
    win_high_low = float(win_high - win_low)
    if win_high_low > 2.5*high_low_benchmark:
        to_drop.append(item)
def my_filters(rawdata, date, win):
    symbols = list(rawdata['Symbol'])
    #temp_win_date = datetime.datetime.strptime(date, "%Y-%m-%d")
    count = 0
    window_days = []
    gap_up_days = []
    win_end_index = daterange1.index(date)
    while count < 10:
        if count < win:
            window_days.append(datetime.datetime.strptime(daterange1[win_end_index-count], "%Y-%m-%d"))
        else:
            gap_up_days.append(datetime.datetime.strptime(daterange1[win_end_index-count], "%Y-%m-%d"))
        count += 1
    window_days = window_days[::-1]
    gap_up_days = gap_up_days[::-1]
    win_start = window_days[0]
    win_end = window_days[-1]
    to_drop = Manager().list()
    args = []
    for item in symbols:
        args.append((date, win_end, to_drop, window_days, gap_up_days, item))
    pool = ThreadPool(10)
    pool.map(my_parallel, args) #important, no run except permission
    pool.close()
    pool.join() 

    to_drop = list(set(to_drop))
    for item in to_drop:
        rawdata = rawdata.loc[rawdata['Symbol'] != item]
    return rawdata
for win in [3]:# run win3
    for date in daterange2[47:]:
        print(datetime.datetime.now())
        print(date)
        for cap in ['mid']:
            try:
                to_filter = pd.read_csv\
                ('leaderlist {}/{}_cap/window_{}_day/{}_cap_highest_change_time_window_{}.csv'.format(date, cap, win, cap, win))
            except FileNotFoundError:
                continue
            to_filter = to_filter.loc[to_filter['PageView_Change_in_Std_{}'.format(win)] >= 3]
            to_filter = my_filters(to_filter, date, win)
            each = date
            each = each[5:]
            each = each.replace('-', '')
            to_filter = to_filter.head(10)
            to_filter.to_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win), index = False)
# Out:
# 2019-03-18 16:34:11.943148
# 2018-03-12
# prior 10 days open 154.5
# close 168.06
# change > 0.07, drop LGND
# OKTA has earning date, drop
# JBL has earning date, drop
# prior 10 days open 41.92708
# close 48.47509
# change > 0.07, drop KFY
# prior 10 days open 14.15
# close 16.15
# change > 0.07, drop EVH
# prior 10 days open 19.26
# close 30.21
# change > 0.07, drop GTHX
# prior 10 days open 27.3
# close 37.5
# prior 10 days open 47.57
# change > 0.07, drop RGNX
# close 53.95
# change > 0.07, drop Z
# TECD has earning date, drop
# 2019-03-18 16:34:15.396628
# 2018-03-13
# prior 10 days open 43.14
# close 47.61
# change > 0.07, drop COUP
# prior 10 days open 154.99
# close 174.7
# change > 0.07, drop LGND
# prior 10 days open 14.2
# close 15.75
# change > 0.07, drop EVH
# JBL has earning date, drop
# prior 10 days open 68.65
# close 83.25
# change > 0.07, drop JOBS
# DKS has earning date, drop
# prior 10 days open 36.31
# close 42.6
# change > 0.07, drop OKTA
# DSW has earning date, drop
# GOLF has earning date, drop
# prior 10 days open 42.23464
# close 48.19729
# change > 0.07, drop KFY
# prior 10 days open 47.42
# close 53.77
# change > 0.07, drop Z
# 2019-03-18 16:34:18.842993
# 2018-03-14
# prior 10 days open 14.45
# close 15.6
# change > 0.07, drop EVH
# prior 10 days open 69.73
# close 83.71
# change > 0.07, drop JOBS
# JBL has earning date, drop
# DKS has earning date, drop
# prior 10 days open 43.29
# close 48.39
# change > 0.07, drop COUP
# prior 10 days open 20.81225
# close 22.398970000000002
# change > 0.07, drop GOLF
# prior 10 days open 35.96
# close 49.095
# change > 0.07, drop NTNX
# prior 10 days open 46.82
# close 55.19
# change > 0.07, drop Z
# DSW has earning date, drop
# SIG has earning date, drop
# prior 10 days open 29.85
# close 33.7
# change > 0.07, drop MMYT
# prior 10 days open 154.49
# close 176.04
# change > 0.07, drop LGND
# prior 10 days open 47.15
# close 55.12
# change > 0.07, drop ZG
# prior 10 days open 36.8
# close 39.71
# change > 0.07, drop OKTA
# 2019-03-18 16:34:22.734607
# 2018-03-15
# prior 10 days open 36.64
# close 51.48
# change > 0.07, drop NTNX
# prior 10 days open 50.17075
# close 46.18558
# change > 0.07, drop SIG
# prior 10 days open 17.1
# close 19.99
# change > 0.07, drop AKCA
# prior 10 days open 65.07
# close 83.2
# change > 0.07, drop JOBS
# SMTC has earning date, drop
# prior 10 days open 46.49
# close 56.78
# change > 0.07, drop ZG
# prior 10 days open 44.14
# close 49.18
# change > 0.07, drop COUP
# DKS has earning date, drop
# WSM has earning date, drop
# JBL has earning date, drop
# prior 10 days open 46.41
# close 56.97
# change > 0.07, drop Z
# prior 10 days open 14.45
# close 15.95
# change > 0.07, drop EVH
# DSW has earning date, drop
# 2019-03-18 16:34:26.437743
# 2018-03-16
# prior 10 days open 16.8
# close 19.64
# change > 0.07, drop AKCA
# prior 10 days open 35.9
# close 53.04
# change > 0.07, drop NTNX
# SMTC has earning date, drop
# JBL has earning date, drop
# SIG has earning date, drop
# prior 10 days open 66.13
# close 81.59
# change > 0.07, drop JOBS
# prior 10 days open 46.45
# close 57.15
# change > 0.07, drop ZG
# prior 10 days open 33.17862
# close 37.150290000000005
# WSM has earning date, drop
# change > 0.07, drop HLNE
# 2019-03-18 16:34:29.801941
# 2018-03-19
# prior 10 days open 62.65
# close 68.05
# change > 0.07, drop RNG
# prior 10 days open 17.08
# close 20.34
# change > 0.07, drop AKCA
# prior 10 days open 20.55
# prior 10 days open 55.45842
# close 59.61946
# change > 0.07, drop TQQQ
# close 22.2
# change > 0.07, drop HRTX
# JBL has earning date, drop
# SMTC has earning date, drop
# prior 10 days open 63.4
# close 81.46
# change > 0.07, drop JOBS
# prior 10 days open 36.55
# close 54.66
# change > 0.07, drop NTNX
# prior 10 days open 33.54
# close 30.16
# change > 0.07, drop FWONA
# prior 10 days open 47.64
# close 58.49
# change > 0.07, drop ZG
# 2019-03-18 16:34:32.752363
# 2018-03-20
# prior 10 days open 54.2294
# close 58.24823000000001
# change > 0.07, drop SKYW
# prior 10 days open 62.2
# close 68.1
# change > 0.07, drop RNG
# prior 10 days open 50.824670000000005
# close 59.35315
# change > 0.07, drop TQQQ
# prior 10 days open 44.88668
# close 36.69468
# prior 10 days open 25.950960000000002
# change > 0.07, drop TCP
# close 28.154709999999998
# change > 0.07, drop JBL
# prior 10 days open 40.35
# close 33.01
# change > 0.07, drop ARNA
# prior 10 days open 53.55
# close 59.23
# change > 0.07, drop HQY
# prior 10 days open 17.16
# close 28.14
# change > 0.07, drop AKCA
# prior 10 days open 70.6
# close 81.54
# change > 0.07, drop JOBS
# prior 10 days open 33.01
# close 39.73
# change > 0.07, drop MDB
# prior 10 days open 54
# close 59.21
# change > 0.07, drop ORBK
# 2019-03-18 16:34:35.898414
# 2018-03-21
# prior 10 days open 55.34
# close 59.39
# change > 0.07, drop HQY
# prior 10 days open 53.35791
# close 58.96035
# change > 0.07, drop TQQQ
# prior 10 days open 43.76
# prior 10 days open 25.25
# close 31.51
# prior 10 days open 53.832480000000004
# close 21.6
# change > 0.07, drop ARNA
# close 59.835919999999994
# change > 0.07, drop SKYW
# change > 0.07, drop DM
# prior 10 days open 74.1
# close 83.72
# change > 0.07, drop JOBS
# prior 10 days open 35.99
# close 39.28
# change > 0.07, drop MDB
# prior 10 days open 55.82
# close 59.9
# change > 0.07, drop ORBK
# prior 10 days open 44.73107
# close 32.72224
# change > 0.07, drop TCP
# PQG has earning date, drop
# LAUR has earning date, drop
# prior 10 days open 237.8985
# close 255.1271
# change > 0.07, drop RE
# 2019-03-18 16:34:39.949242
# 2018-03-22
# prior 10 days open 42.73
# close 30.89
# change > 0.07, drop ARNA
# prior 10 days open 25.8
# close 18.4
# change > 0.07, drop DM
# prior 10 days open 25.31
# close 27.83
# change > 0.07, drop ETSY
# SCS has earning date, drop
# HQY has earning date, drop
# MLHR has earning date, drop
# prior 10 days open 76.39
# close 83.8
# change > 0.07, drop JOBS
# prior 10 days open 26.646890000000003
# close 13.23371
# change > 0.07, drop MFGP
# prior 10 days open 49.49
# close 52.96
# change > 0.07, drop PCTY
# FIVE has earning date, drop
# prior 10 days open 36.64
# close 39.62
# change > 0.07, drop MDB
# 2019-03-18 16:34:42.665990
# 2018-03-23
# prior 10 days open 25.5
# close 28.31
# change > 0.07, drop ETSY
# MLHR has earning date, drop
# prior 10 days open 49.92
# close 54.82
# change > 0.07, drop PCTY
# prior 10 days open 29.85
# prior 10 days open 57.75
# close 33.84
# close 64.54
# change > 0.07, drop GKOS
# change > 0.07, drop HQY
# FIVE has earning date, drop
# prior 10 days open 80
# close 85.65
# prior 10 days open 2.3
# change > 0.07, drop JOBS
# close 2.47
# change > 0.07, drop DNR
# prior 10 days open 25.1
# close 17.75
# change > 0.07, drop DM
# prior 10 days open 26.35407
# close 13.224260000000001
# change > 0.07, drop MFGP
# 2019-03-18 16:34:45.473401
# 2018-03-26
# prior 10 days open 30.37
# close 27.63
# change > 0.07, drop HOME
# prior 10 days open 31.59
# close 34.5
# change > 0.07, drop GKOS
# prior 10 days open 24.9
# close 16.75
# change > 0.07, drop DM
# prior 10 days open 51.8
# close 55.6
# change > 0.07, drop PCTY
# prior 10 days open 58.76
# close 65.46
# change > 0.07, drop HQY
# prior 10 days open 26.29
# close 28.95
# change > 0.07, drop ETSY
# prior 10 days open 2.3
# close 2.71
# change > 0.07, drop DNR
# FIVE has earning date, drop
# 2019-03-18 16:34:48.387504
# 2018-03-27
# prior 10 days open 76.44415
# close 69.74714
# change > 0.07, drop BDC
# prior 10 days open 29.66
# close 26.46
# change > 0.07, drop HOME
# prior 10 days open 25
# close 16.5
# change > 0.07, drop DM
# CLDR has earning date, drop
# 2019-03-18 16:34:51.092705
# 2018-03-28
# CALM has earning date, drop
# CLDR has earning date, drop
# prior 10 days open 25.4
# close 16.25
# change > 0.07, drop DM
# RH has earning date, drop
# 2019-03-18 16:34:54.448427
# 2018-03-29
# CLDR has earning date, drop
# prior 10 days open 14.38641
# close 16.49772
# change > 0.07, drop TVPT
# prior 10 days open 23.81306
# close 19.326
# change > 0.07, drop SHLX
# CALM has earning date, drop
# RH has earning date, drop
# prior 10 days open 3.85
# close 4.13
# change > 0.07, drop TNDM
# prior 10 days open 35.5
# close 40.03
# change > 0.07, drop USG
# 2019-03-18 16:34:56.870990
# 2018-04-02
# prior 10 days open 3.75
# close 4.51
# change > 0.07, drop TNDM
# prior 10 days open 122.2294
# close 113.1506
# change > 0.07, drop SNX
# CALM has earning date, drop
# CLDR has earning date, drop
# RH has earning date, drop
# 2019-03-18 16:34:59.496240
# 2018-04-03
# prior 10 days open 121.5205
# close 112.6878
# change > 0.07, drop SNX
# CLDR has earning date, drop
# 2019-03-18 16:35:02.013461
# 2018-04-04
# prior 10 days open 19.8
# close 21.58
# change > 0.07, drop CLDR
# OLLI has earning date, drop
# prior 10 days open 12.5
# close 11.25
# change > 0.07, drop CZR
# 2019-03-18 16:35:06.068392
# 2018-04-05
# prior 10 days open 19.51
# close 21.23
# change > 0.07, drop CLDR
# prior 10 days open 12.7
# close 10.8
# change > 0.07, drop CZR
# LW has earning date, drop
# OLLI has earning date, drop
# prior 10 days open 58.25
# close 63.4
# change > 0.07, drop CVLT
# 2019-03-18 16:35:09.810071
# 2018-04-06
# prior 10 days open 19.54
# close 22.24
# change > 0.07, drop CLDR
# prior 10 days open 82.05
# close 91.05
# change > 0.07, drop USNA
# PSMT has earning date, drop
# prior 10 days open 12.3
# close 10.65
# change > 0.07, drop CZR
# LW has earning date, drop
# OLLI has earning date, drop
# 2019-03-18 16:35:12.536848
# 2018-04-09
# prior 10 days open 54.926230000000004
# close 58.78382
# change > 0.07, drop LW
# prior 10 days open 82.05
# close 92.65
# change > 0.07, drop USNA
# MSM has earning date, drop
# PSMT has earning date, drop
# 2019-03-18 16:35:15.047882
# 2018-04-10
# prior 10 days open 24.45
# close 22.13
# change > 0.07, drop ACAD
# prior 10 days open 54.401990000000005
# close 60.80164
# change > 0.07, drop LW
# MSM has earning date, drop
# PSMT has earning date, drop
# prior 10 days open 3.69
# close 5.52
# change > 0.07, drop TNDM
# prior 10 days open 82.5
# close 93.2
# change > 0.07, drop USNA
# API Problem
# prior 10 days open 38.07804
# close 41.88585
# change > 0.07, drop DK
# 2019-03-18 16:35:18.077472
# 2018-04-11
# prior 10 days open 8.009286999999999
# close 8.820843
# prior 10 days open 23.63
# close 21.53
# change > 0.07, drop ACAD
# change > 0.07, drop TI.A
# prior 10 days open 30.25
# close 27.2
# prior 10 days open 4.14
# change > 0.07, drop RGNX
# close 5.75
# change > 0.07, drop TNDM
# MSM has earning date, drop
# prior 10 days open 54.154709999999994
# close 61.10827
# change > 0.07, drop LW
# prior 10 days open 4.64
# close 5.13
# change > 0.07, drop I
# HCSG has earning date, drop
# 2019-03-18 16:35:20.800098
# 2018-04-12
# prior 10 days open 7.922333999999999
# close 8.714568
# prior 10 days open 14.61
# change > 0.07, drop TI.A
# close 13.12
# change > 0.07, drop WPX
# prior 10 days open 4.1
# close 5.72
# change > 0.07, drop TNDM
# BBBY has earning date, drop
# CBSH has earning date, drop
# EXPO has earning date, drop
# prior 10 days open 4.45
# close 5.77
# change > 0.07, drop I
# prior 10 days open 21.21
# close 19.48
# change > 0.07, drop JBLU
# SJR has earning date, drop
# 2019-03-18 16:35:23.908328
# 2018-04-13
# CBSH has earning date, drop
# prior 10 days open 18.39
# close 20.23
# prior 10 days open 58.05
# change > 0.07, drop WRD
# close 63.2
# change > 0.07, drop AMN
# BBBY has earning date, drop
# WAFD has earning date, drop
# prior 10 days open 22.77579
# close 24.389229999999998
# change > 0.07, drop VNOM
# prior 10 days open 4.21
# close 6.41
# change > 0.07, drop I
# SJR has earning date, drop
# 2019-03-18 16:35:26.732289
# 2018-04-16
# prior 10 days open 121.16
# close 133.82
# change > 0.07, drop INGN
# prior 10 days open 3.99
# close 6.41
# prior 10 days open 17.93
# change > 0.07, drop I
# close 21.34
# change > 0.07, drop WRD
# WAFD has earning date, drop
# CBSH has earning date, drop
# BBBY has earning date, drop
# prior 10 days open 57.35
# close 64.15
# change > 0.07, drop AMN
# prior 10 days open 22.07225
# close 24.839489999999998
# change > 0.07, drop VNOM
# prior 10 days open 63.572359999999996
# close 68.39265
# change > 0.07, drop HP
# prior 10 days open 57.9195
# close 65.80203
# change > 0.07, drop MEOH
# 2019-03-18 16:35:29.657010
# 2018-04-17
# prior 10 days open 32.5
# close 35.5
# change > 0.07, drop ERI
# prior 10 days open 18.08
# close 21.8
# change > 0.07, drop WRD
# prior 10 days open 3.75
# close 6.94
# change > 0.07, drop I
# prior 10 days open 21.99721
# close 24.95205
# change > 0.07, drop VNOM
# prior 10 days open 20.67004
# close 19.057479999999998
# change > 0.07, drop UGP
# CBSH has earning date, drop
# LTXB has earning date, drop
# prior 10 days open 62.10905
# close 69.34905
# change > 0.07, drop HP
# prior 10 days open 120.46
# close 137.39
# change > 0.07, drop INGN
# 2019-03-18 16:35:33.101094
# 2018-04-18
# prior 10 days open 20.87528
# close 18.85225
# change > 0.07, drop UGP
# prior 10 days open 3.74
# close 7.08
# change > 0.07, drop I
# prior 10 days open 18.96
# close 22.11
# change > 0.07, drop WRD
# prior 10 days open 168.854
# close 147.9431
# change > 0.07, drop ALGT
# prior 10 days open 32.95
# prior 10 days open 23.68569
# close 26.406029999999998
# close 35.7
# change > 0.07, drop ERI
# change > 0.07, drop VNOM
# LTXB has earning date, drop
# prior 10 days open 60.5
# close 64.95
# change > 0.07, drop VRNS
# prior 10 days open 20.6
# close 22.53
# change > 0.07, drop SAIL
# HCSG has earning date, drop
# prior 10 days open 44.86
# close 54.96
# change > 0.07, drop AA
# prior 10 days open 114.25
# close 122.99
# change > 0.07, drop LOXO
# 2019-03-18 16:35:36.443594
# 2018-04-19
# GTLS has earning date, drop
# prior 10 days open 3.64
# close 8.41
# change > 0.07, drop I
# prior 10 days open 22.79
# close 27.03
# change > 0.07, drop CVNA
# prior 10 days open 60.5
# prior 10 days open 20.15
# close 65.75
# close 22.32
# change > 0.07, drop VRNS
# change > 0.07, drop SAIL
# prior 10 days open 20.80687
# close 18.49065
# change > 0.07, drop UGP
# WBS has earning date, drop
# CHE has earning date, drop
# prior 10 days open 44.63
# close 55.03
# change > 0.07, drop AA
# prior 10 days open 23.54498
# close 26.93133
# change > 0.07, drop VNOM
# prior 10 days open 13.79
# close 15.48
# change > 0.07, drop WPX
# prior 10 days open 38.08
# close 42.4
# change > 0.07, drop SKX
# SEIC has earning date, drop
# TMK has earning date, drop
# SON has earning date, drop
# prior 10 days open 67.43903
# close 72.79449
# change > 0.07, drop NSP
# prior 10 days open 18.09
# close 20.04
# change > 0.07, drop OII
# prior 10 days open 18.34
# close 23.44
# change > 0.07, drop WRD
# POOL has earning date, drop
# prior 10 days open 106.1
# close 120.58
# change > 0.07, drop GWPH
# prior 10 days open 16.21539
# close 17.43279
# change > 0.07, drop ELY
# prior 10 days open 2.423764
# close 2.103644
# change > 0.07, drop VEON
# prior 10 days open 12.87
# close 10.84
# change > 0.07, drop MTG
# 2019-03-18 16:35:40.973238
# 2018-04-20
# prior 10 days open 38.5
# close 42.45
# change > 0.07, drop SKX
# WBS has earning date, drop
# prior 10 days open 44.4
# close 57.08
# change > 0.07, drop AA
# prior 10 days open 60.75
# close 67.35
# prior 10 days open 18.16
# close 19.62
# change > 0.07, drop VRNS
# change > 0.07, drop OII
# CHE has earning date, drop
# LECO has earning date, drop
# SEIC has earning date, drop
# prior 10 days open 17.97
# close 23.55
# change > 0.07, drop WRD
# prior 10 days open 203.29
# close 224
# change > 0.07, drop TYL
# prior 10 days open 41.26
# close 44.49
# prior 10 days open 20.3
# change > 0.07, drop IONS
# close 24.61
# prior 10 days open 38.46671
# change > 0.07, drop SAIL
# close 41.31518
# change > 0.07, drop EXPO
# prior 10 days open 12.3
# prior 10 days open 44.95
# close 13.55
# close 50.46
# change > 0.07, drop CPE
# change > 0.07, drop ZEN
# prior 10 days open 4.14
# close 4.48
# change > 0.07, drop ICL
# prior 10 days open 28.50017
# close 30.7329
# change > 0.07, drop SHOO
# GTLS has earning date, drop
# prior 10 days open 68.13325999999999
# close 75.32345
# change > 0.07, drop NSP
# prior 10 days open 109.86
# close 134.13
# prior 10 days open 13.34
# change > 0.07, drop GWPH
# close 15.83
# change > 0.07, drop WPX
# prior 10 days open 3.64
# close 9.11
# change > 0.07, drop I
# MAN has earning date, drop
# UMPQ has earning date, drop
# 2019-03-18 16:35:44.396298
# 2018-04-23
# prior 10 days open 18.63
# close 24.3
# change > 0.07, drop WRD
# LECO has earning date, drop
# WRB has earning date, drop
# CHE has earning date, drop
# SKX has earning date, drop
# FFBC has earning date, drop
# GTLS has earning date, drop
# prior 10 days open 47.2
# close 59.4
# change > 0.07, drop AA
# prior 10 days open 60.26568
# close 64.63546
# change > 0.07, drop ALK
# MAN has earning date, drop
# MDR has earning date, drop
# RNST has earning date, drop
# UMPQ has earning date, drop
# SHOO has earning date, drop
# prior 10 days open 69.42254
# close 75.96809
# change > 0.07, drop NSP
# prior 10 days open 4.21
# close 4.51
# change > 0.07, drop ICL
# prior 10 days open 112.46
# close 133.39
# change > 0.07, drop GWPH
# prior 10 days open 18.73
# close 20.17
# change > 0.07, drop OII
# EXPO has earning date, drop
# prior 10 days open 63.717
# close 69.10251
# change > 0.07, drop BWXT
# prior 10 days open 18.7
# close 20.5
# change > 0.07, drop MNTA
# VRNS has earning date, drop
# BOH has earning date, drop
# prior 10 days open 20.5
# close 23.8
# change > 0.07, drop NVCR
# CLF has earning date, drop
# MSA has earning date, drop
# SON has earning date, drop
# ASB has earning date, drop
# 2019-03-18 16:35:49.139946
# 2018-04-24
# prior 10 days open 19.06
# close 24.91
# change > 0.07, drop WRD
# WRB has earning date, drop
# TCF has earning date, drop
# LECO has earning date, drop
# SKX has earning date, drop
# CLF has earning date, drop
# ALK has earning date, drop
# WHR has earning date, drop
# SC has earning date, drop
# MDR has earning date, drop
# prior 10 days open 42.16
# close 45.85
# change > 0.07, drop IONS
# FFBC has earning date, drop
# prior 10 days open 17.85
# prior 10 days open 26.6
# close 28.9
# close 20.45
# change > 0.07, drop TSG
# change > 0.07, drop MNTA
# API Problem
# HOG has earning date, drop
# MAN has earning date, drop
# RNST has earning date, drop
# prior 10 days open 41.67105
# close 45.19571
# change > 0.07, drop DK
# prior 10 days open 64.03321
# close 69.77445999999999
# change > 0.07, drop BWXT
# prior 10 days open 47.18
# close 60.23
# change > 0.07, drop AA
# prior 10 days open 45.82
# close 50.48
# change > 0.07, drop ZEN
# ONB has earning date, drop
# EXPO has earning date, drop
# FFIN has earning date, drop
# prior 10 days open 69.968
# close 77.25737
# change > 0.07, drop NSP
# ENTG has earning date, drop
# JBLU has earning date, drop
# GPK has earning date, drop
# CHE has earning date, drop
# UMPQ has earning date, drop
# ASB has earning date, drop
# prior 10 days open 12.92
# close 10.35
# change > 0.07, drop MTG
# prior 10 days open 4.81
# close 9.19
# change > 0.07, drop I
# prior 10 days open 17.39
# close 18.73
# change > 0.07, drop CDEV
# SNV has earning date, drop
# 2019-03-18 16:35:54.922132
# 2018-04-25
# RNST has earning date, drop
# BPOP has earning date, drop
# prior 10 days open 16.89
# close 18.15
# change > 0.07, drop MDR
# prior 10 days open 45.58508
# close 49.10366
# change > 0.07, drop TQQQ
# prior 10 days open 104.5766
# close 118.7482
# change > 0.07, drop CLB
# WRB has earning date, drop
# TCF has earning date, drop
# GPK has earning date, drop
# SLGN has earning date, drop
# USNA has earning date, drop
# prior 10 days open 41.77845
# close 45.65459
# change > 0.07, drop DK
# SC has earning date, drop
# prior 10 days open 27.6271
# close 29.96179
# change > 0.07, drop FFBC
# IART has earning date, drop
# prior 10 days open 26.45
# close 29.3
# change > 0.07, drop TSG
# prior 10 days open 18.94
# close 24.85
# change > 0.07, drop WRD
# HOG has earning date, drop
# ENTG has earning date, drop
# TRVG has earning date, drop
# prior 10 days open 68.72832
# close 73.93500999999999
# change > 0.07, drop NSP
# prior 10 days open 59.7562
# close 64.06719
# change > 0.07, drop ALK
# prior 10 days open 5.09
# close 9.31
# change > 0.07, drop I
# TRN has earning date, drop
# WHR has earning date, drop
# FFIN has earning date, drop
# MTG has earning date, drop
# prior 10 days open 39.08
# close 41.97
# change > 0.07, drop OKTA
# prior 10 days open 6.856107000000001
# close 7.670889999999999
# change > 0.07, drop CLF
# prior 10 days open 20.80205
# close 22.9423
# change > 0.07, drop UMPQ
# JBLU has earning date, drop
# CFR has earning date, drop
# TER has earning date, drop
# SNV has earning date, drop
# GT has earning date, drop
# BRO has earning date, drop
# prior 10 days open 45.85
# close 49.8
# change > 0.07, drop QTWO
# VVV has earning date, drop
# prior 10 days open 81.72864
# close 87.56919
# change > 0.07, drop RS
# CUZ has earning date, drop
# RHI has earning date, drop
# CR has earning date, drop
# PII has earning date, drop
# prior 10 days open 2.38
# close 2.57
# change > 0.07, drop WFT
# BOKF has earning date, drop
# prior 10 days open 18.41
# close 23.71
# change > 0.07, drop CRC
# AOS has earning date, drop
# prior 10 days open 61.18046
# close 66.05202
# change > 0.07, drop GRA
# prior 10 days open 49.78
# close 60.01
# change > 0.07, drop AA
# H has earning date, drop
# prior 10 days open 39.63087
# close 42.52887
# CSL has earning date, drop
# change > 0.07, drop EXPO
# prior 10 days open 35.91548
# close 32.12113
# change > 0.07, drop LB
# OI has earning date, drop
# GMED has earning date, drop
# prior 10 days open 53.9305
# close 58.10759
# change > 0.07, drop WBS
# prior 10 days open 23.97648
# close 27.29482
# change > 0.07, drop VNOM
# LII has earning date, drop
# prior 10 days open 14.1
# close 16.75
# change > 0.07, drop STAA
# API Problem
# prior 10 days open 24.01
# close 25.94
# change > 0.07, drop ATI
# MRCY has earning date, drop
# prior 10 days open 40.64
# close 30.7
# change > 0.07, drop SKX
# MANT has earning date, drop
# 2019-03-18 16:36:05.427079
# 2018-04-26
# prior 10 days open 42.45213
# close 46.13301
# change > 0.07, drop DK
# RNST has earning date, drop
# SLGN has earning date, drop
# prior 10 days open 18.7
# close 23.35
# change > 0.07, drop CRC
# IART has earning date, drop
# BEAT has earning date, drop
# HXL has earning date, drop
# SNV has earning date, drop
# prior 10 days open 105.0653
# close 119.9601
# change > 0.07, drop CLB
# TRVG has earning date, drop
# ENTG has earning date, drop
# prior 10 days open 43.13276
# close 40.080870000000004
# change > 0.07, drop TER
# USNA has earning date, drop
# AXE has earning date, drop
# SC has earning date, drop
# CFR has earning date, drop
# prior 10 days open 21.97114
# close 23.73625
# change > 0.07, drop TCF
# WRB has earning date, drop
# BRO has earning date, drop
# FCN has earning date, drop
# BPOP has earning date, drop
# FFIN has earning date, drop
# prior 10 days open 5.85
# close 9.3
# change > 0.07, drop I
# prior 10 days open 27.67574
# close 30.54546
# change > 0.07, drop FFBC
# MRCY has earning date, drop
# HOG has earning date, drop
# TRN has earning date, drop
# RHI has earning date, drop
# CAKE has earning date, drop
# CCMP has earning date, drop
# MASI has earning date, drop
# OC has earning date, drop
# prior 10 days open 61.54533000000001
# close 66.45633000000001
# change > 0.07, drop GRA
# QTWO has earning date, drop
# prior 10 days open 34.04607
# close 36.73238
# change > 0.07, drop TX
# prior 10 days open 2.39
# close 2.59
# change > 0.07, drop WFT
# prior 10 days open 19.36
# close 24.8
# change > 0.07, drop WRD
# AOS has earning date, drop
# JBLU has earning date, drop
# prior 10 days open 69.86882
# close 75.96809
# change > 0.07, drop NSP
# GWB has earning date, drop
# prior 10 days open 14.35
# CLF has earning date, drop
# close 16.65
# AZPN has earning date, drop
# change > 0.07, drop STAA
# prior 10 days open 20.976370000000003
# close 23.23283
# change > 0.07, drop UMPQ
# UBSI has earning date, drop
# prior 10 days open 20.37
# close 22.91
# change > 0.07, drop BOX
# BOKF has earning date, drop
# prior 10 days open 15.68
# close 17.02
# change > 0.07, drop AMGP
# prior 10 days open 54.40005
# close 58.63584
# change > 0.07, drop WBS
# GT has earning date, drop
# UGI has earning date, drop
# USM has earning date, drop
# HUBB has earning date, drop
# CR has earning date, drop
# WHR has earning date, drop
# prior 10 days open 67.53464
# close 72.61842
# change > 0.07, drop MTX
# MD has earning date, drop
# prior 10 days open 35.803329999999995
# close 32.52299
# MMSI has earning date, drop
# change > 0.07, drop LB
# WWE has earning date, drop
# prior 10 days open 20.73
# close 24.2
# change > 0.07, drop SAIL
# prior 10 days open 10.1
# close 12.48
# change > 0.07, drop RIG
# CSL has earning date, drop
# SLM has earning date, drop
# ST has earning date, drop
# CZR has earning date, drop
# AX has earning date, drop
# ATI has earning date, drop
# 2019-03-18 16:36:15.976953
# 2018-04-27
# prior 10 days open 41.92667
# close 45.1503
# change > 0.07, drop BPOP
# prior 10 days open 43.242979999999996
# close 46.347809999999996
# change > 0.07, drop DK
# prior 10 days open 34.39646
# close 36.90757
# change > 0.07, drop TX
# MOG.A has earning date, drop
# CLB has earning date, drop
# ROIC has earning date, drop
# IART has earning date, drop
# FCN has earning date, drop
# CFR has earning date, drop
# BOKF has earning date, drop
# prior 10 days open 45.792609999999996
# close 49.68671
# change > 0.07, drop FFIN
# AXE has earning date, drop
# FIX has earning date, drop
# FLEX has earning date, drop
# MDU has earning date, drop
# BRO has earning date, drop
# UGI has earning date, drop
# BEAT has earning date, drop
# prior 10 days open 35.72502
# close 32.95026
# change > 0.07, drop ENTG
# TRVG has earning date, drop
# OC has earning date, drop
# USNA has earning date, drop
# GWB has earning date, drop
# MASI has earning date, drop
# prior 10 days open 46.53
# close 42.93
# change > 0.07, drop MRCY
# MD has earning date, drop
# CAKE has earning date, drop
# AZPN has earning date, drop
# prior 10 days open 20.96669
# close 23.55242
# change > 0.07, drop UMPQ
# MMSI has earning date, drop
# WWE has earning date, drop
# QTWO has earning date, drop
# BWA has earning date, drop
# prior 10 days open 6.43
# close 10.02
# change > 0.07, drop I
# RNST has earning date, drop
# TER has earning date, drop
# CLGX has earning date, drop
# prior 10 days open 54.13593
# close 58.86083000000001
# change > 0.07, drop WBS
# HXL has earning date, drop
# RHI has earning date, drop
# CR has earning date, drop
# prior 10 days open 106.2439
# close 98.4186
# change > 0.07, drop CCMP
# prior 10 days open 95.65208
# close 102.6944
# prior 10 days open 17.6
# change > 0.07, drop MORN
# close 19.47
# change > 0.07, drop ACAD
# DRE has earning date, drop
# prior 10 days open 20.53
# close 24
# change > 0.07, drop CRC
# prior 10 days open 20.39
# close 24.85
# change > 0.07, drop WRD
# ELY has earning date, drop
# IPG has earning date, drop
# EQM has earning date, drop
# prior 10 days open 14.35
# close 16.15
# change > 0.07, drop STAA
# IDA has earning date, drop
# CUZ has earning date, drop
# NTB has earning date, drop
# prior 10 days open 56.0406
# close 48.24635
# change > 0.07, drop TEN
# UCBI has earning date, drop
# B has earning date, drop
# GMED has earning date, drop
# ST has earning date, drop
# PFPT has earning date, drop
# GT has earning date, drop
# VVV has earning date, drop
# prior 10 days open 24.839489999999998
# close 26.770290000000003
# change > 0.07, drop VNOM
# DNKN has earning date, drop
# prior 10 days open 10.51
# close 12.45
# change > 0.07, drop RIG
# X has earning date, drop
# TRN has earning date, drop
# USM has earning date, drop
# AVX has earning date, drop
# CY has earning date, drop
# SNV has earning date, drop
# CLF has earning date, drop
# 2019-03-18 16:36:26.646593
# 2018-04-30
# CFR has earning date, drop
# AXE has earning date, drop
# FLEX has earning date, drop
# ALE has earning date, drop
# DK has earning date, drop
# BRO has earning date, drop
# KMPR has earning date, drop
# ROIC has earning date, drop
# VAC has earning date, drop
# REXR has earning date, drop
# prior 10 days open 46.67987
# close 50.03176
# change > 0.07, drop FFIN
# CAKE has earning date, drop
# BEAT has earning date, drop
# FCN has earning date, drop
# MMSI has earning date, drop
# FIX has earning date, drop
# TX has earning date, drop
# BOH has earning date, drop
# IPG has earning date, drop
# IART has earning date, drop
# CLGX has earning date, drop
# AZPN has earning date, drop
# BWA has earning date, drop
# WCC has earning date, drop
# PFPT has earning date, drop
# NATI has earning date, drop
# USM has earning date, drop
# prior 10 days open 108.5361
# close 96.96619
# change > 0.07, drop CCMP
# CUZ has earning date, drop
# KOS has earning date, drop
# ELY has earning date, drop
# MEDP has earning date, drop
# DRE has earning date, drop
# MASI has earning date, drop
# ARLP has earning date, drop
# GMED has earning date, drop
# CONE has earning date, drop
# prior 10 days open 80.04365
# close 66.31963
# change > 0.07, drop OC
# ENTG has earning date, drop
# prior 10 days open 42.53416
# close 46.11052
# HXL has earning date, drop
# change > 0.07, drop BPOP
# KRC has earning date, drop
# ALSN has earning date, drop
# SAM has earning date, drop
# COLM has earning date, drop
# prior 10 days open 16.83011
# close 15.57981
# change > 0.07, drop CY
# prior 10 days open 54.11152
# close 48.86015
# change > 0.07, drop TEN
# VNOM has earning date, drop
# prior 10 days open 11.03
# close 12.55
# change > 0.07, drop RIG
# CLB has earning date, drop
# prior 10 days open 21.44
# close 24.95
# change > 0.07, drop WRD
# VVV has earning date, drop
# FSLR has earning date, drop
# WWE has earning date, drop
# UAA has earning date, drop
# GNRC has earning date, drop
# ITT has earning date, drop
# X has earning date, drop
# CNMD has earning date, drop
# MGP has earning date, drop
# EXAS has earning date, drop
# 2019-03-18 16:36:36.414126
# 2018-05-01
# FIX has earning date, drop
# FLEX has earning date, drop
# ELY has earning date, drop
# VAC has earning date, drop
# AIZ has earning date, drop
# COMM has earning date, drop
# CAKE has earning date, drop
# KMPR has earning date, drop
# ARLP has earning date, drop
# prior 10 days open 44.042
# close 47.15142
# change > 0.07, drop UGI
# IRWD has earning date, drop
# CUBE has earning date, drop
# INGN has earning date, drop
# ALE has earning date, drop
# DRE has earning date, drop
# REXR has earning date, drop
# FELE has earning date, drop
# MEDP has earning date, drop
# prior 10 days open 50.35
# close 56.66
# change > 0.07, drop FCN
# NATI has earning date, drop
# VVV has earning date, drop
# prior 10 days open 47.59303
# close 51.04831
# change > 0.07, drop CONE
# CFR has earning date, drop
# COLM has earning date, drop
# MMSI has earning date, drop
# IPG has earning date, drop
# ALSN has earning date, drop
# prior 10 days open 10.91
# close 10.01
# change > 0.07, drop MTG
# UAA has earning date, drop
# USM has earning date, drop
# prior 10 days open 76.7
# close 60.1
# change > 0.07, drop AXE
# NRZ has earning date, drop
# THC has earning date, drop
# prior 10 days open 83.00632
# close 90.76501999999999
# change > 0.07, drop IDA
# SAVE has earning date, drop
# CCJ has earning date, drop
# prior 10 days open 24.623739999999998
# close 26.78936
# change > 0.07, drop VNOM
# prior 10 days open 51.33
# close 55.24
# change > 0.07, drop PDCE
# TNET has earning date, drop
# B has earning date, drop
# prior 10 days open 119.4737
# close 107.5929
# change > 0.07, drop CPA
# prior 10 days open 55.92
# close 60.02
# change > 0.07, drop IART
# FSLR has earning date, drop
# ARCC has earning date, drop
# GMED has earning date, drop
# prior 10 days open 71.45563
# close 76.51356
# change > 0.07, drop NSP
# prior 10 days open 17.2892
# close 15.79471
# change > 0.07, drop CY
# prior 10 days open 11.09
# prior 10 days open 34.53618
# close 12.48
# close 37.33903
# change > 0.07, drop RIG
# change > 0.07, drop PBF
# X has earning date, drop
# TDOC has earning date, drop
# prior 10 days open 41.90537
# close 47.22653
# change > 0.07, drop DK
# EXAS has earning date, drop
# prior 10 days open 6.89
# prior 10 days open 92.07404
# close 9.99
# close 69.05553
# change > 0.07, drop I
# change > 0.07, drop SPB
# prior 10 days open 33.7
# close 38.15
# change > 0.07, drop BEAT
# WES has earning date, drop
# NUS has earning date, drop
# prior 10 days open 21.92
# close 25.42
# change > 0.07, drop WRD
# PAYC has earning date, drop
# SABR has earning date, drop
# BPL has earning date, drop
# 2019-03-18 16:36:45.741791
# 2018-05-02
# API Problem
# prior 10 days open 69.86310999999999
# close 74.85471
# change > 0.07, drop ALE
# prior 10 days open 44.35
# close 47.75
# change > 0.07, drop APPF
# KMPR has earning date, drop
# INGN has earning date, drop
# THC has earning date, drop
# FELE has earning date, drop
# CUBE has earning date, drop
# VAC has earning date, drop
# LFUS has earning date, drop
# CUZ has earning date, drop
# UNM has earning date, drop
# COMM has earning date, drop
# prior 10 days open 17.19
# close 18.68
# CAKE has earning date, drop
# change > 0.07, drop IRWD
# AIZ has earning date, drop
# prior 10 days open 50.51
# close 55.58
# change > 0.07, drop FCN
# USM has earning date, drop
# HHC has earning date, drop
# JBT has earning date, drop
# ARCC has earning date, drop
# SSD has earning date, drop
# NEU has earning date, drop
# UMC has earning date, drop
# AGCO has earning date, drop
# VVV has earning date, drop
# CCJ has earning date, drop
# ARLP has earning date, drop
# prior 10 days open 16.64
# close 17.83
# change > 0.07, drop UAA
# prior 10 days open 14.72233
# close 16.1728
# change > 0.07, drop UNIT
# CIGI has earning date, drop
# SAVE has earning date, drop
# VNOM has earning date, drop
# XRAY has earning date, drop
# prior 10 days open 7.14
# close 10.34
# change > 0.07, drop I
# DRE has earning date, drop
# TDOC has earning date, drop
# prior 10 days open 55.6
# close 61.72
# change > 0.07, drop IART
# PBF has earning date, drop
# CPS has earning date, drop
# ALSN has earning date, drop
# MUSA has earning date, drop
# SEAS has earning date, drop
# prior 10 days open 11.49
# close 12.42
# change > 0.07, drop RIG
# API Problem
# prior 10 days open 14.796920000000002
# close 15.85711
# change > 0.07, drop NRZ
# BPL has earning date, drop
# NSP has earning date, drop
# NUS has earning date, drop
# MMSI has earning date, drop
# CPA has earning date, drop
# TNET has earning date, drop
# FOXF has earning date, drop
# SRC has earning date, drop
# ENBL has earning date, drop
# ENV has earning date, drop
# prior 10 days open 71.04
# close 77.95
# change > 0.07, drop FSLR
# GNRC has earning date, drop
# prior 10 days open 39.76
# close 36.21
# change > 0.07, drop CRUS
# prior 10 days open 17.03
# close 13.03
# change > 0.07, drop FLEX
# HBI has earning date, drop
# PAYC has earning date, drop
# SABR has earning date, drop
# 2019-03-18 16:36:55.116962
# 2018-05-03
# COMM has earning date, drop
# prior 10 days open 14.4
# close 16.25
# change > 0.07, drop STAA
# UNM has earning date, drop
# XRAY has earning date, drop
# SSD has earning date, drop
# AIZ has earning date, drop
# THC has earning date, drop
# CCOI has earning date, drop
# API Problem
# prior 10 days open 203.2884
# close 185.3593
# change > 0.07, drop LFUS
# INGN has earning date, drop
# prior 10 days open 115.6781
# close 107.266
# change > 0.07, drop JBT
# CUBE has earning date, drop
# CCJ has earning date, drop
# APPF has earning date, drop
# IRWD has earning date, drop
# prior 10 days open 33.78179
# close 36.46117
# change > 0.07, drop TRNO
# MUSA has earning date, drop
# prior 10 days open 50.96
# close 58.4
# change > 0.07, drop FCN
# prior 10 days open 8.4
# close 9.77
# change > 0.07, drop I
# IDA has earning date, drop
# QTWO has earning date, drop
# AGCO has earning date, drop
# CZR has earning date, drop
# TDOC has earning date, drop
# VNOM has earning date, drop
# prior 10 days open 140.1393
# close 127.566
# change > 0.07, drop CW
# API Problem
# ARCC has earning date, drop
# prior 10 days open 39.73
# close 36.47
# change > 0.07, drop CRUS
# ALRM has earning date, drop
# NUS has earning date, drop
# RYN has earning date, drop
# SRC has earning date, drop
# NCR has earning date, drop
# DATA has earning date, drop
# prior 10 days open 21.68259
# close 19.92401
# change > 0.07, drop VVV
# GIL has earning date, drop
# prior 10 days open 14.867370000000001
# close 16.33598
# change > 0.07, drop UNIT
# VRNS has earning date, drop
# SABR has earning date, drop
# TWLO has earning date, drop
# LSI has earning date, drop
# CG has earning date, drop
# OMF has earning date, drop
# AMH has earning date, drop
# FCFS has earning date, drop
# EQC has earning date, drop
# BERY has earning date, drop
# prior 10 days open 50.949329999999996
# close 46.06855
# change > 0.07, drop CGNX
# THG has earning date, drop
# EXEL has earning date, drop
# 2019-03-18 16:37:03.781694
# 2018-05-04
# prior 10 days open 119.1126
# prior 10 days open 43.96
# close 47.35
# close 108.2616
# change > 0.07, drop SHAK
# change > 0.07, drop JBT
# prior 10 days open 141.006
# close 126.1413
# change > 0.07, drop CW
# XRAY has earning date, drop
# AIZ has earning date, drop
# QTWO has earning date, drop
# ZNGA has earning date, drop
# prior 10 days open 5.15
# close 5.55
# change > 0.07, drop P
# CCOI has earning date, drop
# HMSY has earning date, drop
# FLR has earning date, drop
# RYN has earning date, drop
# UNM has earning date, drop
# BKI has earning date, drop
# APPF has earning date, drop
# EPAY has earning date, drop
# prior 10 days open 29.80775
# close 32.06095
# change > 0.07, drop OMF
# NCR has earning date, drop
# BERY has earning date, drop
# PE has earning date, drop
# VNOM has earning date, drop
# GIL has earning date, drop
# CCJ has earning date, drop
# prior 10 days open 52.81
# close 48.28
# change > 0.07, drop CCK
# prior 10 days open 57.46131
# close 51.39255
# change > 0.07, drop EQM
# CRC has earning date, drop
# DATA has earning date, drop
# SRC has earning date, drop
# VRNS has earning date, drop
# UGI has earning date, drop
# prior 10 days open 532.514
# close 585.8993
# change > 0.07, drop TPL
# ARCC has earning date, drop
# CZR has earning date, drop
# ALRM has earning date, drop
# LSI has earning date, drop
# AKCA has earning date, drop
# prior 10 days open 24.18
# close 28.52
# change > 0.07, drop THC
# EXEL has earning date, drop
# TDOC has earning date, drop
# prior 10 days open 51.21
# close 58.82
# change > 0.07, drop FCN
# SAIL has earning date, drop
# WTS has earning date, drop
# DCP has earning date, drop
# PCH has earning date, drop
# IRTC has earning date, drop
# MED has earning date, drop
# prior 10 days open 15.1484
# close 16.27252
# change > 0.07, drop UNIT
# BPL has earning date, drop
# CG has earning date, drop
# PRA has earning date, drop
# RP has earning date, drop
# API Problem
# ITGR has earning date, drop
# SKT has earning date, drop
# prior 10 days open 40.05577
# close 35.82376
# change > 0.07, drop TEX
# 2019-03-18 16:37:12.743545
# 2018-05-07
# API Problem
# prior 10 days open 28.95
# close 26.72
# change > 0.07, drop TSEM
# prior 10 days open 15.55
# close 16.75
# change > 0.07, drop STAA
# prior 10 days open 43.74
# close 47.29
# change > 0.07, drop SHAK
# prior 10 days open 45.65
# close 49.8
# change > 0.07, drop MMSI
# RLGY has earning date, drop
# BKI has earning date, drop
# XRAY has earning date, drop
# API Problem
# QTWO has earning date, drop
# prior 10 days open 24.35
# close 26.22
# change > 0.07, drop CRC
# prior 10 days open 146.29
# close 126.89
# change > 0.07, drop ATHN
# HMSY has earning date, drop
# EPAY has earning date, drop
# WTS has earning date, drop
# RYN has earning date, drop
# JCOM has earning date, drop
# prior 10 days open 56.91293
# close 51.58448
# change > 0.07, drop EQM
# RP has earning date, drop
# FLR has earning date, drop
# API Problem
# PCTY has earning date, drop
# PRA has earning date, drop
# ZNGA has earning date, drop
# DATA has earning date, drop
# API Problem
# prior 10 days open 16.69134
# close 15.48681
# change > 0.07, drop COTY
# BERY has earning date, drop
# API Problem
# prior 10 days open 53.99
# close 47.44
# change > 0.07, drop CCK
# MED has earning date, drop
# ITGR has earning date, drop
# PE has earning date, drop
# BPL has earning date, drop
# prior 10 days open 128.137
# close 116.315
# change > 0.07, drop INGR
# prior 10 days open 104.8579
# close 90.07109
# change > 0.07, drop BMA
# prior 10 days open 51.2
# close 57.38
# change > 0.07, drop FCN
# PEN has earning date, drop
# PLNT has earning date, drop
# SAIL has earning date, drop
# prior 10 days open 65.39223
# close 59.5652
# change > 0.07, drop CUB
# IRTC has earning date, drop
# prior 10 days open 89.53
# close 99.02
# change > 0.07, drop ELLI
# prior 10 days open 39.91
# close 43.73
# change > 0.07, drop WLL
# prior 10 days open 29.833170000000003
# close 27.6175
# change > 0.07, drop LPX
# CRUS has earning date, drop
# DCP has earning date, drop
# PCH has earning date, drop
# CG has earning date, drop
# ZAYO has earning date, drop
# EXEL has earning date, drop
# ZG has earning date, drop
# prior 10 days open 79.2
# close 60.1
# change > 0.07, drop AXE
# CSOD has earning date, drop
# VRNS has earning date, drop
# prior 10 days open 8.496203
# close 7.798402
# change > 0.07, drop TKC
# REXR has earning date, drop
# prior 10 days open 540.081
# close 615.1159
# change > 0.07, drop TPL
# HLF has earning date, drop
# prior 10 days open 21.45761
# close 24.07199
# change > 0.07, drop STL
# GWPH has earning date, drop
# RARE has earning date, drop
# BRKR has earning date, drop
# AMN has earning date, drop
# prior 10 days open 16.1
# close 17.45
# change > 0.07, drop CVRR
# AKCA has earning date, drop
# 2019-03-18 16:37:23.997616
# 2018-05-08
# prior 10 days open 43.02
# close 47.41
# change > 0.07, drop SHAK
# prior 10 days open 30.48
# close 27.62
# change > 0.07, drop HAIN
# prior 10 days open 105.2659
# prior 10 days open 5.31
# close 87.11762
# close 5.75
# change > 0.07, drop BMA
# change > 0.07, drop P
# WTS has earning date, drop
# FLR has earning date, drop
# HMSY has earning date, drop
# TSEM has earning date, drop
# RLGY has earning date, drop
# BKI has earning date, drop
# prior 10 days open 147
# close 125.14
# change > 0.07, drop ATHN
# JCOM has earning date, drop
# ICLR has earning date, drop
# RP has earning date, drop
# CUB has earning date, drop
# CDEV has earning date, drop
# TREX has earning date, drop
# COTY has earning date, drop
# API Problem
# prior 10 days open 16.56198
# close 18.00692
# change > 0.07, drop KL
# API Problem
# prior 10 days open 46.63
# close 51.47
# change > 0.07, drop ZG
# prior 10 days open 90.48
# close 98.85
# change > 0.07, drop ELLI
# AMED has earning date, drop
# PCTY has earning date, drop
# MED has earning date, drop
# CBT has earning date, drop
# SEAS has earning date, drop
# PLNT has earning date, drop
# prior 10 days open 23.24
# close 25.79
# change > 0.07, drop CRC
# XRAY has earning date, drop
# prior 10 days open 66.15697
# close 71.89787
# change > 0.07, drop OGS
# EPAY has earning date, drop
# ZNGA has earning date, drop
# ITGR has earning date, drop
# CRZO has earning date, drop
# PE has earning date, drop
# DCP has earning date, drop
# prior 10 days open 29.57827
# close 27.19593
# change > 0.07, drop LPX
# prior 10 days open 32.13
# close 27.1
# change > 0.07, drop NCR
# CSOD has earning date, drop
# prior 10 days open 39.33
# close 44.23
# change > 0.07, drop WLL
# prior 10 days open 55.57853000000001
# close 50.51786
# change > 0.07, drop EQM
# RARE has earning date, drop
# RYN has earning date, drop
# API Problem
# ICUI has earning date, drop
# CCOI has earning date, drop
# CG has earning date, drop
# BID has earning date, drop
# API Problem
# USFD has earning date, drop
# PEN has earning date, drop
# BPL has earning date, drop
# DNR has earning date, drop
# prior 10 days open 16.05
# close 17.6
# change > 0.07, drop CVRR
# ZBRA has earning date, drop
# BRKR has earning date, drop
# AMN has earning date, drop
# WBT has earning date, drop
# CPE has earning date, drop
# ATHM has earning date, drop
# GWPH has earning date, drop
# prior 10 days open 50.82
# close 57.6
# change > 0.07, drop FCN
# WEN has earning date, drop
# prior 10 days open 15.4
# close 21.15
# change > 0.07, drop STAA
# OHI has earning date, drop
# UGI has earning date, drop
# 2019-03-18 16:37:33.016114
# 2018-05-09
# prior 10 days open 125.2
# close 134.7
# prior 10 days open 18.6
# change > 0.07, drop PEN
# prior 10 days open 89.87
# close 20.2
# change > 0.07, drop CRZO
# close 102.71
# prior 10 days open 16.27299
# close 18.624760000000002
# change > 0.07, drop ELLI
# change > 0.07, drop KL
# AMED has earning date, drop
# TWLO has earning date, drop
# ENV has earning date, drop
# ICLR has earning date, drop
# TREX has earning date, drop
# API Problem
# prior 10 days open 103.0022
# close 80.58891
# change > 0.07, drop BMA
# prior 10 days open 146.63
# close 126.08
# change > 0.07, drop ATHN
# XRAY has earning date, drop
# HAIN has earning date, drop
# CSOD has earning date, drop
# SEAS has earning date, drop
# JCOM has earning date, drop
# MIDD has earning date, drop
# CBT has earning date, drop
# RP has earning date, drop
# prior 10 days open 48.46
# close 53
# change > 0.07, drop ZG
# CUB has earning date, drop
# prior 10 days open 41.65
# close 38.53
# change > 0.07, drop TRIP
# prior 10 days open 3.09
# close 3.4
# change > 0.07, drop DNR
# CDEV has earning date, drop
# PLNT has earning date, drop
# ZBRA has earning date, drop
# COTY has earning date, drop
# TSEM has earning date, drop
# prior 10 days open 10.99129
# close 12.00496
# change > 0.07, drop PSO
# prior 10 days open 56.61
# close 49.34
# change > 0.07, drop BERY
# ICUI has earning date, drop
# API Problem
# USFD has earning date, drop
# prior 10 days open 39.11
# close 44.67
# change > 0.07, drop WLL
# API Problem
# prior 10 days open 31.64
# close 27.7
# change > 0.07, drop NCR
# GRPN has earning date, drop
# prior 10 days open 43.64
# close 55.95
# change > 0.07, drop SHAK
# prior 10 days open 14.70204
# close 16.04674
# change > 0.07, drop ARLP
# prior 10 days open 25.68264
# prior 10 days open 18.13
# close 27.64835
# close 19.46
# change > 0.07, drop BRKS
# change > 0.07, drop HMSY
# API Problem
# WEN has earning date, drop
# prior 10 days open 52.60199
# close 57.12761999999999
# change > 0.07, drop BKH
# KGC has earning date, drop
# AL has earning date, drop
# SINA has earning date, drop
# LPX has earning date, drop
# BID has earning date, drop
# prior 10 days open 56.58
# close 52.51
# change > 0.07, drop PAM
# CPE has earning date, drop
# RARE has earning date, drop
# prior 10 days open 23.319370000000003
# close 25.33754
# change > 0.07, drop OHI
# RGEN has earning date, drop
# AAXN has earning date, drop
# API Problem
# PRI has earning date, drop
# ZNGA has earning date, drop
# SBGI has earning date, drop
# YELP has earning date, drop
# ATHM has earning date, drop
# prior 10 days open 5.31
# close 6.89
# change > 0.07, drop P
# EPC has earning date, drop
# WWW has earning date, drop
# prior 10 days open 48.62
# close 53.65
# change > 0.07, drop ZEN
# prior 10 days open 124.76
# close 115.24
# change > 0.07, drop ESLT
# DLPH has earning date, drop
# prior 10 days open 48.85
# close 44.01
# change > 0.07, drop IONS
# ROKU has earning date, drop
# RYN has earning date, drop
# 2019-03-18 16:37:43.000620
# 2018-05-10
# API Problem
# prior 10 days open 42.79
# close 39.43
# change > 0.07, drop TRIP
# prior 10 days open 25.54435
# close 27.91505
# change > 0.07, drop BRKS
# PLNT has earning date, drop
# GDOT has earning date, drop
# TREX has earning date, drop
# WMGI has earning date, drop
# API Problem
# CDEV has earning date, drop
# TWLO has earning date, drop
# prior 10 days open 123.05
# close 139.1
# change > 0.07, drop PEN
# CSOD has earning date, drop
# AMED has earning date, drop
# YELP has earning date, drop
# MIDD has earning date, drop
# CBT has earning date, drop
# JCOM has earning date, drop
# GRPN has earning date, drop
# ROKU has earning date, drop
# prior 10 days open 56.54
# prior 10 days open 48.17
# close 50.51
# close 55.6
# change > 0.07, drop PAM
# change > 0.07, drop ZG
# AL has earning date, drop
# DNR has earning date, drop
# SINA has earning date, drop
# WWW has earning date, drop
# API Problem
# prior 10 days open 19.03
# close 20.4
# change > 0.07, drop CRZO
# API Problem
# prior 10 days open 102.7496
# close 78.71384
# change > 0.07, drop BMA
# SEAS has earning date, drop
# ZBRA has earning date, drop
# EPC has earning date, drop
# BIO has earning date, drop
# AAXN has earning date, drop
# HAIN has earning date, drop
# ACIW has earning date, drop
# prior 10 days open 54
# close 60.3
# change > 0.07, drop RP
# prior 10 days open 56.08
# close 49.14
# change > 0.07, drop BERY
# prior 10 days open 40
# close 45.05
# change > 0.07, drop WLL
# XRAY has earning date, drop
# KGC has earning date, drop
# HPT has earning date, drop
# MIME has earning date, drop
# COTY has earning date, drop
# ATHM has earning date, drop
# ICUI has earning date, drop
# PAAS has earning date, drop
# NUAN has earning date, drop
# AMCX has earning date, drop
# prior 10 days open 20.71
# close 22.58
# change > 0.07, drop PSTG
# prior 10 days open 19.70383
# close 21.80981
# change > 0.07, drop XHR
# prior 10 days open 43.03
# close 57.1
# change > 0.07, drop SHAK
# UBNT has earning date, drop
# CHH has earning date, drop
# SUPN has earning date, drop
# prior 10 days open 49.21
# close 54.03
# change > 0.07, drop ZEN
# TTD has earning date, drop
# QDEL has earning date, drop
# prior 10 days open 19.75
# close 21.75
# change > 0.07, drop EGHT
# SBGI has earning date, drop
# prior 10 days open 31.4
# close 28.35
# change > 0.07, drop NCR
# 2019-03-18 16:37:51.980649
# 2018-05-11
# prior 10 days open 117.8
# close 135.9
# change > 0.07, drop PEN
# prior 10 days open 40.54
# close 44.35
# change > 0.07, drop TWLO
# TTD has earning date, drop
# SUPN has earning date, drop
# ROKU has earning date, drop
# AAXN has earning date, drop
# GRPN has earning date, drop
# API Problem
# prior 10 days open 25.26776
# close 28.547240000000002
# change > 0.07, drop BRKS
# API Problem
# prior 10 days open 43.99
# close 47.59
# change > 0.07, drop YELP
# MIDD has earning date, drop
# BIO has earning date, drop
# prior 10 days open 41.87
# close 38.78
# change > 0.07, drop TRIP
# GDOT has earning date, drop
# PAAS has earning date, drop
# NUAN has earning date, drop
# prior 10 days open 43.9
# close 47.69
# change > 0.07, drop GLOB
# ACIW has earning date, drop
# prior 10 days open 56.72
# close 47.08
# change > 0.07, drop PAM
# NICE has earning date, drop
# prior 10 days open 93.02
# close 99.98
# change > 0.07, drop SINA
# DNR has earning date, drop
# HUBS has earning date, drop
# XON has earning date, drop
# KGC has earning date, drop
# prior 10 days open 71.38
# close 77.12
# change > 0.07, drop NEWR
# PFGC has earning date, drop
# PLNT has earning date, drop
# AMCX has earning date, drop
# API Problem
# CSOD has earning date, drop
# prior 10 days open 51.98
# close 58.76
# change > 0.07, drop TREX
# UBNT has earning date, drop
# prior 10 days open 2.75
# close 3.27
# change > 0.07, drop WFT
# prior 10 days open 27.85
# close 24.97
# change > 0.07, drop CVNA
# AL has earning date, drop
# prior 10 days open 25.06631
# close 27.023840000000003
# change > 0.07, drop CEQP
# prior 10 days open 37.99
# close 41.37
# change > 0.07, drop MIME
# API Problem
# ...
# close 6.73
# change > 0.07, drop ACB
# close 21.245
# prior 10 days open 62.13
# change > 0.07, drop TGE
# close 70.79
# change > 0.07, drop VSAT
# TRQ has earning date, drop
# USM has earning date, drop
# prior 10 days open 56.54
# close 63.55
# change > 0.07, drop RGEN
# WBT has earning date, drop
# JBGS has earning date, drop
# 2019-03-18 16:45:20.444205
# 2018-11-07
# prior 10 days open 81.52683
# close 87.66346999999999
# change > 0.07, drop ALLE
# JBGS has earning date, drop
# prior 10 days open 67.76
# close 74.32
# change > 0.07, drop TWLO
# prior 10 days open 61.28
# close 70.79
# change > 0.07, drop VSAT
# prior 10 days open 23.07709
# close 21.15689
# change > 0.07, drop TGE
# prior 10 days open 9.6989
# prior 10 days open 7.619984
# close 6.587096000000001
# close 7.02
# change > 0.07, drop BSMX
# change > 0.07, drop ACB
# ITRI has earning date, drop
# CNDT has earning date, drop
# WBT has earning date, drop
# prior 10 days open 1.82
# close 1.95
# change > 0.07, drop TRQ
# prior 10 days open 66.38398000000001
# close 61.3848
# change > 0.07, drop BG
# 2019-03-18 16:45:23.341837
# 2018-11-08
# API Problem
# API Problem
# prior 10 days open 22.93
# close 24.8
# change > 0.07, drop ARRS
# CNDT has earning date, drop
# SBH has earning date, drop
# prior 10 days open 66.99
# close 71.77
# change > 0.07, drop TWLO
# prior 10 days open 79.94542
# close 88.12098
# change > 0.07, drop ALLE
# TLND has earning date, drop
# API Problem
# API Problem
# CDK has earning date, drop
# prior 10 days open 76.65134
# close 82.44667
# change > 0.07, drop FCFS
# prior 10 days open 154.9837
# close 169.6576
# prior 10 days open 64.61
# change > 0.07, drop LANC
# PRGO has earning date, drop
# close 70.97
# change > 0.07, drop GHDX
# prior 10 days open 40.2207
# close 47.836220000000004
# change > 0.07, drop GVA
# 2019-03-18 16:45:26.770558
# 2018-11-09
# API Problem
# API Problem
# API Problem
# prior 10 days open 16.7
# close 18.93
# change > 0.07, drop SBH
# prior 10 days open 38.05
# close 45.44
# change > 0.07, drop IIVI
# prior 10 days open 157.345
# close 175.1839
# change > 0.07, drop LANC
# prior 10 days open 22.47
# close 24.97
# change > 0.07, drop ARRS
# CDK has earning date, drop
# TLND has earning date, drop
# TWLO has earning date, drop
# CNDT has earning date, drop
# ZAYO has earning date, drop
# prior 10 days open 81.88489
# close 88.62823
# change > 0.07, drop ALLE
# prior 10 days open 8.22
# close 7.4
# change > 0.07, drop ACB
# PRGO has earning date, drop
# XHR has earning date, drop
# CYBR has earning date, drop
# CLNY has earning date, drop
# LOPE has earning date, drop
# YELP has earning date, drop
# 2019-03-18 16:45:30.711213
# 2018-11-12
# API Problem
# API Problem
# prior 10 days open 16.85
# close 18.79
# change > 0.07, drop SBH
# prior 10 days open 164.0123
# close 176.0967
# change > 0.07, drop LANC
# prior 10 days open 24
# close 27.79
# change > 0.07, drop ARRS
# prior 10 days open 85.47794
# close 93.54471
# change > 0.07, drop UBNT
# prior 10 days open 36.01
# close 46.26
# change > 0.07, drop IIVI
# XHR has earning date, drop
# TLND has earning date, drop
# ZAYO has earning date, drop
# prior 10 days open 16.17
# close 17.93
# change > 0.07, drop FNSR
# prior 10 days open 41.18
# close 44.84
# change > 0.07, drop YELP
# prior 10 days open 49.53647
# close 53.89219
# change > 0.07, drop BPOP
# prior 10 days open 13.76949
# close 12.20135
# change > 0.07, drop ENLC
# prior 10 days open 7.08
# close 8.08
# change > 0.07, drop ACB
# PNW has earning date, drop
# 2019-03-18 16:45:33.664753
# 2018-11-13
# API Problem
# prior 10 days open 54.03
# close 58.32
# change > 0.07, drop LITE
# prior 10 days open 36.6
# close 46.88
# prior 10 days open 16.24
# prior 10 days open 85.89621
# change > 0.07, drop IIVI
# prior 10 days open 13.55814
# close 12.20135
# close 94.15221
# change > 0.07, drop ENLC
# change > 0.07, drop UBNT
# close 18.88
# change > 0.07, drop FNSR
# PNW has earning date, drop
# ADNT has earning date, drop
# prior 10 days open 192.53
# close 214.68
# change > 0.07, drop CVCO
# prior 10 days open 49.0019
# close 55.109809999999996
# change > 0.07, drop BPOP
# prior 10 days open 5.26
# close 5.94
# change > 0.07, drop BSTI
# YELP has earning date, drop
# UGI has earning date, drop
# 2019-03-18 16:45:36.843918
# 2018-11-14
# prior 10 days open 29.67
# close 32.09
# change > 0.07, drop HCM
# prior 10 days open 81.19176999999999
# close 87.72485
# change > 0.07, drop PNW
# UGI has earning date, drop
# 2019-03-18 16:45:41.326273
# 2018-11-15
# API Problem
# API Problem
# API Problem
# prior 10 days open 41.65
# close 45.98
# change > 0.07, drop BERY
# API Problem
# API Problem
# prior 10 days open 22.82463
# close 25.3195
# change > 0.07, drop COG
# prior 10 days open 50.566
# close 54.208969999999994
# change > 0.07, drop BPOP
# 2019-03-18 16:45:44.452468
# 2018-11-16
# prior 10 days open 76.4211
# close 83.12031999999999
# change > 0.07, drop LW
# prior 10 days open 38.27713
# close 41.12516
# change > 0.07, drop PNM
# prior 10 days open 77.51
# close 82.98
# change > 0.07, drop DORM
# BERY has earning date, drop
# API Problem
# ENR has earning date, drop
# prior 10 days open 24.33633
# close 26.41644
# change > 0.07, drop COG
# 2019-03-18 16:45:47.667688
# 2018-11-19
# API Problem
# prior 10 days open 58.88369
# prior 10 days open 37.94717
# close 63.11449
# close 41.37344
# change > 0.07, drop FFIN
# change > 0.07, drop PNM
# SR has earning date, drop
# prior 10 days open 35.94
# close 32.52
# change > 0.07, drop ARNA
# API Problem
# NJR has earning date, drop
# API Problem
# prior 10 days open 14.70607
# close 13.036430000000001
# change > 0.07, drop RES
# prior 10 days open 32.82
# close 37.69
# change > 0.07, drop HCM
# BERY has earning date, drop
# JWN has earning date, drop
# 2019-03-18 16:45:50.721813
# 2018-11-20
# API Problem
# prior 10 days open 44.75885
# close 48.010979999999996
# change > 0.07, drop NJR
# SR has earning date, drop
# prior 10 days open 14.33402
# close 13.3138
# change > 0.07, drop RES
# prior 10 days open 60.035740000000004
# close 64.74325999999999
# change > 0.07, drop FFIN
# JACK has earning date, drop
# 2019-03-18 16:45:54.749058
# 2018-11-21
# API Problem
# API Problem
# API Problem
# prior 10 days open 167.32
# close 155.1
# change > 0.07, drop ROLL
# prior 10 days open 61.1282
# close 65.56756999999999
# change > 0.07, drop FFIN
# prior 10 days open 44.798390000000005
# close 49.19717
# change > 0.07, drop NJR
# prior 10 days open 113.36
# close 123.32
# change > 0.07, drop CMPR
# API Problem
# prior 10 days open 30.17
# close 34.96
# change > 0.07, drop TSRO
# JACK has earning date, drop
# prior 10 days open 38.41
# close 41.68
# change > 0.07, drop ARNA
# prior 10 days open 44.40194
# close 47.87471
# change > 0.07, drop POR
# 2019-03-18 16:45:57.577672
# 2018-11-23
# API Problem
# prior 10 days open 37.52
# close 40.86
# change > 0.07, drop ARNA
# 2019-03-18 16:45:59.562796
# 2018-11-26
# 2019-03-18 16:46:01.534287
# 2018-11-27
# prior 10 days open 69.23917
# close 64.00059
# change > 0.07, drop CUB
# prior 10 days open 45
# close 38.77
# change > 0.07, drop BL
# 2019-03-18 16:46:03.623827
# 2018-11-28
# API Problem
# prior 10 days open 42.66
# close 38.85
# change > 0.07, drop BL
# prior 10 days open 24.019579999999998
# prior 10 days open 57.45
# close 25.70551
# change > 0.07, drop PHM
# close 50.73
# change > 0.07, drop ENV
# CBRL has earning date, drop
# prior 10 days open 39.759370000000004
# close 36.16928
# change > 0.07, drop PBF
# 2019-03-18 16:46:06.320283
# 2018-11-29
# prior 10 days open 23.43446
# close 25.97328
# change > 0.07, drop PHM
# TECD has earning date, drop
# CBRL has earning date, drop
# API Problem
# 2019-03-18 16:46:09.348935
# 2018-11-30
# API Problem
# API Problem
# prior 10 days open 53.24
# close 58.76
# change > 0.07, drop SAVE
# TECD has earning date, drop
# prior 10 days open 33.36785
# close 28.15588
# change > 0.07, drop BTU
# 2019-03-18 16:46:14.365588
# 2018-12-03
# prior 10 days open 28.99
# close 44.74
# change > 0.07, drop TSRO
# prior 10 days open 70.49
# close 76.24
# change > 0.07, drop OMCL
# prior 10 days open 103.07
# close 111.46
# change > 0.07, drop PRAH
# TECD has earning date, drop
# 2019-03-18 16:46:16.597999
# 2018-12-04
# prior 10 days open 26.1
# close 45.77
# change > 0.07, drop TSRO
# prior 10 days open 100.92
# close 113.88
# change > 0.07, drop PRAH
# AVYA has earning date, drop
# prior 10 days open 120.2031
# close 129.0498
# change > 0.07, drop MPWR
# 2019-03-18 16:46:19.133074
# 2018-12-06
# API Problem
# API Problem
# API Problem
# API Problem
# prior 10 days open 26.46
# close 46.38
# change > 0.07, drop TSRO
# 2019-03-18 16:46:21.149114
# 2018-12-07
# prior 10 days open 34.79359
# close 37.57669
# change > 0.07, drop OHI
# 2019-03-18 16:46:23.069779
# 2018-12-10
# API Problem
# API Problem
# API Problem
# prior 10 days open 34.705090000000006
# close 37.21282
# change > 0.07, drop OHI
# 2019-03-18 16:46:25.154888
# 2018-12-11
# API Problem
# prior 10 days open 19.02804
# close 22.47407
# change > 0.07, drop KL
# prior 10 days open 0.7
# close 0.53
# change > 0.07, drop WFT
# prior 10 days open 225.29
# close 261.92
# change > 0.07, drop TREE
# prior 10 days open 17.79
# close 21.1
# change > 0.07, drop EXEL
# 2019-03-18 16:46:27.786342
# 2018-12-12
# API Problem
# API Problem
# API Problem
# prior 10 days open 63.57151999999999
# close 55.010169999999995
# change > 0.07, drop CUB
# prior 10 days open 18.06
# close 20.54
# change > 0.07, drop EXEL
# prior 10 days open 19.477529999999998
# close 23.34307
# change > 0.07, drop KL
# prior 10 days open 10.21
# close 11.28
# change > 0.07, drop AU
# prior 10 days open 80.08659
# close 74.37462
# change > 0.07, drop CLB
# prior 10 days open 20.73367
# close 18.90481
# change > 0.07, drop JEF
# 2019-03-18 16:46:30.908601
# 2018-12-13
# API Problem
# prior 10 days open 64.82879
# close 55.499109999999995
# change > 0.07, drop CUB
# prior 10 days open 27.50753
# close 25.51077
# change > 0.07, drop TOWN
# prior 10 days open 79.4916
# close 72.49046
# change > 0.07, drop CLB
# prior 10 days open 124.3811
# close 112.46799999999999
# change > 0.07, drop NDSN
# prior 10 days open 19.52747
# close 23.77257
# change > 0.07, drop KL
# API Problem
# prior 10 days open 53.23
# close 48.94
# change > 0.07, drop THS
# prior 10 days open 10.12
# close 11.1
# change > 0.07, drop AU
# prior 10 days open 34.81351
# close 30.99488
# change > 0.07, drop APU
# CIEN has earning date, drop
# 2019-03-18 16:46:33.743983
# 2018-12-14
# API Problem
# prior 10 days open 27.477729999999998
# prior 10 days open 79.87835
# prior 10 days open 30.558629999999997
# close 25.322029999999998
# close 27.64971
# close 69.1089
# change > 0.07, drop TOWN
# change > 0.07, drop CLB
# change > 0.07, drop PPBI
# CIEN has earning date, drop
# API Problem
# prior 10 days open 9.91
# close 11.42
# change > 0.07, drop AU
# prior 10 days open 34.35385
# close 31.21633
# change > 0.07, drop UBSH
# prior 10 days open 36.46
# close 32.55
# change > 0.07, drop FLOW
# prior 10 days open 19.27776
# close 24.31195
# change > 0.07, drop KL
# prior 10 days open 44.015409999999996
# close 38.88028
# change > 0.07, drop PAG
# prior 10 days open 85.49466
# close 77.0153
# change > 0.07, drop CR
# 2019-03-18 16:46:36.965520
# 2018-12-17
# API Problem
# API Problem
# prior 10 days open 13.58
# close 15.26
# change > 0.07, drop BVN
# prior 10 days open 36.01
# close 32.88
# change > 0.07, drop FLOW
# prior 10 days open 17.55
# close 19.47
# change > 0.07, drop IMMU
# prior 10 days open 40.15
# close 43.96
# change > 0.07, drop ZGNX
# prior 10 days open 15.232679999999998
# close 16.65
# change > 0.07, drop WPM
# prior 10 days open 34.1652
# close 31.673059999999996
# prior 10 days open 13.0783
# prior 10 days open 2.931915
# change > 0.07, drop UBSH
# close 14.0881
# close 3.221117
# change > 0.07, drop ENBL
# change > 0.07, drop GFI
# prior 10 days open 83.90849
# close 77.81163000000001
# change > 0.07, drop CR
# CIEN has earning date, drop
# 2019-03-18 16:46:40.440410
# 2018-12-18
# API Problem
# prior 10 days open 14.15
# close 15.19
# change > 0.07, drop BVN
# prior 10 days open 40.42818
# close 37.2979
# change > 0.07, drop WOR
# prior 10 days open 10.27
# close 11.97
# change > 0.07, drop AU
# prior 10 days open 23.00848
# close 21.319329999999997
# change > 0.07, drop ERJ
# prior 10 days open 31.52
# close 25.45
# change > 0.07, drop NAV
# prior 10 days open 34.393570000000004
# close 30.6206
# change > 0.07, drop UBSH
# API Problem
# prior 10 days open 13.23516
# close 14.6077
# change > 0.07, drop ENBL
# prior 10 days open 26.53854
# close 24.435589999999998
# change > 0.07, drop XRX
# 2019-03-18 16:46:43.662040
# 2018-12-19
# prior 10 days open 31.45
# close 25.77
# change > 0.07, drop NAV
# prior 10 days open 10.1
# close 11.85
# change > 0.07, drop AU
# prior 10 days open 19.26127
# close 17.68713
# change > 0.07, drop MFGP
# prior 10 days open 40.329409999999996
# close 36.910309999999996
# change > 0.07, drop WOR
# prior 10 days open 25.86065
# prior 10 days open 31.0251
# close 25.75481
# close 23.28651
# change > 0.07, drop ABM
# change > 0.07, drop SABR
# prior 10 days open 2.99175
# close 3.211145
# change > 0.07, drop GFI
# API Problem
# prior 10 days open 42.43285
# close 33.9104
# change > 0.07, drop ABCB
# prior 10 days open 20.30657
# close 23.70265
# change > 0.07, drop KL
# 2019-03-18 16:46:46.802161
# 2018-12-20
# API Problem
# prior 10 days open 10.2
# close 12.11
# change > 0.07, drop AU
# prior 10 days open 32.74
# close 23.84
# change > 0.07, drop NAV
# prior 10 days open 2.981778
# close 3.300898
# prior 10 days open 31.88028
# change > 0.07, drop GFI
# close 25.79459
# change > 0.07, drop ABM
# prior 10 days open 2.79
# prior 10 days open 19.52526
# prior 10 days open 14.42
# close 16.79739
# change > 0.07, drop MFGP
# close 15.82
# change > 0.07, drop BVN
# prior 10 days open 40.47003
# prior 10 days open 11.32
# close 37.25419
# change > 0.07, drop QTS
# close 3.01
# close 10.49
# change > 0.07, drop KGC
# change > 0.07, drop FOLD
# prior 10 days open 25.28219
# close 20.42324
# change > 0.07, drop VET
# prior 10 days open 37.5
# close 29.23
# change > 0.07, drop EYE
# prior 10 days open 4.2103410000000006
# prior 10 days open 21.26546
# close 3.78335
# close 24.232039999999998
# change > 0.07, drop GGB
# change > 0.07, drop KL
# 2019-03-18 16:46:50.647735
# 2018-12-21
# API Problem
# prior 10 days open 2.99175
# close 3.360733
# change > 0.07, drop GFI
# prior 10 days open 66.50263000000001
# close 60.673790000000004
# change > 0.07, drop UMBF
# prior 10 days open 14.55
# prior 10 days open 10.88
# close 15.94
# prior 10 days open 24.87482
# close 10.04
# close 21.55818
# change > 0.07, drop BVN
# prior 10 days open 63.29342
# change > 0.07, drop FOLD
# change > 0.07, drop APAM
# prior 10 days open 30.81628
# prior 10 days open 4.170621
# close 55.12653
# close 26.908309999999997
# prior 10 days open 2.85
# close 3.8528599999999997
# change > 0.07, drop PRGO
# change > 0.07, drop ABM
# change > 0.07, drop GGB
# close 3.08
# change > 0.07, drop KGC
# prior 10 days open 79.22758
# close 61.244319999999995
# change > 0.07, drop LCII
# prior 10 days open 38.32
# close 29.07
# change > 0.07, drop EYE
# prior 10 days open 10.33
# close 12.48
# change > 0.07, drop AU
# 2019-03-18 16:46:53.672591
# 2018-12-24
# API Problem
# prior 10 days open 75.23252
# close 67.32445
# change > 0.07, drop VAC
# prior 10 days open 62.835280000000004
# close 53.523030000000006
# change > 0.07, drop PRGO
# 2019-03-18 16:46:55.722947
# 2018-12-26
# API Problem
# API Problem
# API Problem
# prior 10 days open 74.71825
# close 64.74654
# change > 0.07, drop VAC
# prior 10 days open 2.87
# close 3.14
# change > 0.07, drop KGC
# prior 10 days open 25.99669
# close 23.18545
# change > 0.07, drop HPT
# prior 10 days open 62.06839
# close 52.1486
# change > 0.07, drop PRGO
# prior 10 days open 3.131365
# close 3.410595
# change > 0.07, drop GFI
# 2019-03-18 16:46:57.475239
# 2018-12-27
# prior 10 days open 22.59364
# close 20.53078
# change > 0.07, drop VET
# prior 10 days open 71.68204
# close 62.22834
# change > 0.07, drop VAC
# prior 10 days open 25.683239999999998
# close 22.96995
# change > 0.07, drop HPT
# prior 10 days open 71.38
# close 81.03
# change > 0.07, drop PAC
# 2019-03-18 16:46:59.395043
# 2018-12-28
# prior 10 days open 71.42
# close 81.22
# change > 0.07, drop PAC
# prior 10 days open 14.239189999999999
# close 12.91577
# prior 10 days open 74.471
# close 61.043890000000005
# change > 0.07, drop DAN
# prior 10 days open 18.39109
# change > 0.07, drop VAC
# close 16.48452
# change > 0.07, drop MFGP
# prior 10 days open 18.85146
# close 16.52811
# change > 0.07, drop SHLX
# prior 10 days open 31.258290000000002
# close 27.89278
# change > 0.07, drop PWR
# 2019-03-18 16:47:02.035293
# 2018-12-31
# API Problem
# API Problem
# API Problem
# prior 10 days open 34.91
# close 39.22
# change > 0.07, drop OMAB
# prior 10 days open 18.47909
# close 17.01249
# change > 0.07, drop MFGP
# prior 10 days open 16.897270000000002
# close 14.937529999999999
# change > 0.07, drop KBR
# API Problem
# prior 10 days open 72.09742
# close 66.52818
# change > 0.07, drop VAC
# prior 10 days open 25.67585
# close 23.2055
# change > 0.07, drop FFBC
# prior 10 days open 125.8625
# close 103.5608
# change > 0.07, drop ALGT

# %%
url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'

# %%
mytest = pd.read_csv(url.format('AAPL', '2018-03-20', '2018-03-20'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6126b788d55c> in <module>
# ----> 1 mytest = pd.read_csv(url.format('AAPL', '2018-03-20', '2018-03-20'))
#
# NameError: name 'pd' is not defined

# %%
daterange2.index('2018-01-17')
# Out:
# 10

# %%
#back test for 1-business day strategy
for win in [1, 3]:#run 3 day window
    for date in daterange2:
        print(date)
        for cap in ['mid']:
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = daterange1[daterange1.index(date) + 1]
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            portfolio = list(portfolio['Symbol'])
            invest = 0
            revenue = 0
            for item in portfolio:
                flag = True
                while flag:
                    try:
                        price = pd.read_csv(url.format(item, trading_day, trading_day))
                        flag = False
                    except ConnectionResetError:
                        print('API problem')
                        continue
                invest += price.loc[0, 'open']
                revenue += price.loc[0, 'close']
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            result = pd.DataFrame([], columns = ['Date', 'invest', 'hold(days)', 'portfolio_value', 'p&l', 'pct_change(%)', 'window'])
            if invest != 0:
                result.loc[0, ['Date', 'invest', 'hold(days)', 'portfolio_value',\
                           'p&l', 'pct_change(%)', 'window']] = [trading_day, invest, 1, revenue, revenue-invest, (revenue/invest - 1)*100, win]
            if not os.path.exists(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_1_day/'.format(date, cap, win))):
                os.makedirs(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_1_day/'.format(date, cap, win)))
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_1_day/{}_{}_cap_window_{}_hold_1_pl.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#Generate trading detail for 1-business day
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['mid']:
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = daterange1[daterange1.index(date) + 1]
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            portfolio = list(portfolio['Symbol'])
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            result = pd.DataFrame([], columns = ['symbol', 'win_start', 'win_end', 'actual_pageview', 'average_pageview', \
                                                 'std_100days_rolling', 'actual_pageview_in_std', 'buy_date', 'sell_date', \
                                                 'buy_price', 'sell_price', 'p&l', 'pct_change(%)', 'window'])
            count = 0
            window_days = []
            while count < win:
                window_days.append(daterange1[daterange1.index(date) - count])
                count += 1
            window_days = window_days[::-1]
            win_start = window_days[0]
            win_end = window_days[-1]
            result['symbol'] = portfolio
            result['win_start'] = str(win_start)[:10]
            result['win_end'] = str(win_end)[:10]
            result['buy_date'] = trading_day
            result['sell_date'] = trading_day
            for i, item in enumerate(portfolio):
                try:
                    price = pd.read_csv(url.format(item, trading_day, trading_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'buy_price']= 'No Trading'
                    continue
                pageview_price = pd.read_csv('pageview_price/pageview_price_{}.csv'.format(item))
                temp = pageview_price['PageView']
                pageview_price['std_100days_rolling'] = (temp.rolling(100).std()).shift(win)
                pageview_price['mean_100days_rolling'] = (temp.rolling(100).mean()).shift(win)
                total_pageview = 0
                for each in window_days:
                    total_pageview += int(pageview_price.loc[pageview_price['Date'] == str(each)[:10]]['PageView'])
                result.loc[i, 'actual_pageview'] = total_pageview
                result.loc[i, 'average_pageview'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['mean_100days_rolling'])*win
                result.loc[i, 'std_100days_rolling'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['std_100days_rolling'])
                result.loc[i, 'actual_pageview_in_std'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['PageView_Change_in_Std_{}'.format(win)])
                result.loc[i, 'buy_price'] = price.loc[0, 'open']
                result.loc[i, 'sell_price'] = price.loc[0, 'close']
                result.loc[i, 'p&l'] = price.loc[0, 'close'] - price.loc[0, 'open']
                result.loc[i, 'pct_change(%)'] = (price.loc[0, 'close']/price.loc[0, 'open'] - 1)*100
                result.loc[i, 'window'] = win
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_1_day/{}_{}_cap_window_{}_hold_1_detail.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#to summary the 1-business day strategy results
for win in [1, 3]:
    for cap in ['mid']:
        to_combine = pd.DataFrame([])
        for date in daterange2:
            trading_day = daterange1[daterange1.index(date) + 1]
            each = trading_day
            each = each[5:]
            each = each.replace('-', '')
            try:
                temp = pd.read_csv('leaderlist {}/{}_cap/window_{}_day/hold_1_day/{}_{}_cap_window_{}_hold_1_pl.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                continue
            to_combine = pd.concat([to_combine, temp], sort = False, ignore_index = True)
        to_combine.loc['total_p&l', 'p&l'] = sum(to_combine.loc[to_combine['window'] == win]['p&l'])
        to_combine.loc['average_pct_change', 'pct_change(%)'] = to_combine['pct_change(%)'].mean()
        to_combine.loc['total_p&l', 'Date'] = 'Total_P&L'
        to_combine.loc['average_pct_change', 'Date'] = 'Average_Pct_Change'
        if not os.path.exists(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win))):
            os.makedirs(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win)))
        to_combine.to_csv('{}_cap/window_{}_day/{}_cap_window_{}_hold_1_pl_summary.csv'.format(cap, win, cap, win), index = False)

# %%
#back test for 3-business day strategy
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['mid']:
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = daterange1[daterange1.index(date) + 1]
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            portfolio = list(portfolio['Symbol'])
            invest = 0
            revenue = 0
            for item in portfolio:
                buy_price = pd.read_csv(url.format(item, trading_day, trading_day))
                invest += buy_price.loc[0, 'open']
                sell_day = datetime.datetime.strptime(daterange1[daterange1.index(trading_day) + 2], "%Y-%m-%d")
                flag = True
                while flag:
                    try:
                        sell_price = pd.read_csv(url.format(item, sell_day, sell_day))
                        flag = False
                    except ConnectionResetError:
                        print('API problem')
                        continue
                revenue += sell_price.loc[0, 'close']
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            result = pd.DataFrame([], columns = ['Date', 'invest', 'hold(days)', 'portfolio_value', 'p&l', 'pct_change(%)', 'window'])
            if invest != 0:
                result.loc[0, ['Date', 'invest', 'hold(days)', 'portfolio_value',\
                           'p&l', 'pct_change(%)', 'window']] = [trading_day, invest, 3, revenue, revenue-invest, (revenue/invest - 1)*100, win]
            if not os.path.exists(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_3_day/'.format(date, cap, win))):
                os.makedirs(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_3_day/'.format(date, cap, win)))
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_3_day/{}_{}_cap_window_{}_hold_3_pl.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
mytest = pd.read_csv(url.format('JW.B', '2018-06-08', '2018-06-12'))

# %%
#Generate trading detail for 3-business day
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['mid']:
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = daterange1[daterange1.index(date) + 1]
            portfolio = list(portfolio['Symbol'])
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            sell_day = datetime.datetime.strptime(daterange1[daterange1.index(trading_day) + 2], "%Y-%m-%d")
            result = pd.DataFrame([], columns = ['symbol', 'win_start', 'win_end', 'actual_pageview', 'average_pageview', \
                                                 'std_100days_rolling', 'actual_pageview_in_std', 'buy_date', 'sell_date', \
                                                 'buy_price', 'sell_price', 'p&l', 'pct_change(%)', 'window'])
            count = 0
            window_days = []
            while count < win:
                window_days.append(daterange1[daterange1.index(date) - count])
                count += 1
            window_days = window_days[::-1]
            win_start = window_days[0]
            win_end = window_days[-1]
            result['symbol'] = portfolio
            result['win_start'] = str(win_start)[:10]
            result['win_end'] = str(win_end)[:10]
            result['buy_date'] = trading_day
            result['sell_date'] = sell_day
            for i, item in enumerate(portfolio):
                try:
                    buy = pd.read_csv(url.format(item, trading_day, trading_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'buy_price'] = 'No Trading'
                    continue
                try:
                    sell = pd.read_csv(url.format(item, sell_day, sell_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'sell_price'] = 'No Trading'
                    continue
                pageview_price = pd.read_csv('pageview_price/pageview_price_{}.csv'.format(item))
                temp = pageview_price['PageView']
                pageview_price['std_100days_rolling'] = (temp.rolling(100).std()).shift(win)
                pageview_price['mean_100days_rolling'] = (temp.rolling(100).mean()).shift(win)
                total_pageview = 0
                for each in window_days:
                    total_pageview += int(pageview_price.loc[pageview_price['Date'] == str(each)[:10]]['PageView'])
                result.loc[i, 'actual_pageview'] = total_pageview
                result.loc[i, 'average_pageview'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['mean_100days_rolling'])*win
                result.loc[i, 'std_100days_rolling'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['std_100days_rolling'])
                result.loc[i, 'actual_pageview_in_std'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['PageView_Change_in_Std_{}'.format(win)])
                result.loc[i, 'buy_price'] = buy.loc[0, 'open']
                result.loc[i, 'sell_price'] = sell.loc[0, 'close']
                result.loc[i, 'p&l'] = sell.loc[0, 'close'] - buy.loc[0, 'open']
                result.loc[i, 'pct_change(%)'] = (sell.loc[0, 'close']/buy.loc[0, 'open'] - 1)*100
                result.loc[i, 'window'] = win
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_3_day/{}_{}_cap_window_{}_hold_3_detail.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#to summary the 3-business day strategy results
for win in [1, 3]:
    for cap in ['mid']:
        to_combine = pd.DataFrame([])
        for date in daterange2:
            trading_day = daterange1[daterange1.index(date) + 1]
            each = trading_day
            each = each[5:]
            each = each.replace('-', '')
            try:
                temp = pd.read_csv('leaderlist {}/{}_cap/window_{}_day/hold_3_day/{}_{}_cap_window_{}_hold_3_pl.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                continue
            to_combine = pd.concat([to_combine, temp], sort = False, ignore_index = True)   
        to_combine.loc['total_p&l', 'p&l'] = sum(to_combine.loc[to_combine['window'] == win]['p&l'])
        to_combine.loc['average_pct_change', 'pct_change(%)'] = to_combine['pct_change(%)'].mean()
        to_combine.loc['total_p&l', 'Date'] = 'Total_P&L'
        to_combine.loc['average_pct_change', 'Date'] = 'Average_Pct_Change'
        if not os.path.exists(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win))):
            os.makedirs(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win)))
        to_combine.to_csv('{}_cap/window_{}_day/{}_cap_window_{}_hold_3_pl_summary.csv'.format(cap, win, cap, win), index = False)

# %%
#back test for buy close, hold one day, and sell close price tomorrow
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['mid']:
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = date
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            portfolio = list(portfolio['Symbol'])
            invest = 0
            portfolio_value = 0
            for item in portfolio:
                buy_price = pd.read_csv(url.format(item, trading_day, trading_day))
                invest += buy_price.loc[0, 'close']
                sell_day = daterange1[daterange1.index(trading_day) + 1]
                flag = True
                while flag:
                    try:
                        sell_price = pd.read_csv(url.format(item, sell_day, sell_day))
                        flag = False
                    except ConnectionResetError:
                        print('API Problem')
                        continue
                portfolio_value += sell_price.loc[0, 'close']
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            result = pd.DataFrame([], columns = ['Date', 'invest', 'hold(days)', 'portfolio_value', 'p&l', 'pct_change(%)', 'window'])
            if invest != 0:
                result.loc[0, ['Date', 'invest', 'hold(days)', 'portfolio_value',\
                           'p&l', 'pct_change(%)', 'window']] = [trading_day, invest, 1, portfolio_value, portfolio_value-invest, (portfolio_value/invest - 1)*100, win]
            if not os.path.exists(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/'.format(date, cap, win))):
                os.makedirs(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/'.format(date, cap, win)))
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/{}_{}_cap_window_{}_hold_1b_pl.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#Generate trading detail for today close to next day close
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['mid']:
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = date
            portfolio = list(portfolio['Symbol'])
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            sell_day = daterange1[daterange1.index(trading_day) + 1]
            result = pd.DataFrame([], columns = ['symbol', 'win_start', 'win_end', 'actual_pageview', 'average_pageview', \
                                                 'std_100days_rolling', 'actual_pageview_in_std', 'buy_date', 'sell_date', \
                                                 'buy_price', 'sell_price', 'p&l', 'pct_change(%)', 'window'])
            temp_win_date = datetime.datetime.strptime(date, "%Y-%m-%d")
            window_days = []
            count = 0
            while count < win:
                window_days.append(daterange1[daterange1.index(date) - count])
                count += 1
            window_days = window_days[::-1]
            win_start = window_days[0]
            win_end = window_days[-1]
            result['symbol'] = portfolio
            result['win_start'] = str(win_start)[:10]
            result['win_end'] = str(win_end)[:10]
            result['buy_date'] = trading_day
            result['sell_date'] = sell_day
            for i, item in enumerate(portfolio):
                try:
                    buy = pd.read_csv(url.format(item, trading_day, trading_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'buy_price'] == 'No Trading'
                    continue
                try:
                    sell = pd.read_csv(url.format(item, sell_day, sell_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'sell_price'] == 'No Trading'
                    continue
                price = pd.read_csv(url.format(item, trading_day, sell_day))
                pageview_price = pd.read_csv('pageview_price/pageview_price_{}.csv'.format(item))
                temp = pageview_price['PageView']
                pageview_price['std_100days_rolling'] = (temp.rolling(100).std()).shift(win)
                pageview_price['mean_100days_rolling'] = (temp.rolling(100).mean()).shift(win)
                total_pageview = 0
                for each in window_days:
                    total_pageview += int(pageview_price.loc[pageview_price['Date'] == str(each)[:10]]['PageView'])
                result.loc[i, 'actual_pageview'] = total_pageview
                result.loc[i, 'average_pageview'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['mean_100days_rolling'])*win
                result.loc[i, 'std_100days_rolling'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['std_100days_rolling'])
                result.loc[i, 'actual_pageview_in_std'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['PageView_Change_in_Std_{}'.format(win)])
                result.loc[i, 'buy_price'] = price.loc[0, 'close']
                result.loc[i, 'sell_price'] = price.loc[1, 'close']
                result.loc[i, 'p&l'] = price.loc[1, 'close'] - price.loc[0, 'close']
                result.loc[i, 'pct_change(%)'] = (price.loc[1, 'close']/price.loc[0, 'close'] - 1)*100
                result.loc[i, 'window'] = win
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/{}_{}_cap_window_{}_hold_1b_detail.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#to summary the today's close to next close strategy results
for win in [1, 3]:
    for cap in ['mid']:
        to_combine = pd.DataFrame([])
        for date in daterange2:
            trading_day = date
            each = trading_day
            each = each[5:]
            each = each.replace('-', '')
            try:
                temp = pd.read_csv('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/{}_{}_cap_window_{}_hold_1b_pl.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                continue
            to_combine = pd.concat([to_combine, temp], sort = False, ignore_index = True)   
        to_combine.loc['total_p&l', 'p&l'] = sum(to_combine.loc[to_combine['window'] == win]['p&l'])
        to_combine.loc['average_pct_change', 'pct_change(%)'] = to_combine['pct_change(%)'].mean()
        to_combine.loc['total_p&l', 'Date'] = 'Total_P&L'
        to_combine.loc['average_pct_change', 'Date'] = 'Average_Pct_Change'
        if not os.path.exists(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win))):
            os.makedirs(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win)))
        to_combine.to_csv('{}_cap/window_{}_day/{}_cap_window_{}_hold_1b_pl_summary.csv'.format(cap, win, cap, win), index = False)
