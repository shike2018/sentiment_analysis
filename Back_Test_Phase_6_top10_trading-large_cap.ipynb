# %%
import numpy as np
import pandas as pd
import seaborn as sb
import io
import requests
import datetime
import ondemand
from scipy.stats import pearsonr
from pandas.io.common import EmptyDataError
from requests.exceptions import HTTPError
import time
import os
import json
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from multiprocessing import Pool as ThreadPool
from multiprocessing import Manager
class Generate_Leaders():
    def __init__(self): 
        self.pageview_change = dict()
        self.my_date = None
    def get_mkt_cap(self, symbol, start_date, end_date):
        file = pd.read_csv('Highest_change_total.csv')
        try:
            mktcap = float(file.loc[file['Symbol'] == symbol]['Market_Cap(billion)'])
        except:
            return
        return mktcap
    def parallel(self, item):
        try:
            pageview_price = pd.read_csv('pageview_price/pageview_price_{}.csv'.format(item.lower()))
        except FileNotFoundError:
            print('{} has no pageview data!!!'.format(item))
            return
        if pageview_price.empty:
            return
        #print(datetime.datetime.now())
        temp_res = pageview_price.set_index(['Date'])
        try:
            temp_res = temp_res.loc[[self.my_date]]
            temp_res.reset_index(col_fill = 'Date', inplace = True)
        except:
            print('{} has no trading on {}!!!'.format(item, self.my_date))
            return
        if temp_res.loc[0, 'PageView'] < 10:
            print('{} pageview on {} less than 10, skip it.'.format(item, self.my_date))
            return
        temp_res.loc[0, 'Market_Cap(billion)'] = self.get_mkt_cap(item, self.my_date, self.my_date)
        if temp_res['Market_Cap(billion)'].isnull().values.any():
            pass
        else:
            temp_res['Market_Cap(billion)'] = temp_res['Market_Cap(billion)'].round(2)
        self.pageview_change[item] = temp_res 
    def highest_change(self, my_date):
        largecap = pd.read_csv('large_cap_symbols.csv')
        symbols = list(largecap['Symbol'])
        self.my_date = my_date
        for i, item in enumerate(symbols):
            if i % 300 == 0:
                print('run well')
                print(i)
            self.parallel(item)

# %%
largecap = pd.read_csv('large_cap_symbols.csv')
all_symbols = list(largecap['Symbol'])

# %%
#Generate highest change for each day
for i, date in enumerate(daterange):
    print(i)
    print(date)
    leader = Generate_Leaders()
    highest_change = leader.highest_change(date)
    to_combine = pd.DataFrame([])
    for item in all_symbols:
        try:
            temp = leader.pageview_change[item]
        except:
            continue
        to_combine = pd.concat([to_combine, temp], sort = False, ignore_index = True)
    if not os.path.exists(os.path.dirname('leaderlist {}/'.format(date))):
        os.makedirs(os.path.dirname('leaderlist {}/'.format(date)))
    if to_combine.empty:
        print('{} is not trading day!!!'.format(date))
        continue
    highest_change_window1 = to_combine.drop(['PageView_Change_in_Std_3'], axis = 1)
    highest_change_window1['Time_Window'] = 1
    highest_change_window1.sort_values(by = ['PageView_Change_in_Std_1'], ascending = False, inplace = True)
    highest_change_window3 = to_combine.drop(['PageView_Change_in_Std_1'], axis = 1)
    highest_change_window3['Time_Window'] = 3
    highest_change_window3.sort_values(by = ['PageView_Change_in_Std_3'], ascending = False, inplace = True)
    if not os.path.exists(os.path.dirname('leaderlist {}/large_cap/window_{}_day/'.format(date, 1))):
        os.makedirs(os.path.dirname('leaderlist {}/large_cap/window_{}_day/'.format(date, 1)))
    if not os.path.exists(os.path.dirname('leaderlist {}/large_cap/window_{}_day/'.format(date, 3))):
        os.makedirs(os.path.dirname('leaderlist {}/large_cap/window_{}_day/'.format(date, 3)))    
    highest_change_window1.to_csv('leaderlist {}/large_cap/window_1_day/large_cap_highest_change_time_window_1.csv'.format(date), index = False)
    highest_change_window3.to_csv('leaderlist {}/large_cap/window_3_day/large_cap_highest_change_time_window_3.csv'.format(date), index = False)
# Out:
# 0
# 2018-01-01
# run well
# 0
# SRE has no trading on 2018-01-01!!!
# BSX has no trading on 2018-01-01!!!
# LDOS has no trading on 2018-01-01!!!
# BBVA has no trading on 2018-01-01!!!
# EMN has no trading on 2018-01-01!!!
# PTC has no trading on 2018-01-01!!!
# ZTS has no trading on 2018-01-01!!!
# WCG has no trading on 2018-01-01!!!
# PCG has no trading on 2018-01-01!!!
# DTE has no trading on 2018-01-01!!!
# DGX has no trading on 2018-01-01!!!
# APH has no trading on 2018-01-01!!!
# FOX has no trading on 2018-01-01!!!
# DVA has no trading on 2018-01-01!!!
# UN has no trading on 2018-01-01!!!
# AEP has no trading on 2018-01-01!!!
# EFX has no trading on 2018-01-01!!!
# SHG has no trading on 2018-01-01!!!
# TRGP has no trading on 2018-01-01!!!
# JNPR has no trading on 2018-01-01!!!
# LH has no trading on 2018-01-01!!!
# MDLZ has no trading on 2018-01-01!!!
# ED has no trading on 2018-01-01!!!
# AON has no trading on 2018-01-01!!!
# NVS has no trading on 2018-01-01!!!
# XEL has no trading on 2018-01-01!!!
# WEC has no trading on 2018-01-01!!!
# CCI has no trading on 2018-01-01!!!
# XLNX has no trading on 2018-01-01!!!
# APD has no trading on 2018-01-01!!!
# GRFS has no trading on 2018-01-01!!!
# FOXA has no trading on 2018-01-01!!!
# MCHP has no trading on 2018-01-01!!!
# IR has no trading on 2018-01-01!!!
# EA has no trading on 2018-01-01!!!
# FDX has no trading on 2018-01-01!!!
# AGN has no trading on 2018-01-01!!!
# O has no trading on 2018-01-01!!!
# DAL has no trading on 2018-01-01!!!
# LRCX has no trading on 2018-01-01!!!
# NSC has no trading on 2018-01-01!!!
# FDC has no trading on 2018-01-01!!!
# UNH has no trading on 2018-01-01!!!
# NEE has no trading on 2018-01-01!!!
# APA has no trading on 2018-01-01!!!
# EQNR has no pageview data!!!
# REG has no trading on 2018-01-01!!!
# BF.A has no trading on 2018-01-01!!!
# MELI has no trading on 2018-01-01!!!
# HPQ has no trading on 2018-01-01!!!
# ROK has no trading on 2018-01-01!!!
# DLR has no trading on 2018-01-01!!!
# BMO has no trading on 2018-01-01!!!
# ENB has no trading on 2018-01-01!!!
# SNA has no trading on 2018-01-01!!!
# KHC has no trading on 2018-01-01!!!
# MKL has no trading on 2018-01-01!!!
# SIVB has no trading on 2018-01-01!!!
# FCAU has no trading on 2018-01-01!!!
# NKTR has no trading on 2018-01-01!!!
# SYK has no trading on 2018-01-01!!!
# TSN has no trading on 2018-01-01!!!
# AMD has no trading on 2018-01-01!!!
# DHR has no trading on 2018-01-01!!!
# ROP has no trading on 2018-01-01!!!
# DUK has no trading on 2018-01-01!!!
# LVS has no trading on 2018-01-01!!!
# COO has no trading on 2018-01-01!!!
# TJX has no trading on 2018-01-01!!!
# BX has no trading on 2018-01-01!!!
# CGC has no pageview data!!!
# TEVA has no trading on 2018-01-01!!!
# ATVI has no trading on 2018-01-01!!!
# ADBE has no trading on 2018-01-01!!!
# ANTM has no trading on 2018-01-01!!!
# ICE has no trading on 2018-01-01!!!
# AMP has no trading on 2018-01-01!!!
# DVN has no trading on 2018-01-01!!!
# A has no trading on 2018-01-01!!!
# HD has no trading on 2018-01-01!!!
# TEF has no trading on 2018-01-01!!!
# ODFL has no trading on 2018-01-01!!!
# BGNE has no trading on 2018-01-01!!!
# EVRG has no pageview data!!!
# GM has no trading on 2018-01-01!!!
# TSLA has no trading on 2018-01-01!!!
# MTN has no trading on 2018-01-01!!!
# KKR has no trading on 2018-01-01!!!
# TRU has no trading on 2018-01-01!!!
# ANSS has no trading on 2018-01-01!!!
# MNST has no trading on 2018-01-01!!!
# ISRG has no trading on 2018-01-01!!!
# PAYX has no trading on 2018-01-01!!!
# COP has no trading on 2018-01-01!!!
# PM has no trading on 2018-01-01!!!
# MGM has no trading on 2018-01-01!!!
# PGR has no trading on 2018-01-01!!!
# SCCO has no trading on 2018-01-01!!!
# MRK has no trading on 2018-01-01!!!
# AVGO has no trading on 2018-01-01!!!
# LUV has no trading on 2018-01-01!!!
# LLL has no trading on 2018-01-01!!!
# IX has no trading on 2018-01-01!!!
# KO has no trading on 2018-01-01!!!
# CPRT has no trading on 2018-01-01!!!
# ADM has no trading on 2018-01-01!!!
# DB has no trading on 2018-01-01!!!
# SJM has no trading on 2018-01-01!!!
# TAL has no trading on 2018-01-01!!!
# AAL has no trading on 2018-01-01!!!
# HCA has no trading on 2018-01-01!!!
# DPZ has no trading on 2018-01-01!!!
# ALGN has no trading on 2018-01-01!!!
# BIIB has no trading on 2018-01-01!!!
# SAP has no trading on 2018-01-01!!!
# CM has no trading on 2018-01-01!!!
# INCY has no trading on 2018-01-01!!!
# AKAM has no trading on 2018-01-01!!!
# TSCO has no trading on 2018-01-01!!!
# XPO has no trading on 2018-01-01!!!
# BBD has no trading on 2018-01-01!!!
# CLR has no trading on 2018-01-01!!!
# BR has no trading on 2018-01-01!!!
# RHT has no trading on 2018-01-01!!!
# VZ has no trading on 2018-01-01!!!
# COF has no trading on 2018-01-01!!!
# JNJ has no trading on 2018-01-01!!!
# CNA has no trading on 2018-01-01!!!
# TWTR has no trading on 2018-01-01!!!
# ABMD has no trading on 2018-01-01!!!
# CTL has no trading on 2018-01-01!!!
# LYG has no trading on 2018-01-01!!!
# SGEN has no trading on 2018-01-01!!!
# SHW has no trading on 2018-01-01!!!
# AMAT has no trading on 2018-01-01!!!
# STM has no trading on 2018-01-01!!!
# HFC has no trading on 2018-01-01!!!
# AAP has no trading on 2018-01-01!!!
# GIS has no trading on 2018-01-01!!!
# HRL has no trading on 2018-01-01!!!
# MCD has no trading on 2018-01-01!!!
# FCX has no trading on 2018-01-01!!!
# DEO has no trading on 2018-01-01!!!
# PG has no trading on 2018-01-01!!!
# CPB has no trading on 2018-01-01!!!
# FISV has no trading on 2018-01-01!!!
# AIG has no trading on 2018-01-01!!!
# NOW has no trading on 2018-01-01!!!
# UAL has no trading on 2018-01-01!!!
# QCOM has no trading on 2018-01-01!!!
# BP has no trading on 2018-01-01!!!
# CVX has no trading on 2018-01-01!!!
# T has no trading on 2018-01-01!!!
# CSX has no trading on 2018-01-01!!!
# UBS has no trading on 2018-01-01!!!
# CBRE has no pageview data!!!
# AMT has no trading on 2018-01-01!!!
# BEN has no trading on 2018-01-01!!!
# PBR.A has no trading on 2018-01-01!!!
# CNC has no trading on 2018-01-01!!!
# KR has no trading on 2018-01-01!!!
# CTRP has no trading on 2018-01-01!!!
# KMI has no trading on 2018-01-01!!!
# PPL has no trading on 2018-01-01!!!
# LLY has no trading on 2018-01-01!!!
# EW has no trading on 2018-01-01!!!
# RCL has no trading on 2018-01-01!!!
# ACN has no trading on 2018-01-01!!!
# F has no trading on 2018-01-01!!!
# AEE has no trading on 2018-01-01!!!
# DXCM has no trading on 2018-01-01!!!
# LN has no trading on 2018-01-01!!!
# ITUB has no trading on 2018-01-01!!!
# IP has no trading on 2018-01-01!!!
# STZ has no trading on 2018-01-01!!!
# E has no trading on 2018-01-01!!!
# TS has no trading on 2018-01-01!!!
# CMI has no trading on 2018-01-01!!!
# MMC has no trading on 2018-01-01!!!
# W has no trading on 2018-01-01!!!
# BIP has no trading on 2018-01-01!!!
# NTR has no pageview data!!!
# ES has no trading on 2018-01-01!!!
# FNV has no trading on 2018-01-01!!!
# BCS has no trading on 2018-01-01!!!
# COST has no trading on 2018-01-01!!!
# KMX has no trading on 2018-01-01!!!
# SU has no trading on 2018-01-01!!!
# PKX has no trading on 2018-01-01!!!
# MRVL has no trading on 2018-01-01!!!
# SPGI has no trading on 2018-01-01!!!
# PEP has no trading on 2018-01-01!!!
# CVS has no trading on 2018-01-01!!!
# RELX has no trading on 2018-01-01!!!
# SHOP has no trading on 2018-01-01!!!
# ROST has no trading on 2018-01-01!!!
# NLY has no trading on 2018-01-01!!!
# CB has no trading on 2018-01-01!!!
# ABEV has no trading on 2018-01-01!!!
# MO has no trading on 2018-01-01!!!
# WBA has no trading on 2018-01-01!!!
# GOOGL has no trading on 2018-01-01!!!
# HSBC has no trading on 2018-01-01!!!
# MPLX has no trading on 2018-01-01!!!
# CXO has no trading on 2018-01-01!!!
# NXPI has no trading on 2018-01-01!!!
# JBHT has no trading on 2018-01-01!!!
# INTU has no trading on 2018-01-01!!!
# HUM has no trading on 2018-01-01!!!
# VNO has no trading on 2018-01-01!!!
# CF has no trading on 2018-01-01!!!
# GD has no trading on 2018-01-01!!!
# DISCK has no trading on 2018-01-01!!!
# JAZZ has no trading on 2018-01-01!!!
# TTM has no trading on 2018-01-01!!!
# BUD has no trading on 2018-01-01!!!
# RIO has no trading on 2018-01-01!!!
# YUMC has no trading on 2018-01-01!!!
# CUK has no trading on 2018-01-01!!!
# CME has no trading on 2018-01-01!!!
# ZBH has no trading on 2018-01-01!!!
# KSU has no trading on 2018-01-01!!!
# MU has no trading on 2018-01-01!!!
# TGT has no trading on 2018-01-01!!!
# EPD has no trading on 2018-01-01!!!
# TD has no trading on 2018-01-01!!!
# ADSK has no trading on 2018-01-01!!!
# PANW has no trading on 2018-01-01!!!
# JD has no trading on 2018-01-01!!!
# BAC has no trading on 2018-01-01!!!
# CRM has no trading on 2018-01-01!!!
# BAK has no trading on 2018-01-01!!!
# EXPD has no trading on 2018-01-01!!!
# APTV has no trading on 2018-01-01!!!
# VOD has no trading on 2018-01-01!!!
# CTAS has no trading on 2018-01-01!!!
# PTR has no trading on 2018-01-01!!!
# WLK has no trading on 2018-01-01!!!
# DFS has no trading on 2018-01-01!!!
# SLF has no trading on 2018-01-01!!!
# CINF has no trading on 2018-01-01!!!
# WB has no trading on 2018-01-01!!!
# WDAY has no trading on 2018-01-01!!!
# SNPS has no trading on 2018-01-01!!!
# WELL has no pageview data!!!
# TPR has no trading on 2018-01-01!!!
# FTI has no trading on 2018-01-01!!!
# AGR has no trading on 2018-01-01!!!
# LFC has no trading on 2018-01-01!!!
# EQIX has no trading on 2018-01-01!!!
# SSL has no trading on 2018-01-01!!!
# ORAN has no trading on 2018-01-01!!!
# XOM has no trading on 2018-01-01!!!
# DG has no trading on 2018-01-01!!!
# BNS has no trading on 2018-01-01!!!
# CHKP has no trading on 2018-01-01!!!
# UNP has no trading on 2018-01-01!!!
# WYNN has no trading on 2018-01-01!!!
# HLT has no trading on 2018-01-01!!!
# PBR has no trading on 2018-01-01!!!
# PFE has no trading on 2018-01-01!!!
# NFLX has no trading on 2018-01-01!!!
# BMY has no trading on 2018-01-01!!!
# AMX has no trading on 2018-01-01!!!
# TEL has no trading on 2018-01-01!!!
# CS has no trading on 2018-01-01!!!
# AVB has no trading on 2018-01-01!!!
# NTES has no trading on 2018-01-01!!!
# HCP has no trading on 2018-01-01!!!
# VLO has no trading on 2018-01-01!!!
# M has no trading on 2018-01-01!!!
# CX has no trading on 2018-01-01!!!
# NUE has no trading on 2018-01-01!!!
# YUM has no trading on 2018-01-01!!!
# DISCA has no trading on 2018-01-01!!!
# ARE has no trading on 2018-01-01!!!
# CSCO has no trading on 2018-01-01!!!
# CDW has no trading on 2018-01-01!!!
# MA has no trading on 2018-01-01!!!
# TMO has no trading on 2018-01-01!!!
# ILMN has no trading on 2018-01-01!!!
# ATH has no trading on 2018-01-01!!!
# HAL has no trading on 2018-01-01!!!
# IDXX has no trading on 2018-01-01!!!
# CP has no trading on 2018-01-01!!!
# SNAP has no trading on 2018-01-01!!!
# URI has no trading on 2018-01-01!!!
# BBL has no trading on 2018-01-01!!!
# NRG has no trading on 2018-01-01!!!
# AZO has no trading on 2018-01-01!!!
# MKC has no trading on 2018-01-01!!!
# MLCO has no trading on 2018-01-01!!!
# V has no trading on 2018-01-01!!!
# AAPL has no trading on 2018-01-01!!!
# FTS has no trading on 2018-01-01!!!
# D has no trading on 2018-01-01!!!
# CCL has no trading on 2018-01-01!!!
# BIDU has no trading on 2018-01-01!!!
# IBM has no trading on 2018-01-01!!!
# CAG has no trading on 2018-01-01!!!
# run well
# 300
# VRSN has no trading on 2018-01-01!!!
# UDR has no trading on 2018-01-01!!!
# PAA has no trading on 2018-01-01!!!
# SO has no trading on 2018-01-01!!!
# HIG has no trading on 2018-01-01!!!
# PKI has no trading on 2018-01-01!!!
# SBUX has no trading on 2018-01-01!!!
# USB has no trading on 2018-01-01!!!
# BBY has no trading on 2018-01-01!!!
# CLX has no trading on 2018-01-01!!!
# EDU has no trading on 2018-01-01!!!
# DHI has no trading on 2018-01-01!!!
# FRC has no trading on 2018-01-01!!!
# EXPE has no trading on 2018-01-01!!!
# YNDX has no trading on 2018-01-01!!!
# MUFG has no pageview data!!!
# AFL has no trading on 2018-01-01!!!
# VALE has no trading on 2018-01-01!!!
# BABA has no trading on 2018-01-01!!!
# SSNC has no trading on 2018-01-01!!!
# VMC has no trading on 2018-01-01!!!
# IFF has no trading on 2018-01-01!!!
# DIS has no trading on 2018-01-01!!!
# MTCH has no trading on 2018-01-01!!!
# CMS has no trading on 2018-01-01!!!
# MSFT has no trading on 2018-01-01!!!
# ETN has no trading on 2018-01-01!!!
# HBAN has no trading on 2018-01-01!!!
# GWW has no trading on 2018-01-01!!!
# MGA has no trading on 2018-01-01!!!
# BKNG has no pageview data!!!
# ALLY has no trading on 2018-01-01!!!
# BF.B has no trading on 2018-01-01!!!
# LOW has no trading on 2018-01-01!!!
# SKM has no trading on 2018-01-01!!!
# SNN has no trading on 2018-01-01!!!
# NGG has no trading on 2018-01-01!!!
# STI has no trading on 2018-01-01!!!
# UPS has no trading on 2018-01-01!!!
# PVH has no trading on 2018-01-01!!!
# PYPL has no trading on 2018-01-01!!!
# ABC has no trading on 2018-01-01!!!
# MSI has no trading on 2018-01-01!!!
# JPM has no trading on 2018-01-01!!!
# INTC has no trading on 2018-01-01!!!
# ITW has no trading on 2018-01-01!!!
# ORCL has no trading on 2018-01-01!!!
# JKHY has no trading on 2018-01-01!!!
# OXY has no trading on 2018-01-01!!!
# NVO has no trading on 2018-01-01!!!
# LYB has no trading on 2018-01-01!!!
# KSS has no trading on 2018-01-01!!!
# NCLH has no trading on 2018-01-01!!!
# SIRI has no trading on 2018-01-01!!!
# VIV has no trading on 2018-01-01!!!
# HST has no trading on 2018-01-01!!!
# CSGP has no trading on 2018-01-01!!!
# RBS has no trading on 2018-01-01!!!
# NBL has no trading on 2018-01-01!!!
# ARNC has no trading on 2018-01-01!!!
# AMZN has no trading on 2018-01-01!!!
# C has no trading on 2018-01-01!!!
# AABA has no trading on 2018-01-01!!!
# K has no trading on 2018-01-01!!!
# ATUS has no trading on 2018-01-01!!!
# INFO has no trading on 2018-01-01!!!
# SQM has no trading on 2018-01-01!!!
# CTXS has no trading on 2018-01-01!!!
# TFX has no trading on 2018-01-01!!!
# LBRDA has no trading on 2018-01-01!!!
# ORLY has no trading on 2018-01-01!!!
# CHD has no trading on 2018-01-01!!!
# MFC has no trading on 2018-01-01!!!
# CMG has no trading on 2018-01-01!!!
# RSG has no trading on 2018-01-01!!!
# PFG has no trading on 2018-01-01!!!
# IEF has no trading on 2018-01-01!!!
# MTD has no trading on 2018-01-01!!!
# MT has no trading on 2018-01-01!!!
# AJG has no trading on 2018-01-01!!!
# TTWO has no trading on 2018-01-01!!!
# RL has no trading on 2018-01-01!!!
# SWKS has no trading on 2018-01-01!!!
# TV has no trading on 2018-01-01!!!
# SQ has no trading on 2018-01-01!!!
# NMR has no trading on 2018-01-01!!!
# AWK has no trading on 2018-01-01!!!
# KB has no trading on 2018-01-01!!!
# MMM has no trading on 2018-01-01!!!
# TSS has no trading on 2018-01-01!!!
# DLTR has no trading on 2018-01-01!!!
# STX has no trading on 2018-01-01!!!
# CBS has no trading on 2018-01-01!!!
# HSY has no trading on 2018-01-01!!!
# CELG has no trading on 2018-01-01!!!
# ADP has no trading on 2018-01-01!!!
# RACE has no trading on 2018-01-01!!!
# PRU has no trading on 2018-01-01!!!
# BMRN has no trading on 2018-01-01!!!
# VST has no trading on 2018-01-01!!!
# SNY has no trading on 2018-01-01!!!
# ABBV has no trading on 2018-01-01!!!
# LULU has no trading on 2018-01-01!!!
# TMUS has no trading on 2018-01-01!!!
# MDT has no trading on 2018-01-01!!!
# FMC has no trading on 2018-01-01!!!
# GRUB has no trading on 2018-01-01!!!
# TAP has no trading on 2018-01-01!!!
# GRMN has no trading on 2018-01-01!!!
# PXD has no trading on 2018-01-01!!!
# TRI has no trading on 2018-01-01!!!
# GE has no trading on 2018-01-01!!!
# WDC has no trading on 2018-01-01!!!
# WIT has no trading on 2018-01-01!!!
# TIF has no trading on 2018-01-01!!!
# HEI has no trading on 2018-01-01!!!
# DWDP has no trading on 2018-01-01!!!
# SLB has no trading on 2018-01-01!!!
# EC has no trading on 2018-01-01!!!
# LKQ has no trading on 2018-01-01!!!
# ADI has no trading on 2018-01-01!!!
# VIA has no trading on 2018-01-01!!!
# EXC has no trading on 2018-01-01!!!
# GPS has no trading on 2018-01-01!!!
# VIAB has no trading on 2018-01-01!!!
# NVDA has no trading on 2018-01-01!!!
# NTAP has no trading on 2018-01-01!!!
# HON has no trading on 2018-01-01!!!
# LNC has no trading on 2018-01-01!!!
# FIS has no trading on 2018-01-01!!!
# VFC has no trading on 2018-01-01!!!
# EMR has no trading on 2018-01-01!!!
# RMD has no trading on 2018-01-01!!!
# ULTI has no trading on 2018-01-01!!!
# UTX has no trading on 2018-01-01!!!
# MET has no trading on 2018-01-01!!!
# TDG has no trading on 2018-01-01!!!
# MRO has no trading on 2018-01-01!!!
# BBT has no trading on 2018-01-01!!!
# BA has no trading on 2018-01-01!!!
# CI has no trading on 2018-01-01!!!
# TU has no trading on 2018-01-01!!!
# BT has no trading on 2018-01-01!!!
# ECA has no trading on 2018-01-01!!!
# BAX has no trading on 2018-01-01!!!
# JCI has no trading on 2018-01-01!!!
# CHTR has no trading on 2018-01-01!!!
# GPC has no trading on 2018-01-01!!!
# IAC has no trading on 2018-01-01!!!
# SAN has no trading on 2018-01-01!!!
# WAB has no trading on 2018-01-01!!!
# FITB has no trading on 2018-01-01!!!
# SBAC has no trading on 2018-01-01!!!
# WFC has no trading on 2018-01-01!!!
# TRMB has no trading on 2018-01-01!!!
# FMX has no trading on 2018-01-01!!!
# MAA has no trading on 2018-01-01!!!
# FTNT has no trading on 2018-01-01!!!
# CEO has no trading on 2018-01-01!!!
# BXP has no trading on 2018-01-01!!!
# VRSK has no trading on 2018-01-01!!!
# WMT has no trading on 2018-01-01!!!
# LSXMA has no trading on 2018-01-01!!!
# MHK has no trading on 2018-01-01!!!
# TRV has no trading on 2018-01-01!!!
# HPE has no trading on 2018-01-01!!!
# SYY has no trading on 2018-01-01!!!
# HII has no trading on 2018-01-01!!!
# CFG has no trading on 2018-01-01!!!
# INFY has no trading on 2018-01-01!!!
# HDB has no trading on 2018-01-01!!!
# TXN has no trading on 2018-01-01!!!
# MYL has no trading on 2018-01-01!!!
# LBRDK has no trading on 2018-01-01!!!
# CAH has no trading on 2018-01-01!!!
# SYMC has no trading on 2018-01-01!!!
# SNE has no trading on 2018-01-01!!!
# FB has no trading on 2018-01-01!!!
# SRPT has no trading on 2018-01-01!!!
# ARMK has no trading on 2018-01-01!!!
# LEN has no trading on 2018-01-01!!!
# EL has no trading on 2018-01-01!!!
# BK has no trading on 2018-01-01!!!
# IEX has no trading on 2018-01-01!!!
# BAM has no trading on 2018-01-01!!!
# CMCSA has no trading on 2018-01-01!!!
# WUBA has no trading on 2018-01-01!!!
# WPP has no trading on 2018-01-01!!!
# BCE has no trading on 2018-01-01!!!
# ACWI has no trading on 2018-01-01!!!
# BDX has no trading on 2018-01-01!!!
# KEYS has no trading on 2018-01-01!!!
# PLD has no trading on 2018-01-01!!!
# MS has no trading on 2018-01-01!!!
# MLM has no trading on 2018-01-01!!!
# EIX has no trading on 2018-01-01!!!
# EBAY has no trading on 2018-01-01!!!
# BSAC has no trading on 2018-01-01!!!
# GILD has no trading on 2018-01-01!!!
# MPC has no trading on 2018-01-01!!!
# ANDX has no trading on 2018-01-01!!!
# CDNS has no trading on 2018-01-01!!!
# CNP has no trading on 2018-01-01!!!
# L has no trading on 2018-01-01!!!
# AMGN has no trading on 2018-01-01!!!
# EXR has no trading on 2018-01-01!!!
# SPG has no trading on 2018-01-01!!!
# SWK has no trading on 2018-01-01!!!
# KMB has no trading on 2018-01-01!!!
# NOC has no trading on 2018-01-01!!!
# STT has no trading on 2018-01-01!!!
# HAS has no trading on 2018-01-01!!!
# WY has no trading on 2018-01-01!!!
# PCAR has no trading on 2018-01-01!!!
# NOK has no trading on 2018-01-01!!!
# RDS.A has no trading on 2018-01-01!!!
# WMB has no trading on 2018-01-01!!!
# ALL has no trading on 2018-01-01!!!
# TEAM has no trading on 2018-01-01!!!
# ERIC has no trading on 2018-01-01!!!
# MBB has no trading on 2018-01-01!!!
# TSM has no trading on 2018-01-01!!!
# TM has no trading on 2018-01-01!!!
# IXUS has no trading on 2018-01-01!!!
# PFF has no trading on 2018-01-01!!!
# PPG has no trading on 2018-01-01!!!
# ING has no trading on 2018-01-01!!!
# SMFG has no trading on 2018-01-01!!!
# BHP has no trading on 2018-01-01!!!
# IQV has no trading on 2018-01-01!!!
# TROW has no trading on 2018-01-01!!!
# BTI has no trading on 2018-01-01!!!
# ALXN has no trading on 2018-01-01!!!
# FANG has no trading on 2018-01-01!!!
# FLT has no trading on 2018-01-01!!!
# BURL has no trading on 2018-01-01!!!
# VRTX has no trading on 2018-01-01!!!
# NKE has no trading on 2018-01-01!!!
# SCZ has no trading on 2018-01-01!!!
# SCHW has no trading on 2018-01-01!!!
# SHV has no trading on 2018-01-01!!!
# S has no trading on 2018-01-01!!!
# GOOG has no trading on 2018-01-01!!!
# HSIC has no trading on 2018-01-01!!!
# ABT has no trading on 2018-01-01!!!
# CHT has no trading on 2018-01-01!!!
# PUK has no trading on 2018-01-01!!!
# LBTYK has no trading on 2018-01-01!!!
# EMB has no trading on 2018-01-01!!!
# IEP has no trading on 2018-01-01!!!
# VCSH has no trading on 2018-01-01!!!
# CL has no trading on 2018-01-01!!!
# ASML has no trading on 2018-01-01!!!
# LEN.B has no trading on 2018-01-01!!!
# DVY has no trading on 2018-01-01!!!
# HOLX has no trading on 2018-01-01!!!
# OMC has no trading on 2018-01-01!!!
# VAR has no trading on 2018-01-01!!!
# BSBR has no trading on 2018-01-01!!!
# RY has no trading on 2018-01-01!!!
# CVE has no trading on 2018-01-01!!!
# AME has no trading on 2018-01-01!!!
# WP has no pageview data!!!
# KEP has no trading on 2018-01-01!!!
# ESS has no trading on 2018-01-01!!!
# KLAC has no trading on 2018-01-01!!!
# GPN has no trading on 2018-01-01!!!
# RCI has no trading on 2018-01-01!!!
# ANGI has no trading on 2018-01-01!!!
# BLL has no trading on 2018-01-01!!!
# TXT has no trading on 2018-01-01!!!
# RTN has no trading on 2018-01-01!!!
# TI has no trading on 2018-01-01!!!
# QSR has no trading on 2018-01-01!!!
# REGN has no trading on 2018-01-01!!!
# CHA has no trading on 2018-01-01!!!
# BLK has no trading on 2018-01-01!!!
# AMTD has no trading on 2018-01-01!!!
# IT has no trading on 2018-01-01!!!
# DISH has no trading on 2018-01-01!!!
# MAS has no trading on 2018-01-01!!!
# CERN has no trading on 2018-01-01!!!
# CAT has no trading on 2018-01-01!!!
# VCIT has no trading on 2018-01-01!!!
# BRK.B has no trading on 2018-01-01!!!
# AEG has no trading on 2018-01-01!!!
# CBS.A has no trading on 2018-01-01!!!
# SYF has no trading on 2018-01-01!!!
# LYV has no trading on 2018-01-01!!!
# STZ.B has no trading on 2018-01-01!!!
# GS has no trading on 2018-01-01!!!
# OTEX has no trading on 2018-01-01!!!
# PKG has no trading on 2018-01-01!!!
# PHG has no trading on 2018-01-01!!!
# MTB has no trading on 2018-01-01!!!
# DRI has no trading on 2018-01-01!!!
# INVH has no trading on 2018-01-01!!!
# IBN has no trading on 2018-01-01!!!
# JEC has no trading on 2018-01-01!!!
# EQT has no trading on 2018-01-01!!!
# run well
# 600
# AXP has no trading on 2018-01-01!!!
# IHG has no trading on 2018-01-01!!!
# ANET has no trading on 2018-01-01!!!
# BBDO has no trading on 2018-01-01!!!
# WAT has no trading on 2018-01-01!!!
# VMW has no trading on 2018-01-01!!!
# CTSH has no trading on 2018-01-01!!!
# CMA has no trading on 2018-01-01!!!
# GIB has no trading on 2018-01-01!!!
# FTV has no trading on 2018-01-01!!!
# LMT has no trading on 2018-01-01!!!
# EQR has no trading on 2018-01-01!!!
# RDS.B has no trading on 2018-01-01!!!
# BAP has no trading on 2018-01-01!!!
# DXC has no trading on 2018-01-01!!!
# UHS has no trading on 2018-01-01!!!
# LBTYA has no trading on 2018-01-01!!!
# SHY has no trading on 2018-01-01!!!
# TOT has no trading on 2018-01-01!!!
# FMS has no trading on 2018-01-01!!!
# EOG has no trading on 2018-01-01!!!
# CNI has no trading on 2018-01-01!!!
# CAJ has no trading on 2018-01-01!!!
# GLW has no trading on 2018-01-01!!!
# MFG has no trading on 2018-01-01!!!
# MAR has no trading on 2018-01-01!!!
# ABB has no trading on 2018-01-01!!!
# PSX has no trading on 2018-01-01!!!
# ADS has no trading on 2018-01-01!!!
# PEG has no trading on 2018-01-01!!!
# AZN has no trading on 2018-01-01!!!
# BHGE has no trading on 2018-01-01!!!
# FFIV has no trading on 2018-01-01!!!
# ULTA has no trading on 2018-01-01!!!
# GDDY has no trading on 2018-01-01!!!
# SPLK has no trading on 2018-01-01!!!
# SNP has no trading on 2018-01-01!!!
# NDAQ has no trading on 2018-01-01!!!
# FNF has no trading on 2018-01-01!!!
# MCO has no trading on 2018-01-01!!!
# DOV has no trading on 2018-01-01!!!
# HRS has no trading on 2018-01-01!!!
# VEEV has no trading on 2018-01-01!!!
# KEY has no trading on 2018-01-01!!!
# BND has no trading on 2018-01-01!!!
# ATO has no trading on 2018-01-01!!!
# QQQ has no trading on 2018-01-01!!!
# CE has no trading on 2018-01-01!!!
# RJF has no trading on 2018-01-01!!!
# VXUS has no trading on 2018-01-01!!!
# ETR has no trading on 2018-01-01!!!
# ACGL has no trading on 2018-01-01!!!
# MXIM has no trading on 2018-01-01!!!
# APC has no trading on 2018-01-01!!!
# WRK has no trading on 2018-01-01!!!
# WBK has no trading on 2018-01-01!!!
# WLTW has no trading on 2018-01-01!!!
# PBA has no trading on 2018-01-01!!!
# RF has no trading on 2018-01-01!!!
# HMC has no trading on 2018-01-01!!!
# UL has no trading on 2018-01-01!!!
# CNHI has no trading on 2018-01-01!!!
# RYAAY has no trading on 2018-01-01!!!
# NTRS has no trading on 2018-01-01!!!
# CRH has no trading on 2018-01-01!!!
# FE has no trading on 2018-01-01!!!
# NEM has no trading on 2018-01-01!!!
# NBIX has no trading on 2018-01-01!!!
# ETFC has no trading on 2018-01-01!!!
# BNDX has no trading on 2018-01-01!!!
# TECK has no trading on 2018-01-01!!!
# TLK has no trading on 2018-01-01!!!
# PH has no trading on 2018-01-01!!!
# KOF has no trading on 2018-01-01!!!
# WCN has no trading on 2018-01-01!!!
# WPC has no trading on 2018-01-01!!!
# ALB has no trading on 2018-01-01!!!
# VTR has no trading on 2018-01-01!!!
# ECL has no trading on 2018-01-01!!!
# ASX has no trading on 2018-01-01!!!
# TRP has no trading on 2018-01-01!!!
# MMP has no trading on 2018-01-01!!!
# HES has no trading on 2018-01-01!!!
# STLD has no trading on 2018-01-01!!!
# FAST has no trading on 2018-01-01!!!
# PNC has no trading on 2018-01-01!!!
# DE has no trading on 2018-01-01!!!
# NOV has no trading on 2018-01-01!!!
# MCK has no trading on 2018-01-01!!!
# XYL has no trading on 2018-01-01!!!
# ROL has no trading on 2018-01-01!!!
# CHU has no trading on 2018-01-01!!!
# BRK.A has no trading on 2018-01-01!!!
# GSK has no trading on 2018-01-01!!!
# OKE has no trading on 2018-01-01!!!
# CNQ has no trading on 2018-01-01!!!
# MOS has no trading on 2018-01-01!!!
# WM has no trading on 2018-01-01!!!
# PSA has no trading on 2018-01-01!!!
# BCH has no trading on 2018-01-01!!!
# MSCI has no trading on 2018-01-01!!!
# CHRW has no trading on 2018-01-01!!!
# CHL has no trading on 2018-01-01!!!
# GOLD has no trading on 2018-01-01!!!
# CCEP has no pageview data!!!
# EQH has no pageview data!!!
# ET has no trading on 2018-01-01!!!
# KDP has no pageview data!!!
# SPOT has no pageview data!!!
# SUZ has no pageview data!!!
# TAK has no pageview data!!!
# DBX has no pageview data!!!
# IGSB has no pageview data!!!
# IQ has no pageview data!!!
# 2018-01-01 is not trading day!!!
# 1
# 2018-01-02
# run well
# 0
# SRE pageview on 2018-01-02 less than 10, skip it.
# LDOS pageview on 2018-01-02 less than 10, skip it.
# EMN pageview on 2018-01-02 less than 10, skip it.
# PTC pageview on 2018-01-02 less than 10, skip it.
# WCG pageview on 2018-01-02 less than 10, skip it.
# DTE pageview on 2018-01-02 less than 10, skip it.
# FOX pageview on 2018-01-02 less than 10, skip it.
# EFX pageview on 2018-01-02 less than 10, skip it.
# SHG pageview on 2018-01-02 less than 10, skip it.
# LH pageview on 2018-01-02 less than 10, skip it.
# WEC pageview on 2018-01-02 less than 10, skip it.
# EQNR has no pageview data!!!
# REG pageview on 2018-01-02 less than 10, skip it.
# BF.A pageview on 2018-01-02 less than 10, skip it.
# SNA pageview on 2018-01-02 less than 10, skip it.
# SIVB pageview on 2018-01-02 less than 10, skip it.
# ROP pageview on 2018-01-02 less than 10, skip it.
# COO pageview on 2018-01-02 less than 10, skip it.
# CGC has no pageview data!!!
# ODFL pageview on 2018-01-02 less than 10, skip it.
# EVRG has no pageview data!!!
# TRU pageview on 2018-01-02 less than 10, skip it.
# ANSS pageview on 2018-01-02 less than 10, skip it.
# IX pageview on 2018-01-02 less than 10, skip it.
# SAP pageview on 2018-01-02 less than 10, skip it.
# BBD pageview on 2018-01-02 less than 10, skip it.
# CNA pageview on 2018-01-02 less than 10, skip it.
# FISV pageview on 2018-01-02 less than 10, skip it.
# CBRE has no pageview data!!!
# DXCM pageview on 2018-01-02 less than 10, skip it.
# LN pageview on 2018-01-02 less than 10, skip it.
# TS pageview on 2018-01-02 less than 10, skip it.
# NTR has no pageview data!!!
# RELX pageview on 2018-01-02 less than 10, skip it.
# NXPI pageview on 2018-01-02 less than 10, skip it.
# VNO pageview on 2018-01-02 less than 10, skip it.
# JAZZ pageview on 2018-01-02 less than 10, skip it.
# YUMC pageview on 2018-01-02 less than 10, skip it.
# CUK pageview on 2018-01-02 less than 10, skip it.
# EXPD pageview on 2018-01-02 less than 10, skip it.
# PTR pageview on 2018-01-02 less than 10, skip it.
# SLF pageview on 2018-01-02 less than 10, skip it.
# CINF pageview on 2018-01-02 less than 10, skip it.
# SNPS pageview on 2018-01-02 less than 10, skip it.
# WELL has no pageview data!!!
# AGR pageview on 2018-01-02 less than 10, skip it.
# LFC pageview on 2018-01-02 less than 10, skip it.
# EQIX pageview on 2018-01-02 less than 10, skip it.
# SSL pageview on 2018-01-02 less than 10, skip it.
# ORAN pageview on 2018-01-02 less than 10, skip it.
# CHKP pageview on 2018-01-02 less than 10, skip it.
# AMX pageview on 2018-01-02 less than 10, skip it.
# ARE pageview on 2018-01-02 less than 10, skip it.
# CDW pageview on 2018-01-02 less than 10, skip it.
# ATH pageview on 2018-01-02 less than 10, skip it.
# FTS pageview on 2018-01-02 less than 10, skip it.
# run well
# 300
# UDR pageview on 2018-01-02 less than 10, skip it.
# HIG pageview on 2018-01-02 less than 10, skip it.
# MUFG has no pageview data!!!
# SSNC pageview on 2018-01-02 less than 10, skip it.
# IFF pageview on 2018-01-02 less than 10, skip it.
# BKNG has no pageview data!!!
# SKM pageview on 2018-01-02 less than 10, skip it.
# SNN pageview on 2018-01-02 less than 10, skip it.
# NGG pageview on 2018-01-02 less than 10, skip it.
# JKHY pageview on 2018-01-02 less than 10, skip it.
# LYB pageview on 2018-01-02 less than 10, skip it.
# NCLH pageview on 2018-01-02 less than 10, skip it.
# VIV pageview on 2018-01-02 less than 10, skip it.
# CSGP pageview on 2018-01-02 less than 10, skip it.
# RBS pageview on 2018-01-02 less than 10, skip it.
# INFO pageview on 2018-01-02 less than 10, skip it.
# TFX pageview on 2018-01-02 less than 10, skip it.
# LBRDA pageview on 2018-01-02 less than 10, skip it.
# CHD pageview on 2018-01-02 less than 10, skip it.
# MFC pageview on 2018-01-02 less than 10, skip it.
# RSG pageview on 2018-01-02 less than 10, skip it.
# PFG pageview on 2018-01-02 less than 10, skip it.
# IEF pageview on 2018-01-02 less than 10, skip it.
# MTD pageview on 2018-01-02 less than 10, skip it.
# AJG pageview on 2018-01-02 less than 10, skip it.
# TV pageview on 2018-01-02 less than 10, skip it.
# NMR pageview on 2018-01-02 less than 10, skip it.
# KB pageview on 2018-01-02 less than 10, skip it.
# TSS pageview on 2018-01-02 less than 10, skip it.
# BMRN pageview on 2018-01-02 less than 10, skip it.
# TRI pageview on 2018-01-02 less than 10, skip it.
# WIT pageview on 2018-01-02 less than 10, skip it.
# NTAP pageview on 2018-01-02 less than 10, skip it.
# LNC pageview on 2018-01-02 less than 10, skip it.
# FIS pageview on 2018-01-02 less than 10, skip it.
# RMD pageview on 2018-01-02 less than 10, skip it.
# ULTI pageview on 2018-01-02 less than 10, skip it.
# TDG pageview on 2018-01-02 less than 10, skip it.
# TU pageview on 2018-01-02 less than 10, skip it.
# GPC pageview on 2018-01-02 less than 10, skip it.
# WAB pageview on 2018-01-02 less than 10, skip it.
# TRMB pageview on 2018-01-02 less than 10, skip it.
# FMX pageview on 2018-01-02 less than 10, skip it.
# MAA pageview on 2018-01-02 less than 10, skip it.
# BXP pageview on 2018-01-02 less than 10, skip it.
# VRSK pageview on 2018-01-02 less than 10, skip it.
# LSXMA pageview on 2018-01-02 less than 10, skip it.
# CFG pageview on 2018-01-02 less than 10, skip it.
# LBRDK pageview on 2018-01-02 less than 10, skip it.
# ARMK pageview on 2018-01-02 less than 10, skip it.
# IEX pageview on 2018-01-02 less than 10, skip it.
# BAM pageview on 2018-01-02 less than 10, skip it.
# WPP pageview on 2018-01-02 less than 10, skip it.
# BCE pageview on 2018-01-02 less than 10, skip it.
# ACWI pageview on 2018-01-02 less than 10, skip it.
# KEYS pageview on 2018-01-02 less than 10, skip it.
# PLD pageview on 2018-01-02 less than 10, skip it.
# BSAC pageview on 2018-01-02 less than 10, skip it.
# ANDX pageview on 2018-01-02 less than 10, skip it.
# EXR pageview on 2018-01-02 less than 10, skip it.
# MBB pageview on 2018-01-02 less than 10, skip it.
# IXUS pageview on 2018-01-02 less than 10, skip it.
# PFF pageview on 2018-01-02 less than 10, skip it.
# ING pageview on 2018-01-02 less than 10, skip it.
# SMFG pageview on 2018-01-02 less than 10, skip it.
# SCZ pageview on 2018-01-02 less than 10, skip it.
# SHV pageview on 2018-01-02 less than 10, skip it.
# PUK pageview on 2018-01-02 less than 10, skip it.
# LBTYK pageview on 2018-01-02 less than 10, skip it.
# EMB pageview on 2018-01-02 less than 10, skip it.
# VCSH pageview on 2018-01-02 less than 10, skip it.
# LEN.B pageview on 2018-01-02 less than 10, skip it.
# DVY pageview on 2018-01-02 less than 10, skip it.
# VAR pageview on 2018-01-02 less than 10, skip it.
# WP has no pageview data!!!
# KEP pageview on 2018-01-02 less than 10, skip it.
# ESS pageview on 2018-01-02 less than 10, skip it.
# GPN pageview on 2018-01-02 less than 10, skip it.
# RCI pageview on 2018-01-02 less than 10, skip it.
# TI pageview on 2018-01-02 less than 10, skip it.
# CHA pageview on 2018-01-02 less than 10, skip it.
# IT pageview on 2018-01-02 less than 10, skip it.
# VCIT pageview on 2018-01-02 less than 10, skip it.
# CBS.A pageview on 2018-01-02 less than 10, skip it.
# STZ.B pageview on 2018-01-02 less than 10, skip it.
# MTB pageview on 2018-01-02 less than 10, skip it.
# INVH pageview on 2018-01-02 less than 10, skip it.
# run well
# 600
# IHG pageview on 2018-01-02 less than 10, skip it.
# BBDO pageview on 2018-01-02 less than 10, skip it.
# WAT pageview on 2018-01-02 less than 10, skip it.
# GIB pageview on 2018-01-02 less than 10, skip it.
# FTV pageview on 2018-01-02 less than 10, skip it.
# BAP pageview on 2018-01-02 less than 10, skip it.
# UHS pageview on 2018-01-02 less than 10, skip it.
# LBTYA pageview on 2018-01-02 less than 10, skip it.
# SHY pageview on 2018-01-02 less than 10, skip it.
# FMS pageview on 2018-01-02 less than 10, skip it.
# CAJ pageview on 2018-01-02 less than 10, skip it.
# MFG pageview on 2018-01-02 less than 10, skip it.
# ADS pageview on 2018-01-02 less than 10, skip it.
# SNP pageview on 2018-01-02 less than 10, skip it.
# DOV pageview on 2018-01-02 less than 10, skip it.
# HRS pageview on 2018-01-02 less than 10, skip it.
# BND pageview on 2018-01-02 less than 10, skip it.
# RJF pageview on 2018-01-02 less than 10, skip it.
# VXUS pageview on 2018-01-02 less than 10, skip it.
# ACGL pageview on 2018-01-02 less than 10, skip it.
# WRK pageview on 2018-01-02 less than 10, skip it.
# WBK pageview on 2018-01-02 less than 10, skip it.
# WLTW pageview on 2018-01-02 less than 10, skip it.
# CNHI pageview on 2018-01-02 less than 10, skip it.
# RYAAY pageview on 2018-01-02 less than 10, skip it.
# BNDX pageview on 2018-01-02 less than 10, skip it.
# TLK pageview on 2018-01-02 less than 10, skip it.
# KOF pageview on 2018-01-02 less than 10, skip it.
# WPC pageview on 2018-01-02 less than 10, skip it.
# TRP pageview on 2018-01-02 less than 10, skip it.
# XYL pageview on 2018-01-02 less than 10, skip it.
# ROL pageview on 2018-01-02 less than 10, skip it.
# CHU pageview on 2018-01-02 less than 10, skip it.
# BCH pageview on 2018-01-02 less than 10, skip it.
# CCEP has no pageview data!!!
# EQH has no pageview data!!!
# ET pageview on 2018-01-02 less than 10, skip it.
# KDP has no pageview data!!!
# SPOT has no pageview data!!!
# SUZ has no pageview data!!!
# TAK has no pageview data!!!
# DBX has no pageview data!!!
# IGSB has no pageview data!!!
# IQ has no pageview data!!!
# 2
# 2018-01-03
# run well
# 0
# PTC pageview on 2018-01-03 less than 10, skip it.
# DTE pageview on 2018-01-03 less than 10, skip it.
# SHG pageview on 2018-01-03 less than 10, skip it.
# LH pageview on 2018-01-03 less than 10, skip it.
# XEL pageview on 2018-01-03 less than 10, skip it.
# IR pageview on 2018-01-03 less than 10, skip it.
# EQNR has no pageview data!!!
# REG pageview on 2018-01-03 less than 10, skip it.
# BF.A pageview on 2018-01-03 less than 10, skip it.
# BMO pageview on 2018-01-03 less than 10, skip it.
# SNA pageview on 2018-01-03 less than 10, skip it.
# MKL pageview on 2018-01-03 less than 10, skip it.
# ROP pageview on 2018-01-03 less than 10, skip it.
# CGC has no pageview data!!!
# AMP pageview on 2018-01-03 less than 10, skip it.
# TEF pageview on 2018-01-03 less than 10, skip it.
# EVRG has no pageview data!!!
# TRU pageview on 2018-01-03 less than 10, skip it.
# IX pageview on 2018-01-03 less than 10, skip it.
# CNA pageview on 2018-01-03 less than 10, skip it.
# CBRE has no pageview data!!!
# DXCM pageview on 2018-01-03 less than 10, skip it.
# LN pageview on 2018-01-03 less than 10, skip it.
# NTR has no pageview data!!!
# RELX pageview on 2018-01-03 less than 10, skip it.
# MPLX pageview on 2018-01-03 less than 10, skip it.
# VNO pageview on 2018-01-03 less than 10, skip it.
# CUK pageview on 2018-01-03 less than 10, skip it.
# BAK pageview on 2018-01-03 less than 10, skip it.
# EXPD pageview on 2018-01-03 less than 10, skip it.
# PTR pageview on 2018-01-03 less than 10, skip it.
# SLF pageview on 2018-01-03 less than 10, skip it.
# CINF pageview on 2018-01-03 less than 10, skip it.
# WELL has no pageview data!!!
# AGR pageview on 2018-01-03 less than 10, skip it.
# LFC pageview on 2018-01-03 less than 10, skip it.
# SSL pageview on 2018-01-03 less than 10, skip it.
# ORAN pageview on 2018-01-03 less than 10, skip it.
# AMX pageview on 2018-01-03 less than 10, skip it.
# AVB pageview on 2018-01-03 less than 10, skip it.
# ARE pageview on 2018-01-03 less than 10, skip it.
# CDW pageview on 2018-01-03 less than 10, skip it.
# ATH pageview on 2018-01-03 less than 10, skip it.
# run well
# 300
# UDR pageview on 2018-01-03 less than 10, skip it.
# HIG pageview on 2018-01-03 less than 10, skip it.
# MUFG has no pageview data!!!
# IFF pageview on 2018-01-03 less than 10, skip it.
# CMS pageview on 2018-01-03 less than 10, skip it.
# BKNG has no pageview data!!!
# SKM pageview on 2018-01-03 less than 10, skip it.
# JKHY pageview on 2018-01-03 less than 10, skip it.
# VIV pageview on 2018-01-03 less than 10, skip it.
# INFO pageview on 2018-01-03 less than 10, skip it.
# TFX pageview on 2018-01-03 less than 10, skip it.
# LBRDA pageview on 2018-01-03 less than 10, skip it.
# CHD pageview on 2018-01-03 less than 10, skip it.
# RSG pageview on 2018-01-03 less than 10, skip it.
# PFG pageview on 2018-01-03 less than 10, skip it.
# IEF pageview on 2018-01-03 less than 10, skip it.
# MTD pageview on 2018-01-03 less than 10, skip it.
# AJG pageview on 2018-01-03 less than 10, skip it.
# TV pageview on 2018-01-03 less than 10, skip it.
# NMR pageview on 2018-01-03 less than 10, skip it.
# KB pageview on 2018-01-03 less than 10, skip it.
# TSS pageview on 2018-01-03 less than 10, skip it.
# HSY pageview on 2018-01-03 less than 10, skip it.
# WIT pageview on 2018-01-03 less than 10, skip it.
# LKQ pageview on 2018-01-03 less than 10, skip it.
# VIA pageview on 2018-01-03 less than 10, skip it.
# LNC pageview on 2018-01-03 less than 10, skip it.
# FIS pageview on 2018-01-03 less than 10, skip it.
# ULTI pageview on 2018-01-03 less than 10, skip it.
# TU pageview on 2018-01-03 less than 10, skip it.
# WAB pageview on 2018-01-03 less than 10, skip it.
# TRMB pageview on 2018-01-03 less than 10, skip it.
# FMX pageview on 2018-01-03 less than 10, skip it.
# MAA pageview on 2018-01-03 less than 10, skip it.
# BXP pageview on 2018-01-03 less than 10, skip it.
# VRSK pageview on 2018-01-03 less than 10, skip it.
# LSXMA pageview on 2018-01-03 less than 10, skip it.
# CFG pageview on 2018-01-03 less than 10, skip it.
# LBRDK pageview on 2018-01-03 less than 10, skip it.
# ARMK pageview on 2018-01-03 less than 10, skip it.
# IEX pageview on 2018-01-03 less than 10, skip it.
# WPP pageview on 2018-01-03 less than 10, skip it.
# ACWI pageview on 2018-01-03 less than 10, skip it.
# BSAC pageview on 2018-01-03 less than 10, skip it.
# EXR pageview on 2018-01-03 less than 10, skip it.
# MBB pageview on 2018-01-03 less than 10, skip it.
# IXUS pageview on 2018-01-03 less than 10, skip it.
# PFF pageview on 2018-01-03 less than 10, skip it.
# PPG pageview on 2018-01-03 less than 10, skip it.
# SCZ pageview on 2018-01-03 less than 10, skip it.
# SHV pageview on 2018-01-03 less than 10, skip it.
# CHT pageview on 2018-01-03 less than 10, skip it.
# PUK pageview on 2018-01-03 less than 10, skip it.
# LBTYK pageview on 2018-01-03 less than 10, skip it.
# EMB pageview on 2018-01-03 less than 10, skip it.
# VCSH pageview on 2018-01-03 less than 10, skip it.
# DVY pageview on 2018-01-03 less than 10, skip it.
# VAR pageview on 2018-01-03 less than 10, skip it.
# WP has no pageview data!!!
# KEP pageview on 2018-01-03 less than 10, skip it.
# ESS pageview on 2018-01-03 less than 10, skip it.
# RCI pageview on 2018-01-03 less than 10, skip it.
# TI pageview on 2018-01-03 less than 10, skip it.
# CHA pageview on 2018-01-03 less than 10, skip it.
# VCIT pageview on 2018-01-03 less than 10, skip it.
# CBS.A pageview on 2018-01-03 less than 10, skip it.
# STZ.B pageview on 2018-01-03 less than 10, skip it.
# OTEX pageview on 2018-01-03 less than 10, skip it.
# MTB pageview on 2018-01-03 less than 10, skip it.
# INVH pageview on 2018-01-03 less than 10, skip it.
# run well
# 600
# IHG pageview on 2018-01-03 less than 10, skip it.
# BBDO pageview on 2018-01-03 less than 10, skip it.
# CMA pageview on 2018-01-03 less than 10, skip it.
# GIB pageview on 2018-01-03 less than 10, skip it.
# EQR pageview on 2018-01-03 less than 10, skip it.
# BAP pageview on 2018-01-03 less than 10, skip it.
# LBTYA pageview on 2018-01-03 less than 10, skip it.
# SHY pageview on 2018-01-03 less than 10, skip it.
# CAJ pageview on 2018-01-03 less than 10, skip it.
# MFG pageview on 2018-01-03 less than 10, skip it.
# SNP pageview on 2018-01-03 less than 10, skip it.
# DOV pageview on 2018-01-03 less than 10, skip it.
# HRS pageview on 2018-01-03 less than 10, skip it.
# BND pageview on 2018-01-03 less than 10, skip it.
# ATO pageview on 2018-01-03 less than 10, skip it.
# QQQ pageview on 2018-01-03 less than 10, skip it.
# CE pageview on 2018-01-03 less than 10, skip it.
# RJF pageview on 2018-01-03 less than 10, skip it.
# VXUS pageview on 2018-01-03 less than 10, skip it.
# WBK pageview on 2018-01-03 less than 10, skip it.
# WLTW pageview on 2018-01-03 less than 10, skip it.
# RYAAY pageview on 2018-01-03 less than 10, skip it.
# BNDX pageview on 2018-01-03 less than 10, skip it.
# TLK pageview on 2018-01-03 less than 10, skip it.
# KOF pageview on 2018-01-03 less than 10, skip it.
# TRP pageview on 2018-01-03 less than 10, skip it.
# XYL pageview on 2018-01-03 less than 10, skip it.
# ROL pageview on 2018-01-03 less than 10, skip it.
# CHU pageview on 2018-01-03 less than 10, skip it.
# BCH pageview on 2018-01-03 less than 10, skip it.
# CCEP has no pageview data!!!
# EQH has no pageview data!!!
# ET pageview on 2018-01-03 less than 10, skip it.
# KDP has no pageview data!!!
# SPOT has no pageview data!!!
# SUZ has no pageview data!!!
# TAK has no pageview data!!!
# DBX has no pageview data!!!
# IGSB has no pageview data!!!
# IQ has no pageview data!!!
# 3
# 2018-01-04
# run well
# 0
# LDOS pageview on 2018-01-04 less than 10, skip it.
# PTC pageview on 2018-01-04 less than 10, skip it.
# DGX pageview on 2018-01-04 less than 10, skip it.
# FOX pageview on 2018-01-04 less than 10, skip it.
# UN pageview on 2018-01-04 less than 10, skip it.
# SHG pageview on 2018-01-04 less than 10, skip it.
# EQNR has no pageview data!!!
# REG pageview on 2018-01-04 less than 10, skip it.
# BF.A pageview on 2018-01-04 less than 10, skip it.
# DLR pageview on 2018-01-04 less than 10, skip it.
# SNA pageview on 2018-01-04 less than 10, skip it.
# MKL pageview on 2018-01-04 less than 10, skip it.
# ROP pageview on 2018-01-04 less than 10, skip it.
# CGC has no pageview data!!!
# EVRG has no pageview data!!!
# TRU pageview on 2018-01-04 less than 10, skip it.
# ANSS pageview on 2018-01-04 less than 10, skip it.
# MGM pageview on 2018-01-04 less than 10, skip it.
# IX pageview on 2018-01-04 less than 10, skip it.
# SAP pageview on 2018-01-04 less than 10, skip it.
# CNA pageview on 2018-01-04 less than 10, skip it.
# DEO pageview on 2018-01-04 less than 10, skip it.
# CBRE has no pageview data!!!
# NTR has no pageview data!!!
# RELX pageview on 2018-01-04 less than 10, skip it.
# VNO pageview on 2018-01-04 less than 10, skip it.
# JAZZ pageview on 2018-01-04 less than 10, skip it.
# CUK pageview on 2018-01-04 less than 10, skip it.
# KSU pageview on 2018-01-04 less than 10, skip it.
# BAK pageview on 2018-01-04 less than 10, skip it.
# EXPD pageview on 2018-01-04 less than 10, skip it.
# SLF pageview on 2018-01-04 less than 10, skip it.
# CINF pageview on 2018-01-04 less than 10, skip it.
# WELL has no pageview data!!!
# AGR pageview on 2018-01-04 less than 10, skip it.
# LFC pageview on 2018-01-04 less than 10, skip it.
# EQIX pageview on 2018-01-04 less than 10, skip it.
# SSL pageview on 2018-01-04 less than 10, skip it.
# ORAN pageview on 2018-01-04 less than 10, skip it.
# AMX pageview on 2018-01-04 less than 10, skip it.
# TEL pageview on 2018-01-04 less than 10, skip it.
# AVB pageview on 2018-01-04 less than 10, skip it.
# ATH pageview on 2018-01-04 less than 10, skip it.
# FTS pageview on 2018-01-04 less than 10, skip it.
# run well
# 300
# UDR pageview on 2018-01-04 less than 10, skip it.
# HIG pageview on 2018-01-04 less than 10, skip it.
# MUFG has no pageview data!!!
# SSNC pageview on 2018-01-04 less than 10, skip it.
# MGA pageview on 2018-01-04 less than 10, skip it.
# BKNG has no pageview data!!!
# BF.B pageview on 2018-01-04 less than 10, skip it.
# SKM pageview on 2018-01-04 less than 10, skip it.
# SNN pageview on 2018-01-04 less than 10, skip it.
# VIV pageview on 2018-01-04 less than 10, skip it.
# HST pageview on 2018-01-04 less than 10, skip it.
# CSGP pageview on 2018-01-04 less than 10, skip it.
# INFO pageview on 2018-01-04 less than 10, skip it.
# TFX pageview on 2018-01-04 less than 10, skip it.
# LBRDA pageview on 2018-01-04 less than 10, skip it.
# IEF pageview on 2018-01-04 less than 10, skip it.
# MTD pageview on 2018-01-04 less than 10, skip it.
# AJG pageview on 2018-01-04 less than 10, skip it.
# TV pageview on 2018-01-04 less than 10, skip it.
# NMR pageview on 2018-01-04 less than 10, skip it.
# KB pageview on 2018-01-04 less than 10, skip it.
# VST pageview on 2018-01-04 less than 10, skip it.
# TRI pageview on 2018-01-04 less than 10, skip it.
# WIT pageview on 2018-01-04 less than 10, skip it.
# VIA pageview on 2018-01-04 less than 10, skip it.
# LNC pageview on 2018-01-04 less than 10, skip it.
# FIS pageview on 2018-01-04 less than 10, skip it.
# RMD pageview on 2018-01-04 less than 10, skip it.
# ULTI pageview on 2018-01-04 less than 10, skip it.
# TDG pageview on 2018-01-04 less than 10, skip it.
# GPC pageview on 2018-01-04 less than 10, skip it.
# IAC pageview on 2018-01-04 less than 10, skip it.
# WAB pageview on 2018-01-04 less than 10, skip it.
# SBAC pageview on 2018-01-04 less than 10, skip it.
# FMX pageview on 2018-01-04 less than 10, skip it.
# MAA pageview on 2018-01-04 less than 10, skip it.
# BXP pageview on 2018-01-04 less than 10, skip it.
# VRSK pageview on 2018-01-04 less than 10, skip it.
# LSXMA pageview on 2018-01-04 less than 10, skip it.
# CFG pageview on 2018-01-04 less than 10, skip it.
# LBRDK pageview on 2018-01-04 less than 10, skip it.
# IEX pageview on 2018-01-04 less than 10, skip it.
# WPP pageview on 2018-01-04 less than 10, skip it.
# BCE pageview on 2018-01-04 less than 10, skip it.
# ACWI pageview on 2018-01-04 less than 10, skip it.
# KEYS pageview on 2018-01-04 less than 10, skip it.
# BSAC pageview on 2018-01-04 less than 10, skip it.
# EXR pageview on 2018-01-04 less than 10, skip it.
# MBB pageview on 2018-01-04 less than 10, skip it.
# IXUS pageview on 2018-01-04 less than 10, skip it.
# PFF pageview on 2018-01-04 less than 10, skip it.
# BURL pageview on 2018-01-04 less than 10, skip it.
# SCZ pageview on 2018-01-04 less than 10, skip it.
# SHV pageview on 2018-01-04 less than 10, skip it.
# HSIC pageview on 2018-01-04 less than 10, skip it.
# PUK pageview on 2018-01-04 less than 10, skip it.
# LBTYK pageview on 2018-01-04 less than 10, skip it.
# EMB pageview on 2018-01-04 less than 10, skip it.
# VCSH pageview on 2018-01-04 less than 10, skip it.
# DVY pageview on 2018-01-04 less than 10, skip it.
# VAR pageview on 2018-01-04 less than 10, skip it.
# WP has no pageview data!!!
# ESS pageview on 2018-01-04 less than 10, skip it.
# GPN pageview on 2018-01-04 less than 10, skip it.
# RCI pageview on 2018-01-04 less than 10, skip it.
# TI pageview on 2018-01-04 less than 10, skip it.
# CHA pageview on 2018-01-04 less than 10, skip it.
# VCIT pageview on 2018-01-04 less than 10, skip it.
# CBS.A pageview on 2018-01-04 less than 10, skip it.
# LYV pageview on 2018-01-04 less than 10, skip it.
# STZ.B pageview on 2018-01-04 less than 10, skip it.
# PHG pageview on 2018-01-04 less than 10, skip it.
# MTB pageview on 2018-01-04 less than 10, skip it.
# INVH pageview on 2018-01-04 less than 10, skip it.
# ...
# PFF pageview on 2018-01-09 less than 10, skip it.
# SMFG pageview on 2018-01-09 less than 10, skip it.
# SCZ pageview on 2018-01-09 less than 10, skip it.
# SHV pageview on 2018-01-09 less than 10, skip it.
# CHT pageview on 2018-01-09 less than 10, skip it.
# PUK pageview on 2018-01-09 less than 10, skip it.
# LBTYK pageview on 2018-01-09 less than 10, skip it.
# EMB pageview on 2018-01-09 less than 10, skip it.
# VCSH pageview on 2018-01-09 less than 10, skip it.
# LEN.B pageview on 2018-01-09 less than 10, skip it.
# DVY pageview on 2018-01-09 less than 10, skip it.
# VAR pageview on 2018-01-09 less than 10, skip it.
# WP has no pageview data!!!
# KEP pageview on 2018-01-09 less than 10, skip it.
# ESS pageview on 2018-01-09 less than 10, skip it.
# ANGI pageview on 2018-01-09 less than 10, skip it.
# VCIT pageview on 2018-01-09 less than 10, skip it.
# LYV pageview on 2018-01-09 less than 10, skip it.
# OTEX pageview on 2018-01-09 less than 10, skip it.
# MTB pageview on 2018-01-09 less than 10, skip it.
# IBN pageview on 2018-01-09 less than 10, skip it.
# run well
# 600
# IHG pageview on 2018-01-09 less than 10, skip it.
# BBDO pageview on 2018-01-09 less than 10, skip it.
# GIB pageview on 2018-01-09 less than 10, skip it.
# BAP pageview on 2018-01-09 less than 10, skip it.
# LBTYA pageview on 2018-01-09 less than 10, skip it.
# SHY pageview on 2018-01-09 less than 10, skip it.
# CAJ pageview on 2018-01-09 less than 10, skip it.
# GDDY pageview on 2018-01-09 less than 10, skip it.
# SNP pageview on 2018-01-09 less than 10, skip it.
# BND pageview on 2018-01-09 less than 10, skip it.
# ATO pageview on 2018-01-09 less than 10, skip it.
# VXUS pageview on 2018-01-09 less than 10, skip it.
# ACGL pageview on 2018-01-09 less than 10, skip it.
# WRK pageview on 2018-01-09 less than 10, skip it.
# WBK pageview on 2018-01-09 less than 10, skip it.
# WLTW pageview on 2018-01-09 less than 10, skip it.
# PBA pageview on 2018-01-09 less than 10, skip it.
# RYAAY pageview on 2018-01-09 less than 10, skip it.
# CRH pageview on 2018-01-09 less than 10, skip it.
# BNDX pageview on 2018-01-09 less than 10, skip it.
# TLK pageview on 2018-01-09 less than 10, skip it.
# KOF pageview on 2018-01-09 less than 10, skip it.
# WCN pageview on 2018-01-09 less than 10, skip it.
# WPC pageview on 2018-01-09 less than 10, skip it.
# ECL pageview on 2018-01-09 less than 10, skip it.
# TRP pageview on 2018-01-09 less than 10, skip it.
# ROL pageview on 2018-01-09 less than 10, skip it.
# CHU pageview on 2018-01-09 less than 10, skip it.
# BCH pageview on 2018-01-09 less than 10, skip it.
# CCEP has no pageview data!!!
# EQH has no pageview data!!!
# ET pageview on 2018-01-09 less than 10, skip it.
# KDP has no pageview data!!!
# SPOT has no pageview data!!!
# SUZ has no pageview data!!!
# TAK has no pageview data!!!
# DBX has no pageview data!!!
# IGSB has no pageview data!!!
# IQ has no pageview data!!!
# 9
# 2018-01-10
# run well
# 0
# PTC pageview on 2018-01-10 less than 10, skip it.
# WCG pageview on 2018-01-10 less than 10, skip it.
# DTE pageview on 2018-01-10 less than 10, skip it.
# DGX pageview on 2018-01-10 less than 10, skip it.
# FOX pageview on 2018-01-10 less than 10, skip it.
# SHG pageview on 2018-01-10 less than 10, skip it.
# LH pageview on 2018-01-10 less than 10, skip it.
# GRFS pageview on 2018-01-10 less than 10, skip it.
# EQNR has no pageview data!!!
# REG pageview on 2018-01-10 less than 10, skip it.
# BF.A pageview on 2018-01-10 less than 10, skip it.
# SNA pageview on 2018-01-10 less than 10, skip it.
# COO pageview on 2018-01-10 less than 10, skip it.
# CGC has no pageview data!!!
# EVRG has no pageview data!!!
# TRU pageview on 2018-01-10 less than 10, skip it.
# ANSS pageview on 2018-01-10 less than 10, skip it.
# SAP pageview on 2018-01-10 less than 10, skip it.
# BBD pageview on 2018-01-10 less than 10, skip it.
# CNA pageview on 2018-01-10 less than 10, skip it.
# SGEN pageview on 2018-01-10 less than 10, skip it.
# CBRE has no pageview data!!!
# PBR.A pageview on 2018-01-10 less than 10, skip it.
# LN pageview on 2018-01-10 less than 10, skip it.
# MMC pageview on 2018-01-10 less than 10, skip it.
# NTR has no pageview data!!!
# RELX pageview on 2018-01-10 less than 10, skip it.
# MPLX pageview on 2018-01-10 less than 10, skip it.
# VNO pageview on 2018-01-10 less than 10, skip it.
# BAK pageview on 2018-01-10 less than 10, skip it.
# APTV pageview on 2018-01-10 less than 10, skip it.
# SLF pageview on 2018-01-10 less than 10, skip it.
# WELL has no pageview data!!!
# TPR pageview on 2018-01-10 less than 10, skip it.
# AGR pageview on 2018-01-10 less than 10, skip it.
# LFC pageview on 2018-01-10 less than 10, skip it.
# SSL pageview on 2018-01-10 less than 10, skip it.
# ORAN pageview on 2018-01-10 less than 10, skip it.
# AMX pageview on 2018-01-10 less than 10, skip it.
# ARE pageview on 2018-01-10 less than 10, skip it.
# CDW pageview on 2018-01-10 less than 10, skip it.
# ATH pageview on 2018-01-10 less than 10, skip it.
# CP pageview on 2018-01-10 less than 10, skip it.
# run well
# 300
# VRSN pageview on 2018-01-10 less than 10, skip it.
# UDR pageview on 2018-01-10 less than 10, skip it.
# PKI pageview on 2018-01-10 less than 10, skip it.
# MUFG has no pageview data!!!
# CMS pageview on 2018-01-10 less than 10, skip it.
# BKNG has no pageview data!!!
# MSI pageview on 2018-01-10 less than 10, skip it.
# VIV pageview on 2018-01-10 less than 10, skip it.
# CSGP pageview on 2018-01-10 less than 10, skip it.
# INFO pageview on 2018-01-10 less than 10, skip it.
# LBRDA pageview on 2018-01-10 less than 10, skip it.
# RSG pageview on 2018-01-10 less than 10, skip it.
# IEF pageview on 2018-01-10 less than 10, skip it.
# MTD pageview on 2018-01-10 less than 10, skip it.
# AJG pageview on 2018-01-10 less than 10, skip it.
# RL pageview on 2018-01-10 less than 10, skip it.
# TV pageview on 2018-01-10 less than 10, skip it.
# VST pageview on 2018-01-10 less than 10, skip it.
# TRI pageview on 2018-01-10 less than 10, skip it.
# WIT pageview on 2018-01-10 less than 10, skip it.
# LKQ pageview on 2018-01-10 less than 10, skip it.
# VIA pageview on 2018-01-10 less than 10, skip it.
# FIS pageview on 2018-01-10 less than 10, skip it.
# RMD pageview on 2018-01-10 less than 10, skip it.
# ULTI pageview on 2018-01-10 less than 10, skip it.
# TDG pageview on 2018-01-10 less than 10, skip it.
# BT pageview on 2018-01-10 less than 10, skip it.
# IAC pageview on 2018-01-10 less than 10, skip it.
# WAB pageview on 2018-01-10 less than 10, skip it.
# TRMB pageview on 2018-01-10 less than 10, skip it.
# FMX pageview on 2018-01-10 less than 10, skip it.
# MAA pageview on 2018-01-10 less than 10, skip it.
# FTNT pageview on 2018-01-10 less than 10, skip it.
# CEO pageview on 2018-01-10 less than 10, skip it.
# BXP pageview on 2018-01-10 less than 10, skip it.
# VRSK pageview on 2018-01-10 less than 10, skip it.
# LSXMA pageview on 2018-01-10 less than 10, skip it.
# LBRDK pageview on 2018-01-10 less than 10, skip it.
# ARMK pageview on 2018-01-10 less than 10, skip it.
# IEX pageview on 2018-01-10 less than 10, skip it.
# WPP pageview on 2018-01-10 less than 10, skip it.
# ACWI pageview on 2018-01-10 less than 10, skip it.
# BSAC pageview on 2018-01-10 less than 10, skip it.
# EXR pageview on 2018-01-10 less than 10, skip it.
# MBB pageview on 2018-01-10 less than 10, skip it.
# IXUS pageview on 2018-01-10 less than 10, skip it.
# PFF pageview on 2018-01-10 less than 10, skip it.
# SCZ pageview on 2018-01-10 less than 10, skip it.
# SHV pageview on 2018-01-10 less than 10, skip it.
# CHT pageview on 2018-01-10 less than 10, skip it.
# LBTYK pageview on 2018-01-10 less than 10, skip it.
# EMB pageview on 2018-01-10 less than 10, skip it.
# VCSH pageview on 2018-01-10 less than 10, skip it.
# DVY pageview on 2018-01-10 less than 10, skip it.
# VAR pageview on 2018-01-10 less than 10, skip it.
# BSBR pageview on 2018-01-10 less than 10, skip it.
# WP has no pageview data!!!
# KEP pageview on 2018-01-10 less than 10, skip it.
# GPN pageview on 2018-01-10 less than 10, skip it.
# RCI pageview on 2018-01-10 less than 10, skip it.
# ANGI pageview on 2018-01-10 less than 10, skip it.
# TI pageview on 2018-01-10 less than 10, skip it.
# CHA pageview on 2018-01-10 less than 10, skip it.
# IT pageview on 2018-01-10 less than 10, skip it.
# VCIT pageview on 2018-01-10 less than 10, skip it.
# CBS.A pageview on 2018-01-10 less than 10, skip it.
# LYV pageview on 2018-01-10 less than 10, skip it.
# STZ.B pageview on 2018-01-10 less than 10, skip it.
# PHG pageview on 2018-01-10 less than 10, skip it.
# INVH pageview on 2018-01-10 less than 10, skip it.
# IBN pageview on 2018-01-10 less than 10, skip it.
# run well
# 600
# IHG pageview on 2018-01-10 less than 10, skip it.
# BBDO pageview on 2018-01-10 less than 10, skip it.
# WAT pageview on 2018-01-10 less than 10, skip it.
# FTV pageview on 2018-01-10 less than 10, skip it.
# BAP pageview on 2018-01-10 less than 10, skip it.
# UHS pageview on 2018-01-10 less than 10, skip it.
# LBTYA pageview on 2018-01-10 less than 10, skip it.
# SHY pageview on 2018-01-10 less than 10, skip it.
# CAJ pageview on 2018-01-10 less than 10, skip it.
# GDDY pageview on 2018-01-10 less than 10, skip it.
# SNP pageview on 2018-01-10 less than 10, skip it.
# MCO pageview on 2018-01-10 less than 10, skip it.
# DOV pageview on 2018-01-10 less than 10, skip it.
# HRS pageview on 2018-01-10 less than 10, skip it.
# BND pageview on 2018-01-10 less than 10, skip it.
# ATO pageview on 2018-01-10 less than 10, skip it.
# VXUS pageview on 2018-01-10 less than 10, skip it.
# WBK pageview on 2018-01-10 less than 10, skip it.
# WLTW pageview on 2018-01-10 less than 10, skip it.
# RYAAY pageview on 2018-01-10 less than 10, skip it.
# CRH pageview on 2018-01-10 less than 10, skip it.
# BNDX pageview on 2018-01-10 less than 10, skip it.
# TLK pageview on 2018-01-10 less than 10, skip it.
# KOF pageview on 2018-01-10 less than 10, skip it.
# WCN pageview on 2018-01-10 less than 10, skip it.
# CHU pageview on 2018-01-10 less than 10, skip it.
# CNQ pageview on 2018-01-10 less than 10, skip it.
# BCH pageview on 2018-01-10 less than 10, skip it.
# CCEP has no pageview data!!!
# EQH has no pageview data!!!
# ET pageview on 2018-01-10 less than 10, skip it.
# KDP has no pageview data!!!
# SPOT has no pageview data!!!
# SUZ has no pageview data!!!
# TAK has no pageview data!!!
# DBX has no pageview data!!!
# IGSB has no pageview data!!!
# IQ has no pageview data!!!
# 10
# 2018-01-11
# run well
# 0
# LDOS pageview on 2018-01-11 less than 10, skip it.
# PTC pageview on 2018-01-11 less than 10, skip it.
# WCG pageview on 2018-01-11 less than 10, skip it.
# DGX pageview on 2018-01-11 less than 10, skip it.
# FOX pageview on 2018-01-11 less than 10, skip it.
# UN pageview on 2018-01-11 less than 10, skip it.
# SHG pageview on 2018-01-11 less than 10, skip it.
# LH pageview on 2018-01-11 less than 10, skip it.
# GRFS pageview on 2018-01-11 less than 10, skip it.
# NSC pageview on 2018-01-11 less than 10, skip it.
# EQNR has no pageview data!!!
# REG pageview on 2018-01-11 less than 10, skip it.
# BF.A pageview on 2018-01-11 less than 10, skip it.
# SNA pageview on 2018-01-11 less than 10, skip it.
# SIVB pageview on 2018-01-11 less than 10, skip it.
# COO pageview on 2018-01-11 less than 10, skip it.
# CGC has no pageview data!!!
# EVRG has no pageview data!!!
# TRU pageview on 2018-01-11 less than 10, skip it.
# ANSS pageview on 2018-01-11 less than 10, skip it.
# IX pageview on 2018-01-11 less than 10, skip it.
# BBD pageview on 2018-01-11 less than 10, skip it.
# CNA pageview on 2018-01-11 less than 10, skip it.
# CBRE has no pageview data!!!
# NTR has no pageview data!!!
# PKX pageview on 2018-01-11 less than 10, skip it.
# RELX pageview on 2018-01-11 less than 10, skip it.
# VNO pageview on 2018-01-11 less than 10, skip it.
# CUK pageview on 2018-01-11 less than 10, skip it.
# APTV pageview on 2018-01-11 less than 10, skip it.
# SLF pageview on 2018-01-11 less than 10, skip it.
# SNPS pageview on 2018-01-11 less than 10, skip it.
# WELL has no pageview data!!!
# LFC pageview on 2018-01-11 less than 10, skip it.
# SSL pageview on 2018-01-11 less than 10, skip it.
# ORAN pageview on 2018-01-11 less than 10, skip it.
# AMX pageview on 2018-01-11 less than 10, skip it.
# ARE pageview on 2018-01-11 less than 10, skip it.
# CDW pageview on 2018-01-11 less than 10, skip it.
# run well
# 300
# UDR pageview on 2018-01-11 less than 10, skip it.
# HIG pageview on 2018-01-11 less than 10, skip it.
# PKI pageview on 2018-01-11 less than 10, skip it.
# MUFG has no pageview data!!!
# IFF pageview on 2018-01-11 less than 10, skip it.
# BKNG has no pageview data!!!
# SKM pageview on 2018-01-11 less than 10, skip it.
# SNN pageview on 2018-01-11 less than 10, skip it.
# MSI pageview on 2018-01-11 less than 10, skip it.
# JKHY pageview on 2018-01-11 less than 10, skip it.
# CSGP pageview on 2018-01-11 less than 10, skip it.
# TFX pageview on 2018-01-11 less than 10, skip it.
# LBRDA pageview on 2018-01-11 less than 10, skip it.
# CHD pageview on 2018-01-11 less than 10, skip it.
# MFC pageview on 2018-01-11 less than 10, skip it.
# RSG pageview on 2018-01-11 less than 10, skip it.
# IEF pageview on 2018-01-11 less than 10, skip it.
# MTD pageview on 2018-01-11 less than 10, skip it.
# AJG pageview on 2018-01-11 less than 10, skip it.
# TV pageview on 2018-01-11 less than 10, skip it.
# VST pageview on 2018-01-11 less than 10, skip it.
# TRI pageview on 2018-01-11 less than 10, skip it.
# WIT pageview on 2018-01-11 less than 10, skip it.
# VIA pageview on 2018-01-11 less than 10, skip it.
# RMD pageview on 2018-01-11 less than 10, skip it.
# ULTI pageview on 2018-01-11 less than 10, skip it.
# TU pageview on 2018-01-11 less than 10, skip it.
# WAB pageview on 2018-01-11 less than 10, skip it.
# TRMB pageview on 2018-01-11 less than 10, skip it.
# FMX pageview on 2018-01-11 less than 10, skip it.
# CEO pageview on 2018-01-11 less than 10, skip it.
# BXP pageview on 2018-01-11 less than 10, skip it.
# MHK pageview on 2018-01-11 less than 10, skip it.
# HDB pageview on 2018-01-11 less than 10, skip it.
# LBRDK pageview on 2018-01-11 less than 10, skip it.
# BAM pageview on 2018-01-11 less than 10, skip it.
# WPP pageview on 2018-01-11 less than 10, skip it.
# BCE pageview on 2018-01-11 less than 10, skip it.
# ACWI pageview on 2018-01-11 less than 10, skip it.
# KEYS pageview on 2018-01-11 less than 10, skip it.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bf0d5945ab13> in <module>()
#       4     print(date)
#       5     leader = Generate_Leaders()
# ----> 6     highest_change = leader.highest_change(date)
#       7     to_combine = pd.DataFrame([])
#       8     for item in all_symbols:
#
# <ipython-input-9-5d7489b96a69> in highest_change(self, my_date)
#      45                 print('run well')
#      46                 print(i)
# ---> 47             self.parallel(item)
#
# <ipython-input-9-5d7489b96a69> in parallel(self, item)
#      31             print('{} pageview on {} less than 10, skip it.'.format(item, self.my_date))
#      32             return
# ---> 33         temp_res.loc[0, 'Market_Cap(billion)'] = self.get_mkt_cap(item, self.my_date, self.my_date)
#      34         if temp_res['Market_Cap(billion)'].isnull().values.any():
#      35             pass
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
#     191     def _validate_key(self, key, axis):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     364                         new_indexer = convert_from_missing_indexer_tuple(
#     365                             indexer, self.obj.axes)
# --> 366                         self._setitem_with_indexer(new_indexer, value)
#     367
#     368                         return self.obj
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     519                     lplane_indexer = 0
#     520
# --> 521             def setter(item, v):
#     522                 s = self.obj[item]
#     523                 pi = plane_indexer[0] if lplane_indexer == 1 else plane_indexer
#
# KeyboardInterrupt:

# %%
url_price = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=OnDemand&symbol={}&type=daily&startDate={}&endDate={}&maxRecords=1000&interval=60&order=asc&sessionFilter=EFK&splits=true&dividends=true&volume=sum&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ&backAdjust=false&daysToExpiration=1&contractRoll=expiration'

# %%
test = pd.read_csv(url_price.format('AAPL', '2018-07-01', '2018-07-30'))

# %%
test.head()
# Out:
#   symbol                  timestamp  tradingDay      open      high       low  \
# 0   AAPL  2018-07-02T00:00:00-04:00  2018-07-02  181.7611  185.2021  181.3656
# 1   AAPL  2018-07-03T00:00:00-04:00  2018-07-03  185.6866  185.8448  181.4842
# 2   AAPL  2018-07-05T00:00:00-04:00  2018-07-05  183.1850  184.3221  182.2160
# 3   AAPL  2018-07-06T00:00:00-04:00  2018-07-06  183.3432  186.3195  183.1257
# 4   AAPL  2018-07-09T00:00:00-04:00  2018-07-09  187.3775  188.5443  187.1797
#
#       close    volume  openInterest
# 0  185.0835  17932150           NaN
# 1  181.8600  14112872           NaN
# 2  183.3234  16792282           NaN
# 3  185.8646  17683262           NaN
# 4  188.4454  19980392           NaN

# %%
#get business days
from pandas.tseries.offsets import *
daterange1 = pd.date_range('2017-12-01', '2019-01-20', freq=BDay())
daterange1 = list(daterange1.strftime('%Y-%m-%d'))
holidays = ['2017-12-25', '2018-01-01', '2018-01-15', '2018-02-19', '2018-03-30', '2018-05-28', '2018-07-04', '2018-09-03',\
            '2018-11-22', '2018-12-05', '2018-12-25', '2019-01-01']
for each in holidays:
    if each in daterange1:
        daterange1.remove(each)

# %%
daterange2 = daterange1[20:271]

# %%
#Pick the top 10 symbols with highest PageView_Change_in_std and PageView > 10
"""
Filters:
<1> Remove stocks with a gap up or down day within the window period
<2> Remove stocks that have a significantly greater high low range within the window period compared to normal.
"""
url_price = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=OnDemand&symbol={}&type=daily&startDate={}&endDate={}&maxRecords=1000&interval=60&order=asc&sessionFilter=EFK&splits=true&dividends=true&volume=sum&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ&backAdjust=false&daysToExpiration=1&contractRoll=expiration'
#get earning dates
def get_earning_date(symbol, start_date, end_date):
    url_earning = 'https://ondemand.websol.barchart.com/getCorporateActions.csv?apikey=ondemand&symbols={}&startDate={}&endDate={}&eventType=earnings&maxRecords=5'.\
                   format(symbol, start_date, end_date)
    try:
        return pd.read_csv(url_earning)
    except EmptyDataError as ede:
        #print(symbol + ' does not have earning_date during this period!!!')
        return pd.DataFrame([])
    except ConnectionResetError:
        print("getearning API problem")
        return get_earning_date(symbol, start_date, end_date)
def my_parallel(args):# filter for volatility.
    #filter for sentiment
    
    date = args[0]
    win_end = args[1]
    to_drop = args[2]
    window_days = args[3]
    gap_up_days = args[4]
    item = args[5]
    flag = True
    while flag:
        try:
            price = pd.read_csv(url_price.format(item, '2017-12-01', str(win_end)[:10]))
            flag = False
        except EmptyDataError:
            to_drop.append(item) # If the symbol has no trading for this window, drop it.
            print('EmptyData Error, {} has no trading on this window, drop it.'.format(item))
            flag = False
            return
        except ConnectionResetError:
            print('API Problem')
            continue
    price['high_loc_diff'] = price['high'] - price['low']
    price['H_L_20day_moving_avg'] = price['high_loc_diff'].rolling(20).mean()
    benchmark_index = price.loc[price['tradingDay'] == str(win_end)[:10]].index.item() - 1
    try:
        high_low_benchmark = price.iloc[benchmark_index, 10]
    except IndexError:
        print('Index Error')
        print(price)
    win_low = 0
    win_high = 0
    #filter for past 10 days percentage change > 7%
    win_start_index = daterange1.index(str(window_days[0])[:10])
    big_change_end = daterange1[win_start_index - 1]
    big_change_start = daterange1[win_start_index - 10]
    flag1 = True
    while flag1:  
        try:
            last_10_days_open = pd.read_csv(url_price.format(item, big_change_start, big_change_start))
            flag1 = False
        except EmptyDataError:
            to_drop.append(item)
            flag1 = False
            return
        except ConnectionResetError:
            print('API Problem')
            continue
    flag2 = True
    while flag2:
        try:
            last_10_days_close = pd.read_csv(url_price.format(item, big_change_end, big_change_end))
            flag2 = False
        except EmptyDataError:
            to_drop.append(item)
            flag2 = False
            return
        except ConnectionResetError:
            print('API Problem')
            continue
    if abs((last_10_days_close['close'][0] - last_10_days_open['open'][0])/last_10_days_open['open'][0]) > 0.07:
        print('prior 10 days open ' + str(last_10_days_open['open'][0]))
        print('close ' + str(last_10_days_close['close'][0]))
        print('change > 0.07, drop {}'.format(item))
        to_drop.append(item)
        return
    #filter for earning dates
    win_end_index = daterange1.index(str(window_days[-1])[:10])
    earning_start = daterange1[win_end_index - 5]
    earning_end = daterange1[win_end_index + 5]
    if get_earning_date(item, earning_start, earning_end).empty is False:
        print(item + ' has earning date, drop')
        to_drop.append(item)
        return
    for each in gap_up_days:#expand to the past 10 days.
        temp_price = price.loc[price['tradingDay'] == str(each)[:10]]
        try:
            last_day_index = temp_price.index.item() - 1
        except:
            print(temp_price)
        try:
            last_day_price = price.iloc[last_day_index]
        except IndexError:
            print('Index Error')
            print(price)
        try:
            if float(temp_price['open']) > float(last_day_price['high']) or\
            float(temp_price['open']) < float(last_day_price['low']):
                to_drop.append(item)
                return
        except TypeError:
            continue
    #processing window part
    for each in window_days:
        temp_price = price.loc[price['tradingDay'] == str(each)[:10]]
        try:
            last_day_index = temp_price.index.item() - 1
        except:
            print(temp_price)
        try:
            last_day_price = price.iloc[last_day_index]
        except IndexError:
            print('Index Error')
            print(price)
        try:
            if float(temp_price['open']) > float(last_day_price['high']) or\
            float(temp_price['open']) < float(last_day_price['low']):
                to_drop.append(item)
                return
        except TypeError:
            to_drop.append(item) # If the symbol has no trading for this window, drop it.
            print('TypeError, {} has no trading on this window, drop it.'.format(item))
            return
        if win_low == 0:
            win_low = float(temp_price['low'])
        else:
            win_low = min(float(temp_price['low']), win_low)
        if win_high == 0:
            win_high = float(temp_price['high'])
        else:
            win_high = max(float(temp_price['high']), win_high)
    win_high_low = float(win_high - win_low)
    if win_high_low > 2.5*high_low_benchmark:
        to_drop.append(item)
def my_filters(rawdata, date, win):
    symbols = list(rawdata['Symbol'])
    #temp_win_date = datetime.datetime.strptime(date, "%Y-%m-%d")
    count = 0
    window_days = []
    gap_up_days = []
    win_end_index = daterange1.index(date)
    while count < 10:
        if count < win:
            window_days.append(datetime.datetime.strptime(daterange1[win_end_index-count], "%Y-%m-%d"))
        else:
            gap_up_days.append(datetime.datetime.strptime(daterange1[win_end_index-count], "%Y-%m-%d"))
        count += 1
    window_days = window_days[::-1]
    gap_up_days = gap_up_days[::-1]
    win_start = window_days[0]
    win_end = window_days[-1]
    to_drop = Manager().list()
    args = []
    for item in symbols:
        args.append((date, win_end, to_drop, window_days, gap_up_days, item))
    pool = ThreadPool(10)
    pool.map(my_parallel, args) #important, no run except permission
    pool.close()
    pool.join() 

    to_drop = list(set(to_drop))
    for item in to_drop:
        rawdata = rawdata.loc[rawdata['Symbol'] != item]
    return rawdata
for win in [1, 3]:
    for date in daterange2:
        print(datetime.datetime.now())
        print(date)
        for cap in ['small', 'mid', 'large']:
            try:
                to_filter = pd.read_csv\
                ('leaderlist {}/{}_cap/window_{}_day/{}_cap_highest_change_time_window_{}.csv'.format(date, cap, win, cap, win))
            except FileNotFoundError:
                continue
            to_filter = to_filter.loc[to_filter['PageView_Change_in_Std_{}'.format(win)] >= 3]
            to_filter = my_filters(to_filter, date, win)
            each = date
            each = each[5:]
            each = each.replace('-', '')
            to_filter = to_filter.head(10)
            to_filter.to_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win), index = False)
# Out:
# 2019-03-18 23:02:13.752314
# 2018-01-02
# prior 10 days open 42.020579999999995
# close 45.34122
# change > 0.07, drop RIO
# prior 10 days open 12.19309
# close 13.794889999999999
# change > 0.07, drop EC
# prior 10 days open 15.485339999999999
# close 18.43446
# change > 0.07, drop FCX
# 2019-03-18 23:02:15.310395
# 2018-01-03
# prior 10 days open 12.329
# close 13.98905
# change > 0.07, drop EC
# 2019-03-18 23:02:17.295294
# 2018-01-04
# prior 10 days open 48.65615
# close 45.0756
# change > 0.07, drop SO
# prior 10 days open 12.5717
# close 14.202620000000001
# change > 0.07, drop EC
# STZ has earning date, drop
# prior 10 days open 137.7952
# close 150.0514
# change > 0.07, drop CXO
# WBA has earning date, drop
# 2019-03-18 23:02:20.736911
# 2018-01-05
# prior 10 days open 48.0469
# close 44.21327
# change > 0.07, drop SO
# prior 10 days open 7.8234509999999995
# close 8.403481
# change > 0.07, drop ITUB
# prior 10 days open 12.620239999999999
# close 14.940420000000001
# change > 0.07, drop EC
# STZ has earning date, drop
# prior 10 days open 42.56449
# close 46.79942
# change > 0.07, drop HES
# prior 10 days open 136.6664
# close 151.7295
# change > 0.07, drop CXO
# prior 10 days open 25.30278
# close 29.5967
# change > 0.07, drop NBL
# prior 10 days open 59.57209
# close 66.48662
# change > 0.07, drop SLB
# WBA has earning date, drop
# 2019-03-18 23:02:23.973822
# 2018-01-08
# prior 10 days open 42.828559999999996
# close 48.31539
# change > 0.07, drop HES
# prior 10 days open 47.37203
# close 43.960190000000004
# change > 0.07, drop SO
# STZ has earning date, drop
# 2019-03-18 23:02:26.677560
# 2018-01-09
# prior 10 days open 19.96
# close 21.53
# change > 0.07, drop ATUS
# prior 10 days open 42.65251
# close 49.47926
# change > 0.07, drop HES
# STZ has earning date, drop
# prior 10 days open 48.75
# close 55.11
# change > 0.07, drop CLR
# prior 10 days open 216.3
# close 232.99
# change > 0.07, drop ILMN
# PNC has earning date, drop
# 2019-03-18 23:02:30.626048
# 2018-01-10
# prior 10 days open 49.7
# close 55.24
# change > 0.07, drop CLR
# PNC has earning date, drop
# WFC has earning date, drop
# 2019-03-18 23:02:34.322427
# 2018-01-11
# PNC has earning date, drop
# DAL has earning date, drop
# BBT has earning date, drop
# WFC has earning date, drop
# prior 10 days open 207.9523
# close 227.6146
# change > 0.07, drop MLM
# prior 10 days open 30.8892
# close 33.447959999999995
# change > 0.07, drop BHGE
# USB has earning date, drop
# BK has earning date, drop
# BLK has earning date, drop
# 2019-03-18 23:02:39.336763
# 2018-01-12
# PNC has earning date, drop
# BLK has earning date, drop
# DAL has earning date, drop
# BBT has earning date, drop
# prior 10 days open 288.4024
# WFC has earning date, drop
# close 310.7395
# change > 0.07, drop BA
# USB has earning date, drop
# JPM has earning date, drop
# prior 10 days open 31.238120000000002
# close 33.95195
# change > 0.07, drop BHGE
# BK has earning date, drop
# 2019-03-18 23:02:43.524423
# 2018-01-16
# prior 10 days open 39.832
# close 47.33586
# change > 0.07, drop SSNC
# PNC has earning date, drop
# BLK has earning date, drop
# FRC has earning date, drop
# DAL has earning date, drop
# prior 10 days open 289.2513
# close 312.5253
# change > 0.07, drop BA
# JPM has earning date, drop
# prior 10 days open 30.895529999999997
# close 28.18879
# change > 0.07, drop VIAB
# USB has earning date, drop
# BBT has earning date, drop
# CMA has earning date, drop
# BAC has earning date, drop
# 2019-03-18 23:02:47.249217
# 2018-01-17
# prior 10 days open 288.6658
# close 320.1955
# change > 0.07, drop BA
# BLK has earning date, drop
# FRC has earning date, drop
# prior 10 days open 139.1064
# close 151.119
# change > 0.07, drop CEO
# BAC has earning date, drop
# PNC has earning date, drop
# FAST has earning date, drop
# F has earning date, drop
# USB has earning date, drop
# 2019-03-18 23:02:49.944325
# 2018-01-18
# prior 10 days open 289.7686
# prior 10 days open 61.33
# close 65.93
# change > 0.07, drop PTC
# close 328.0901
# change > 0.07, drop BA
# prior 10 days open 138.2799
# close 154.963
# change > 0.07, drop CEO
# FRC has earning date, drop
# F has earning date, drop
# ASML has earning date, drop
# prior 10 days open 56.39286
# close 51.74929
# change > 0.07, drop VTR
# prior 10 days open 10.15057
# close 11.36983
# BLK has earning date, drop
# change > 0.07, drop PBR
# FAST has earning date, drop
# CNI has earning date, drop
# UNH has earning date, drop
# MS has earning date, drop
# KLAC has earning date, drop
# prior 10 days open 45.3193
# close 42.02932
# change > 0.07, drop SO
# PLD has earning date, drop
# BAC has earning date, drop
# PPG has earning date, drop
# TSM has earning date, drop
# 2019-03-18 23:02:53.782895
# 2018-01-19
# prior 10 days open 60.91
# close 65.29
# change > 0.07, drop PTC
# prior 10 days open 172.8612
# prior 10 days open 288.6073
# close 185.0113
# close 327.0655
# change > 0.07, drop ASML
# change > 0.07, drop BA
# KLAC has earning date, drop
# prior 10 days open 3.5583370000000003
# close 3.8349910000000005
# change > 0.07, drop LYG
# AXP has earning date, drop
# F has earning date, drop
# MS has earning date, drop
# IBM has earning date, drop
# CNI has earning date, drop
# TSM has earning date, drop
# prior 10 days open 56.704319999999996
# close 51.45671
# change > 0.07, drop VTR
# FAST has earning date, drop
# PPG has earning date, drop
# prior 10 days open 9.681319
# close 10.40395
# change > 0.07, drop IBN
# MTB has earning date, drop
# 2019-03-18 23:02:57.542628
# 2018-01-22
# prior 10 days open 61.3
# close 66.7
# change > 0.07, drop PTC
# prior 10 days open 288.7927
# close 342.5327
# change > 0.07, drop BA
# prior 10 days open 148.7975
# AXP has earning date, drop
# prior 10 days open 176.4248
# close 159.4934
# close 197.7173
# change > 0.07, drop IBM
# change > 0.07, drop ASML
# WYNN has earning date, drop
# TSM has earning date, drop
# HAL has earning date, drop
# prior 10 days open 102.3146
# close 109.6891
# change > 0.07, drop KLAC
# prior 10 days open 133.8649
# close 143.7676
# change > 0.07, drop ODFL
# MS has earning date, drop
# prior 10 days open 66.91698000000001
# close 73.84108
# change > 0.07, drop SLB
# MTB has earning date, drop
# prior 10 days open 56.562740000000005
# close 51.89087
# change > 0.07, drop VTR
# PPG has earning date, drop
# 2019-03-18 23:03:01.866527
# 2018-01-23
# prior 10 days open 159.1093
# close 171.092
# change > 0.07, drop WYNN
# RMD has earning date, drop
# prior 10 days open 65.62231
# close 70.45775
# change > 0.07, drop LVS
# NFLX has earning date, drop
# HAL has earning date, drop
# prior 10 days open 179.1646
# close 201.8666
# change > 0.07, drop ASML
# JNJ has earning date, drop
# AMTD has earning date, drop
# 2019-03-18 23:03:04.688521
# 2018-01-24
# prior 10 days open 65.66054
# close 71.20313
# change > 0.07, drop LVS
# prior 10 days open 160.3573
# close 175.148
# change > 0.07, drop WYNN
# prior 10 days open 105.1457
# close 113.0099
# change > 0.07, drop TXN
# RMD has earning date, drop
# TEL has earning date, drop
# HAL has earning date, drop
# SYMC has earning date, drop
# FFIV has earning date, drop
# NFLX has earning date, drop
# prior 10 days open 10.89402
# close 12.0538
# change > 0.07, drop PBR
# GIB has earning date, drop
# RJF has earning date, drop
# JNJ has earning date, drop
# ITW has earning date, drop
# EDU has earning date, drop
# LRCX has earning date, drop
# TSM has earning date, drop
# GD has earning date, drop
# PG has earning date, drop
# SPG has earning date, drop
# GWW has earning date, drop
# SHW has earning date, drop
# AMTD has earning date, drop
# 2019-03-18 23:03:09.676184
# 2018-01-25
# prior 10 days open 65.0585
# close 73.67818
# change > 0.07, drop LVS
# RMD has earning date, drop
# prior 10 days open 105.0006
# VAR has earning date, drop
# close 115.5346
# change > 0.07, drop TXN
# prior 10 days open 10.963410000000001
# GWW has earning date, drop
# close 12.14302
# change > 0.07, drop PBR
# FFIV has earning date, drop
# RJF has earning date, drop
# TEL has earning date, drop
# UNP has earning date, drop
# prior 10 days open 10.12745
# close 11.22048
# change > 0.07, drop PBR.A
# prior 10 days open 10.56051
# close 11.33417
# change > 0.07, drop BBD
# LRCX has earning date, drop
# prior 10 days open 10.33307
# close 11.22204
# change > 0.07, drop BCS
# JNJ has earning date, drop
# ITW has earning date, drop
# GD has earning date, drop
# SHW has earning date, drop
# TSS has earning date, drop
# prior 10 days open 210.02
# close 227.58
# change > 0.07, drop NFLX
# prior 10 days open 12.11304
# close 11.02185
# change > 0.07, drop F
# NEE has earning date, drop
# prior 10 days open 160.0161
# close 190.3481
# change > 0.07, drop WYNN
# PG has earning date, drop
# ROL has earning date, drop
# EDU has earning date, drop
# prior 10 days open 69.37
# close 76.87
# change > 0.07, drop UAL
# prior 10 days open 28.915470000000003
# close 26.1026
# change > 0.07, drop SYMC
# CAT has earning date, drop
# HON has earning date, drop
# D has earning date, drop
# ABT has earning date, drop
# prior 10 days open 41.247679999999995
# close 45.11951
# change > 0.07, drop TSM
# 2019-03-18 23:03:14.301193
# 2018-01-26
# prior 10 days open 11.10219
# close 11.94477
# change > 0.07, drop PBR
# prior 10 days open 158.8266
# close 190.0751
# change > 0.07, drop WYNN
# prior 10 days open 106.0357
# close 115.9698
# change > 0.07, drop TXN
# VAR has earning date, drop
# HON has earning date, drop
# TSS has earning date, drop
# SBUX has earning date, drop
# GWW has earning date, drop
# UNP has earning date, drop
# prior 10 days open 193.9674
# close 210.4559
# change > 0.07, drop LRCX
# prior 10 days open 10.42512
# close 11.26648
# change > 0.07, drop BBD
# NEE has earning date, drop
# prior 10 days open 10.204830000000001
# close 10.96898
# change > 0.07, drop PBR.A
# MKC has earning date, drop
# APD has earning date, drop
# D has earning date, drop
# prior 10 days open 10.38087
# close 11.22204
# change > 0.07, drop BCS
# FFIV has earning date, drop
# TEL has earning date, drop
# ITW has earning date, drop
# prior 10 days open 6.462505
# close 7.0361
# change > 0.07, drop SAN
# CL has earning date, drop
# prior 10 days open 12.08553
# close 10.96684
# change > 0.07, drop F
# ROL has earning date, drop
# GD has earning date, drop
# SHW has earning date, drop
# ABT has earning date, drop
# prior 10 days open 65.93767
# close 74.21333
# change > 0.07, drop LVS
# CAT has earning date, drop
# MMM has earning date, drop
# LUV has earning date, drop
# EQR has earning date, drop
# 2019-03-18 23:03:19.556475
# 2018-01-29
# prior 10 days open 10.33808
# close 12.21422
# change > 0.07, drop BBD
# prior 10 days open 158.1051
# close 195.5644
# change > 0.07, drop WYNN
# prior 10 days open 11.042710000000001
# close 12.97568
# change > 0.07, drop PBR
# LMT has earning date, drop
# APD has earning date, drop
# UNP has earning date, drop
# SBUX has earning date, drop
# VAR has earning date, drop
# MKC has earning date, drop
# prior 10 days open 190.1706
# close 205.2304
# change > 0.07, drop LRCX
# ABBV has earning date, drop
# HON has earning date, drop
# prior 10 days open 9.587503
# close 10.78594
# prior 10 days open 10.156460000000001
# change > 0.07, drop BSBR
# close 11.849210000000001
# change > 0.07, drop PBR.A
# CL has earning date, drop
# NOC has earning date, drop
# PFE has earning date, drop
# MMM has earning date, drop
# D has earning date, drop
# CAT has earning date, drop
# FFIV has earning date, drop
# 2019-03-18 23:03:23.415511
# 2018-01-30
# prior 10 days open 10.41545
# close 12.45599
# change > 0.07, drop BBD
# prior 10 days open 95.15938
# close 103.711
# change > 0.07, drop ABBV
# prior 10 days open 84.06955
# close 91.46948
# change > 0.07, drop HCA
# PFE has earning date, drop
# prior 10 days open 157.9491
# close 195.5839
# change > 0.07, drop WYNN
# LMT has earning date, drop
# SBUX has earning date, drop
# CL has earning date, drop
# SAP has earning date, drop
# MXIM has earning date, drop
# MCD has earning date, drop
# NOC has earning date, drop
# SYK has earning date, drop
# MMC has earning date, drop
# EQR has earning date, drop
# prior 10 days open 24.3
# close 22.16
# change > 0.07, drop TWTR
# SIRI has earning date, drop
# HRS has earning date, drop
# prior 10 days open 220.356
# close 240.9978
# change > 0.07, drop UNH
# LLY has earning date, drop
# LH has earning date, drop
# GILD has earning date, drop
# AAPL has earning date, drop
# 2019-03-18 23:03:27.233871
# 2018-01-31
# LLY has earning date, drop
# SAP has earning date, drop
# prior 10 days open 86.07965
# close 95.64734
# change > 0.07, drop HCA
# PFE has earning date, drop
# prior 10 days open 158.7583
# close 175.7817
# change > 0.07, drop WYNN
# EA has earning date, drop
# HRS has earning date, drop
# BXP has earning date, drop
# prior 10 days open 132.79
# close 150
# change > 0.07, drop VMW
# prior 10 days open 10.550839999999999
# close 12.6494
# change > 0.07, drop BBD
# LMT has earning date, drop
# SYK has earning date, drop
# prior 10 days open 223.5702
# close 244.2317
# change > 0.07, drop UNH
# MSFT has earning date, drop
# MMC has earning date, drop
# MCD has earning date, drop
# prior 10 days open 303.9357
# close 328.9957
# change > 0.07, drop NOC
# prior 10 days open 52.565690000000004
# close 56.81138000000001
# change > 0.07, drop MXIM
# prior 10 days open 1273.39
# close 1402.05
# change > 0.07, drop AMZN
# AAPL has earning date, drop
# HSY has earning date, drop
# 2019-03-18 23:03:31.461074
# 2018-02-01
# prior 10 days open 87.72516999999999
# close 96.18929
# change > 0.07, drop HCA
# prior 10 days open 37.92817
# close 40.648
# change > 0.07, drop EBAY
# HRS has earning date, drop
# EA has earning date, drop
# BXP has earning date, drop
# LLY has earning date, drop
# OTEX has earning date, drop
# GIB has earning date, drop
# TRI has earning date, drop
# prior 10 days open 1323
# close 1417.68
# change > 0.07, drop AMZN
# NOK has earning date, drop
# MSFT has earning date, drop
# PFE has earning date, drop
# SYK has earning date, drop
# HSY has earning date, drop
# MMC has earning date, drop
# prior 10 days open 5.440706
# close 5.9263069999999995
# change > 0.07, drop SIRI
# AAPL has earning date, drop
# ADP has earning date, drop
# SAP has earning date, drop
# NOC has earning date, drop
# FB has earning date, drop
# ANTM has earning date, drop
# 2019-03-18 23:03:35.202519
# 2018-02-02
# prior 10 days open 219.11
# close 235.06
# change > 0.07, drop ABMD
# BXP has earning date, drop
# prior 10 days open 1312.24
# close 1437.82
# change > 0.07, drop AMZN
# OTEX has earning date, drop
# EBAY has earning date, drop
# EA has earning date, drop
# MSFT has earning date, drop
# NOK has earning date, drop
# GIB has earning date, drop
# CNHI has earning date, drop
# prior 10 days open 183.3
# close 199.66
# change > 0.07, drop BABA
# NOW has earning date, drop
# HRS has earning date, drop
# AAPL has earning date, drop
# V has earning date, drop
# LLY has earning date, drop
# prior 10 days open 5.3614239999999995
# close 5.8965760000000005
# change > 0.07, drop SIRI
# XOM has earning date, drop
# MSCI has earning date, drop
# PYPL has earning date, drop
# SYK has earning date, drop
# EW has earning date, drop
# FB has earning date, drop
# HSY has earning date, drop
# SNE has earning date, drop
# prior 10 days open 308.8281
# close 332.8194
# change > 0.07, drop NOC
# BA has earning date, drop
# 2019-03-18 23:03:39.571276
# 2018-02-05
# EBAY has earning date, drop
# ABMD has earning date, drop
# prior 10 days open 1293.95
# close 1450.89
# change > 0.07, drop AMZN
# NOK has earning date, drop
# NOW has earning date, drop
# CNHI has earning date, drop
# OTEX has earning date, drop
# AAPL has earning date, drop
# XOM has earning date, drop
# prior 10 days open 184.28
# close 204.29
# change > 0.07, drop BABA
# CHD has earning date, drop
# UPS has earning date, drop
# V has earning date, drop
# MSCI has earning date, drop
# SNE has earning date, drop
# EW has earning date, drop
# XYL has earning date, drop
# ETN has earning date, drop
# GOOG has earning date, drop
# 2019-03-18 23:03:43.338712
# 2018-02-06
# prior 10 days open 141.23
# close 152.81
# CHD has earning date, drop
# change > 0.07, drop NOW
# XYL has earning date, drop
# XOM has earning date, drop
# AMZN has earning date, drop
# BMY has earning date, drop
# AAPL has earning date, drop
# SNE has earning date, drop
# prior 10 days open 227.33
# close 253.13
# change > 0.07, drop ABMD
# V has earning date, drop
# PSX has earning date, drop
# SGEN has earning date, drop
# GOOG has earning date, drop
# MSI has earning date, drop
# 2019-03-18 23:03:46.482091
# 2018-02-07
# SGEN has earning date, drop
# ULTI has earning date, drop
# SPG has earning date, drop
# SNAP has earning date, drop
# BMY has earning date, drop
# XYL has earning date, drop
# GOLD has earning date, drop
# CHD has earning date, drop
# prior 10 days open 1297.17
# close 1429.95
# change > 0.07, drop AMZN
# NOW has earning date, drop
# WMB has earning date, drop
# EQIX has earning date, drop
# XOM has earning date, drop
# CDW has earning date, drop
# FIS has earning date, drop
# 2019-03-18 23:03:49.326554
# 2018-02-08
# GRUB has earning date, drop
# prior 10 days open 120.0355
# close 111.413
# change > 0.07, drop BXP
# prior 10 days open 22.51
# close 25.13
# change > 0.07, drop TWTR
# SNAP has earning date, drop
# prior 10 days open 216.04
# close 196.8
# change > 0.07, drop BRK.B
# BDX has earning date, drop
# IAC has earning date, drop
# ULTI has earning date, drop
# SGEN has earning date, drop
# FIS has earning date, drop
# prior 10 days open 324500
# close 295600
# change > 0.07, drop BRK.A
# prior 10 days open 54.76211
# close 50.05032
# change > 0.07, drop ETFC
# prior 10 days open 179.8244
# close 164.16400000000002
# change > 0.07, drop SPGI
# prior 10 days open 83.80781
# close 75.70718000000001
# change > 0.07, drop XOM
# prior 10 days open 157.4518
# close 146.3124
# change > 0.07, drop SPG
# EQIX has earning date, drop
# 2019-03-18 23:03:52.259452
# 2018-02-09
# prior 10 days open 22.84
# close 25.24
# change > 0.07, drop TWTR
# prior 10 days open 120.4822
# close 111.9762
# change > 0.07, drop BXP
# SGEN has earning date, drop
# SNAP has earning date, drop
# IAC has earning date, drop
# EXPE has earning date, drop
# BDX has earning date, drop
# GRUB has earning date, drop
# 2019-03-18 23:03:54.357121
# 2018-02-12
# prior 10 days open 22.5
# close 26.91
# change > 0.07, drop TWTR
# EXPE has earning date, drop
# GRUB has earning date, drop
# prior 10 days open 235.8726
# close 218.422
# change > 0.07, drop BDX
# prior 10 days open 48.69144
# close 44.560520000000004
# change > 0.07, drop CNA
# 2019-03-18 23:03:56.341073
# 2018-02-13
# prior 10 days open 48.718090000000004
# close 43.04142
# change > 0.07, drop CNA
# prior 10 days open 102.3057
# close 89.57616999999999
# change > 0.07, drop ABC
# prior 10 days open 240.4493
# prior 10 days open 73.83892
# close 208.1072
# close 65.91882
# change > 0.07, drop ICE
# prior 10 days open 22.39
# change > 0.07, drop BDX
# close 30.18
# change > 0.07, drop TWTR
# EXPE has earning date, drop
# OMC has earning date, drop
# MTCH has earning date, drop
# prior 10 days open 132.21
# close 111.76
# change > 0.07, drop WB
# 2019-03-18 23:03:58.956503
# 2018-02-14
# prior 10 days open 102.8732
# close 87.26705
# change > 0.07, drop ABC
# prior 10 days open 140.3603
# close 129.2701
# change > 0.07, drop IEX
# prior 10 days open 242.4177
# close 213.7174
# change > 0.07, drop BDX
# prior 10 days open 78.91
# close 71.75
# change > 0.07, drop HSIC
# prior 10 days open 74.27181
# close 67.34541999999999
# change > 0.07, drop ICE
# prior 10 days open 131.87
# close 115.35
# change > 0.07, drop WB
# OMC has earning date, drop
# 2019-03-18 23:04:01.130611
# 2018-02-15
# prior 10 days open 146.4732
# close 130.9786
# change > 0.07, drop IEX
# prior 10 days open 99.80086999999999
# close 87.52145
# change > 0.07, drop ABC
# prior 10 days open 127.52
# close 118.31
# change > 0.07, drop WB
# OMC has earning date, drop
# prior 10 days open 239.2682
# close 215.4398
# change > 0.07, drop BDX
# prior 10 days open 34.63
# close 37.99
# change > 0.07, drop MTCH
# CSCO has earning date, drop
# YNDX has earning date, drop
# ANET has earning date, drop
# prior 10 days open 78.85
# close 72.18
# change > 0.07, drop HSIC
# prior 10 days open 73.0715
# close 67.493
# change > 0.07, drop ICE
# prior 10 days open 125.1548
# close 102.0573
# change > 0.07, drop UPS
# HII has earning date, drop
# 2019-03-18 23:04:03.398478
# 2018-02-16
# prior 10 days open 74.43271999999999
# close 67.89075
# change > 0.07, drop KHC
# prior 10 days open 239.9276
# close 212.0048
# change > 0.07, drop BDX
# YNDX has earning date, drop
# ANET has earning date, drop
# OMC has earning date, drop
# HII has earning date, drop
# CSCO has earning date, drop
# WB has earning date, drop
# prior 10 days open 35.1
# close 39.6
# change > 0.07, drop MTCH
# prior 10 days open 123.3596
# close 103.2573
# change > 0.07, drop UPS
# ZTS has earning date, drop
# NTAP has earning date, drop
# VFC has earning date, drop
# KO has earning date, drop
# 2019-03-18 23:04:06.079709
# 2018-02-20
# prior 10 days open 273.2
# close 302.12
# change > 0.07, drop ANET
# prior 10 days open 238
# close 255.47
# change > 0.07, drop ABMD
# HII has earning date, drop
# prior 10 days open 29.99865
# close 26.04241
# change > 0.07, drop NBL
# prior 10 days open 73.95935
# close 68.08955999999999
# change > 0.07, drop KHC
# YNDX has earning date, drop
# CNA has earning date, drop
# WMT has earning date, drop
# CSCO has earning date, drop
# ZTS has earning date, drop
# 2019-03-18 23:04:08.679951
# 2018-02-21
# prior 10 days open 29.606509999999997
# close 25.95384
# change > 0.07, drop NBL
# prior 10 days open 272.15
# prior 10 days open 45.71
# close 307.96
# close 49.28
# change > 0.07, drop ANET
# change > 0.07, drop FTNT
# WMT has earning date, drop
# KHC has earning date, drop
# HII has earning date, drop
# prior 10 days open 38.93
# close 41.96
# change > 0.07, drop YNDX
# prior 10 days open 193.4066
# close 179.8366
# change > 0.07, drop HD
# ZTS has earning date, drop
# MOS has earning date, drop
# VRSK has earning date, drop
# 2019-03-18 23:04:11.351979
# 2018-02-22
# prior 10 days open 44.27
# close 48.95
# change > 0.07, drop FTNT
# prior 10 days open 27.9007
# close 25.86526
# prior 10 days open 237.6548
# change > 0.07, drop NBL
# close 261.2856
# change > 0.07, drop HII
# prior 10 days open 89.37
# close 97.52
# change > 0.07, drop W
# MOS has earning date, drop
# WMT has earning date, drop
# prior 10 days open 424.6692
# close 391.93800000000005
# change > 0.07, drop EQIX
# prior 10 days open 37.43
# close 42.1
# change > 0.07, drop YNDX
# prior 10 days open 245
# close 267.74
# change > 0.07, drop ABMD
# prior 10 days open 38.928059999999995
# close 33.727109999999996
# change > 0.07, drop DVN
# VRSK has earning date, drop
# EQT has earning date, drop
# 2019-03-18 23:04:13.842513
# 2018-02-23
# prior 10 days open 51.51
# close 56.24
# change > 0.07, drop GDDY
# prior 10 days open 14.7803
# close 15.990210000000001
# change > 0.07, drop HPE
# prior 10 days open 13.13
# close 14.6
# change > 0.07, drop ANGI
# prior 10 days open 45.27
# close 49.06
# prior 10 days open 415.2716
# close 385.2713
# change > 0.07, drop FTNT
# change > 0.07, drop EQIX
# prior 10 days open 87.78
# close 96.3
# change > 0.07, drop W
# prior 10 days open 24.09176
# close 26.629309999999997
# change > 0.07, drop MOS
# WMT has earning date, drop
# EQT has earning date, drop
# prior 10 days open 17.48155
# close 18.74749
# change > 0.07, drop RF
# 2019-03-18 23:04:15.828920
# 2018-02-26
# prior 10 days open 40.14571
# close 36.26567
# change > 0.07, drop APA
# prior 10 days open 13.6
# close 15.06
# change > 0.07, drop ANGI
# prior 10 days open 417.8858
# close 374.0758
# change > 0.07, drop EQIX
# HPE has earning date, drop
# W has earning date, drop
# GDDY has earning date, drop
# 2019-03-18 23:04:17.640379
# 2018-02-27
# HPE has earning date, drop
# PANW has earning date, drop
# GDDY has earning date, drop
# 2019-03-18 23:04:19.117042
# 2018-02-28
# prior 10 days open 154.61
# close 165.54
# change > 0.07, drop PANW
# prior 10 days open 104.0831
# close 116.6026
# prior 10 days open 105.32
# change > 0.07, drop ALB
# close 114.96
# change > 0.07, drop CRM
# prior 10 days open 22.78643
# close 25.16766
# change > 0.07, drop M
# LOW has earning date, drop
# TJX has earning date, drop
# 2019-03-18 23:04:20.863455
# 2018-03-01
# prior 10 days open 22.98408
# close 25.835910000000002
# change > 0.07, drop M
# prior 10 days open 107.7
# close 116.65
# change > 0.07, drop CRM
# prior 10 days open 55.91
# close 62.1
# change > 0.07, drop VEEV
# LOW has earning date, drop
# MNST has earning date, drop
# BBY has earning date, drop
# ALB has earning date, drop
# TJX has earning date, drop
# 2019-03-18 23:04:23.237603
# 2018-03-02
# prior 10 days open 108.01
# close 116.47
# change > 0.07, drop CRM
# LOW has earning date, drop
# TJX has earning date, drop
# prior 10 days open 56.37
# close 62.07
# change > 0.07, drop VEEV
# MNST has earning date, drop
# ALB has earning date, drop
# BF.B has earning date, drop
# BBY has earning date, drop
# 2019-03-18 23:04:25.086789
# 2018-03-05
# KEYS has earning date, drop
# MNST has earning date, drop
# 2019-03-18 23:04:26.372344
# 2018-03-06
# KEYS has earning date, drop
# UHS has earning date, drop
# 2019-03-18 23:04:27.942114
# 2018-03-07
# prior 10 days open 45.91
# close 49.42
# change > 0.07, drop KEYS
# prior 10 days open 43.29
# close 49.11
# change > 0.07, drop MU
# ADSK has earning date, drop
# UHS has earning date, drop
# DLTR has earning date, drop
# 2019-03-18 23:04:30.446782
# 2018-03-08
# DLTR has earning date, drop
# prior 10 days open 45.59
# close 50.54
# change > 0.07, drop KEYS
# prior 10 days open 44.02
# close 52.03
# change > 0.07, drop MU
# ADSK has earning date, drop
# BURL has earning date, drop
# KR has earning date, drop
# 2019-03-18 23:04:32.842634
# 2018-03-09
# prior 10 days open 25.6523
# close 27.82572
# change > 0.07, drop BHGE
# DLTR has earning date, drop
# KR has earning date, drop
# BURL has earning date, drop
# MRVL has earning date, drop
# ADSK has earning date, drop
# prior 10 days open 45.88
# close 52.55
# change > 0.07, drop KEYS
# 2019-03-18 23:04:35.330113
# 2018-03-12
# prior 10 days open 44.78
# close 53.97
# change > 0.07, drop MU
# KR has earning date, drop
# COO has earning date, drop
# 2019-03-18 23:04:36.881284
# 2018-03-13
# prior 10 days open 193.1079
# close 171.918
# change > 0.07, drop CI
# prior 10 days open 45.18
# close 55.22
# change > 0.07, drop MU
# 2019-03-18 23:04:38.527963
# 2018-03-14
# prior 10 days open 64.04
# close 74.36
# change > 0.07, drop SRPT
# prior 10 days open 46.97
# close 54.59
# change > 0.07, drop MU
# TIF has earning date, drop
# 2019-03-18 23:04:40.489092
# 2018-03-15
# prior 10 days open 6.621169
# close 7.087175
# change > 0.07, drop ABEV
# prior 10 days open 64.9
# close 79.1
# change > 0.07, drop SRPT
# prior 10 days open 47.66
# close 59.37
# change > 0.07, drop MU
# TIF has earning date, drop
# CTRP has earning date, drop
# 2019-03-18 23:04:42.281515
# 2018-03-16
# prior 10 days open 64.78
# close 80.9
# change > 0.07, drop SRPT
# ULTA has earning date, drop
# ADBE has earning date, drop
# TIF has earning date, drop
# 2019-03-18 23:04:44.085231
# 2018-03-19
# TIF has earning date, drop
# ULTA has earning date, drop
# ADBE has earning date, drop
# ORCL has earning date, drop
# 2019-03-18 23:04:46.802252
# 2018-03-20
# prior 10 days open 140.61
# close 156.53
# change > 0.07, drop BGNE
# prior 10 days open 113.97
# close 125.31
# change > 0.07, drop VRSN
# ORCL has earning date, drop
# prior 10 days open 55.2555
# close 59.27933
# prior 10 days open 203.96
# change > 0.07, drop PGR
# close 218.87
# change > 0.07, drop ADBE
# 2019-03-18 23:04:49.190283
# 2018-03-21
# ORCL has earning date, drop
# prior 10 days open 147.43
# close 158.15
# change > 0.07, drop BGNE
# FDX has earning date, drop
# GIS has earning date, drop
# prior 10 days open 55.178490000000004
# close 59.60661999999999
# change > 0.07, drop PGR
# 2019-03-18 23:04:51.271093
# 2018-03-22
# prior 10 days open 152.62
# close 163.61
# change > 0.07, drop BGNE
# FDX has earning date, drop
# ORCL has earning date, drop
# GIS has earning date, drop
# 2019-03-18 23:04:53.835360
# 2018-03-23
# prior 10 days open 53.34
# close 61.15
# change > 0.07, drop MU
# GIS has earning date, drop
# 2019-03-18 23:04:55.513022
# 2018-03-26
# prior 10 days open 66.29894
# close 71.25286
# change > 0.07, drop MPC
# prior 10 days open 183.56
# prior 10 days open 54.58
# close 169.39
# close 61.07
# change > 0.07, drop FB
# change > 0.07, drop MU
# RHT has earning date, drop
# 2019-03-18 23:04:57.105348
# 2018-03-27
# prior 10 days open 183.91
# close 164.89
# change > 0.07, drop FB
# RHT has earning date, drop
# PAYX has earning date, drop
# 2019-03-18 23:04:58.778010
# 2018-03-28
# prior 10 days open 172.195
# close 157.4369
# change > 0.07, drop QQQ
# prior 10 days open 328.61
# close 301.54
# change > 0.07, drop TSLA
# RHT has earning date, drop
# prior 10 days open 185.23
# close 159.39
# change > 0.07, drop FB
# LULU has earning date, drop
# INFO has earning date, drop
# 2019-03-18 23:05:00.530596
# 2018-03-29
# prior 10 days open 64.04
# close 70.17
# change > 0.07, drop DXCM
# prior 10 days open 344.92
# close 304.18
# change > 0.07, drop TSLA
# RHT has earning date, drop
# PVH has earning date, drop
# LULU has earning date, drop
# 2019-03-18 23:05:02.406696
# 2018-04-02
# prior 10 days open 336.76
# close 279.18
# change > 0.07, drop TSLA
# prior 10 days open 65.1
# close 69.99
# change > 0.07, drop DXCM
# prior 10 days open 171.13400000000001
# close 158.003
# change > 0.07, drop QQQ
# LULU has earning date, drop
# PVH has earning date, drop
# prior 10 days open 45.4
# close 42.04
# change > 0.07, drop LYV
# WBA has earning date, drop
# 2019-03-18 23:05:04.843566
# 2018-04-03
# prior 10 days open 170.3903
# close 156.1854
# change > 0.07, drop QQQ
# prior 10 days open 329.38
# close 257.78
# change > 0.07, drop TSLA
# prior 10 days open 4.226635
# close 3.8301540000000003
# change > 0.07, drop WIT
# 2019-03-18 23:05:06.716058
# 2018-04-04
# prior 10 days open 4.211673
# close 3.8600769999999995
# change > 0.07, drop WIT
# prior 10 days open 75.64955
# close 81.73737
# change > 0.07, drop SNP
# prior 10 days open 45.63
# close 42.14
# change > 0.07, drop LYV
# prior 10 days open 325.96
# close 266.13
# change > 0.07, drop TSLA
# 2019-03-18 23:05:08.472452
# 2018-04-05
# prior 10 days open 316.5
# close 252.48
# change > 0.07, drop TSLA
# LEN has earning date, drop
# 2019-03-18 23:05:10.165300
# 2018-04-06
# prior 10 days open 314.87
# close 267.53
# change > 0.07, drop TSLA
# LEN has earning date, drop
# 2019-03-18 23:05:12.028644
# 2018-04-09
# prior 10 days open 212.0868
# close 229.4182
# change > 0.07, drop BAP
# prior 10 days open 29.496440000000003
# close 31.631190000000004
# change > 0.07, drop CNQ
# 2019-03-18 23:05:14.418163
# 2018-04-10
# prior 10 days open 216.4712
# close 232.5765
# change > 0.07, drop BAP
# 2019-03-18 23:05:16.278848
# 2018-04-11
# prior 10 days open 214.382
# close 230.1833
# change > 0.07, drop BAP
# USB has earning date, drop
# 2019-03-18 23:05:18.252557
# 2018-04-12
# prior 10 days open 41.82
# close 34.66
# change > 0.07, drop YNDX
# USB has earning date, drop
# 2019-03-18 23:05:20.754054
# 2018-04-13
# JPM has earning date, drop
# USB has earning date, drop
# 2019-03-18 23:05:22.300774
# 2018-04-16
# prior 10 days open 63.208780000000004
# close 68.6902
# change > 0.07, drop OXY
# JPM has earning date, drop
# JBHT has earning date, drop
# 2019-03-18 23:05:23.956425
# 2018-04-17
# prior 10 days open 287
# close 309.25
# change > 0.07, drop NFLX
# prior 10 days open 88.14269
# close 97.13861999999999
# change > 0.07, drop VLO
# prior 10 days open 60.92805
# close 68.78603000000001
# change > 0.07, drop OXY
# PNC has earning date, drop
# JBHT has earning date, drop
# JPM has earning date, drop
# CE has earning date, drop
# prior 10 days open 57.753
# close 62.17739
# change > 0.07, drop COP
# prior 10 days open 35.953509999999994
# close 40.407920000000004
# change > 0.07, drop NOV
# 2019-03-18 23:05:26.344599
# 2018-04-18
# prior 10 days open 20.902179999999998
# close 22.62107
# change > 0.07, drop PAA
# prior 10 days open 89.13794
# close 98.39475999999999
# change > 0.07, drop VLO
# prior 10 days open 62.154669999999996
# close 70.55886
# change > 0.07, drop OXY
# CE has earning date, drop
# JBHT has earning date, drop
# MS has earning date, drop
# NFLX has earning date, drop
# DGX has earning date, drop
# prior 10 days open 36.41088
# close 40.68633
# change > 0.07, drop NOV
# prior 10 days open 8.295214
# close 9.926738
# change > 0.07, drop CVE
# IBM has earning date, drop
# TXT has earning date, drop
# 2019-03-18 23:05:29.134077
# 2018-04-19
# prior 10 days open 20.44634
# close 23.62772
# change > 0.07, drop PAA
# PM has earning date, drop
# MAS has earning date, drop
# URI has earning date, drop
# TXT has earning date, drop
# SNA has earning date, drop
# AXP has earning date, drop
# MS has earning date, drop
# prior 10 days open 60.608880000000006
# close 52.9313
# change > 0.07, drop BMY
# prior 10 days open 96.55233
# close 104.2416
# change > 0.07, drop CE
# prior 10 days open 30.17329
# close 33.30355
# change > 0.07, drop DVN
# prior 10 days open 34.29091
# close 36.9539
# change > 0.07, drop E
# ISRG has earning date, drop
# prior 10 days open 8.265728999999999
# close 9.739997
# change > 0.07, drop CVE
# IBM has earning date, drop
# LRCX has earning date, drop
# KMI has earning date, drop
# LUV has earning date, drop
# 2019-03-18 23:05:31.834069
# 2018-04-20
# prior 10 days open 20.42734
# close 24.10255
# change > 0.07, drop PAA
# prior 10 days open 6.02
# close 6.52
# change > 0.07, drop ERIC
# prior 10 days open 30.40113
# close 33.372890000000005
# change > 0.07, drop DVN
# prior 10 days open 54.783669999999994
# close 59.88075
# change > 0.07, drop TRU
# PM has earning date, drop
# prior 10 days open 165.05
# close 177.54
# change > 0.07, drop URI
# SNA has earning date, drop
# TXT has earning date, drop
# AXP has earning date, drop
# MAS has earning date, drop
# ROP has earning date, drop
# prior 10 days open 52
# close 62.06
# change > 0.07, drop TEAM
# prior 10 days open 398
# close 435.45
# change > 0.07, drop ISRG
# MO has earning date, drop
# 2019-03-18 23:05:34.316712
# 2018-04-23
# prior 10 days open 21.14909
# close 23.38081
# change > 0.07, drop PAA
# ERIC has earning date, drop
# TRU has earning date, drop
# MO has earning date, drop
# KMB has earning date, drop
# MAS has earning date, drop
# PM has earning date, drop
# HAS has earning date, drop
# CDNS has earning date, drop
# prior 10 days open 58.58051999999999
# close 63.9033
# change > 0.07, drop TXT
# SNA has earning date, drop
# ROP has earning date, drop
# AMP has earning date, drop
# BX has earning date, drop
# GOOG has earning date, drop
# URI has earning date, drop
# AMTD has earning date, drop
# PG has earning date, drop
# prior 10 days open 35.01455
# close 37.80297
# change > 0.07, drop E
# TSM has earning date, drop
# RCI has earning date, drop
# AXP has earning date, drop
# ETFC has earning date, drop
# 2019-03-18 23:05:37.930037
# 2018-04-24
# prior 10 days open 97.30478000000001
# close 82.00336
# change > 0.07, drop PM
# TRU has earning date, drop
# GOOG has earning date, drop
# ERIC has earning date, drop
# BP has earning date, drop
# WAB has earning date, drop
# prior 10 days open 61.865840000000006
# close 55.43747
# change > 0.07, drop MO
# CDNS has earning date, drop
# KMB has earning date, drop
# AMTD has earning date, drop
# FITB has earning date, drop
# HAS has earning date, drop
# AMP has earning date, drop
# PG has earning date, drop
# prior 10 days open 52.7682
# close 57.006769999999996
# change > 0.07, drop MRK
# prior 10 days open 50.80295
# close 57.06391
# change > 0.07, drop HFC
# BX has earning date, drop
# URI has earning date, drop
# AGR has earning date, drop
# CAT has earning date, drop
# ROP has earning date, drop
# prior 10 days open 35.33295
# close 38.015240000000006
# change > 0.07, drop E
# CSGP has earning date, drop
# LMT has earning date, drop
# MAS has earning date, drop
# MMM has earning date, drop
# RF has earning date, drop
# CL has earning date, drop
# PEP has earning date, drop
# CFG has earning date, drop
# prior 10 days open 17.566489999999998
# close 19.35625
# change > 0.07, drop FCX
# GE has earning date, drop
# TECK has earning date, drop
# PHG has earning date, drop
# 2019-03-18 23:05:43.883082
# 2018-04-25
# prior 10 days open 80.46044
# close 87.06436
# change > 0.07, drop WAB
# prior 10 days open 104.8897
# close 96.45259
# change > 0.07, drop KMB
# GOOG has earning date, drop
# AMP has earning date, drop
# FITB has earning date, drop
# AMTD has earning date, drop
# CSGP has earning date, drop
# MMM has earning date, drop
# CDNS has earning date, drop
# HAS has earning date, drop
# NSC has earning date, drop
# BP has earning date, drop
# prior 10 days open 61.29975
# close 54.90976
# change > 0.07, drop MO
# EW has earning date, drop
# CHKP has earning date, drop
# LMT has earning date, drop
# ES has earning date, drop
# prior 10 days open 17.21141
# close 19.14855
# change > 0.07, drop FCX
# MAS has earning date, drop
# PG has earning date, drop
# CAT has earning date, drop
# prior 10 days open 56.36655
# close 66.5408
# change > 0.07, drop TRU
# MRK has earning date, drop
# VZ has earning date, drop
# T has earning date, drop
# prior 10 days open 97.17071999999999
# close 80.69153
# change > 0.07, drop PM
# URI has earning date, drop
# PEP has earning date, drop
# prior 10 days open 51.93952
# close 57.0835
# change > 0.07, drop HFC
# VRSK has earning date, drop
# TMUS has earning date, drop
# AWK has earning date, drop
# EXC has earning date, drop
# BX has earning date, drop
# NDAQ has earning date, drop
# NOW has earning date, drop
# AGR has earning date, drop
# RTN has earning date, drop
# SHW has earning date, drop
# WAT has earning date, drop
# prior 10 days open 59.61623
# close 50.08311
# change > 0.07, drop BMY
# CFG has earning date, drop
# prior 10 days open 92.58751
# close 104.8881
# change > 0.07, drop VLO
# prior 10 days open 6.22
# close 7.78
# change > 0.07, drop ERIC
# JCI has earning date, drop
# KO has earning date, drop
# RF has earning date, drop
# AAPL has earning date, drop
# STM has earning date, drop
# prior 10 days open 1425.03
# close 1527.49
# change > 0.07, drop AMZN
# COF has earning date, drop
# prior 10 days open 12.8309
# close 14.241320000000002
# change > 0.07, drop GE
# XOM has earning date, drop
# IR has earning date, drop
# YNDX has earning date, drop
# ANTM has earning date, drop
# prior 10 days open 168.9045
# close 194.7707
# change > 0.07, drop PXD
# ALGN has earning date, drop
# TROW has earning date, drop
# DPZ has earning date, drop
# CL has earning date, drop
# LLL has earning date, drop
# PHG has earning date, drop
# PCAR has earning date, drop
# TECK has earning date, drop
# 2019-03-18 23:05:52.252722
# 2018-04-26
# prior 10 days open 80.61957
# close 87.56165
# change > 0.07, drop WAB
# LMT has earning date, drop
# CHKP has earning date, drop
# RTN has earning date, drop
# ES has earning date, drop
# GOOG has earning date, drop
# ORLY has earning date, drop
# MMM has earning date, drop
# NSC has earning date, drop
# FITB has earning date, drop
# NDAQ has earning date, drop
# EW has earning date, drop
# AMP has earning date, drop
# CSGP has earning date, drop
# LKQ has earning date, drop
# MAS has earning date, drop
# SHW has earning date, drop
# T has earning date, drop
# prior 10 days open 61.43407
# close 54.27652
# change > 0.07, drop MO
# CMG has earning date, drop
# VRSK has earning date, drop
# DPZ has earning date, drop
# FCX has earning date, drop
# JCI has earning date, drop
# CDNS has earning date, drop
# BP has earning date, drop
# AWK has earning date, drop
# AMZN has earning date, drop
# prior 10 days open 51.78253
# close 47.94011
# change > 0.07, drop QCOM
# VZ has earning date, drop
# CHTR has earning date, drop
# AMD has earning date, drop
# TMUS has earning date, drop
# NOW has earning date, drop
# INTC has earning date, drop
# prior 10 days open 52.77236
# close 57.88695
# change > 0.07, drop HFC
# TROW has earning date, drop
# PG has earning date, drop
# DWDP has earning date, drop
# CFG has earning date, drop
# ALGN has earning date, drop
# STM has earning date, drop
# V has earning date, drop
# ANTM has earning date, drop
# prior 10 days open 49.99627
# close 46.19608
# change > 0.07, drop AAL
# CTXS has earning date, drop
# prior 10 days open 171.5721
# close 197.1685
# change > 0.07, drop PXD
# prior 10 days open 60.05667
# close 49.81885
# change > 0.07, drop BMY
# XOM has earning date, drop
# PEP has earning date, drop
# CAT has earning date, drop
# prior 10 days open 22.32668
# close 23.93161
# change > 0.07, drop PAA
# MSFT has earning date, drop
# WAT has earning date, drop
# prior 10 days open 96.95049
# close 80.11701
# change > 0.07, drop PM
# IR has earning date, drop
# KO has earning date, drop
# prior 10 days open 12.74275
# close 14.221729999999999
# change > 0.07, drop GE
# COF has earning date, drop
# prior 10 days open 70.99009000000001
# close 77.71535
# change > 0.07, drop MPC
# F has earning date, drop
# FTV has earning date, drop
# ARNC has earning date, drop
# LUV has earning date, drop
# AAPL has earning date, drop
# LLL has earning date, drop
# BDX has earning date, drop
# KEY has earning date, drop
# prior 10 days open 94.08521999999999
# close 105.5741
# change > 0.07, drop VLO
# WY has earning date, drop
# BX has earning date, drop
# prior 10 days open 142.49
# close 157.72
# change > 0.07, drop FFIV
# prior 10 days open 66.98444
# close 74.01829000000001
# change > 0.07, drop OXY
# BA has earning date, drop
# BSX has earning date, drop
# ECL has earning date, drop
# EXC has earning date, drop
# 2019-03-18 23:06:01.595792
# 2018-04-27
# prior 10 days open 80.7787
# close 89.84914
# change > 0.07, drop WAB
# CHTR has earning date, drop
# SIVB has earning date, drop
# LKQ has earning date, drop
# WY has earning date, drop
# AMD has earning date, drop
# CTXS has earning date, drop
# ORLY has earning date, drop
# AAL has earning date, drop
# AMZN has earning date, drop
# CHKP has earning date, drop
# NSC has earning date, drop
# CMG has earning date, drop
# T has earning date, drop
# DPZ has earning date, drop
# NOW has earning date, drop
# INTC has earning date, drop
# RTN has earning date, drop
# NDAQ has earning date, drop
# V has earning date, drop
# TROW has earning date, drop
# SNE has earning date, drop
# MSFT has earning date, drop
# AWK has earning date, drop
# ALGN has earning date, drop
# FTV has earning date, drop
# MGM has earning date, drop
# JCI has earning date, drop
# prior 10 days open 61.549209999999995
# close 53.058009999999996
# change > 0.07, drop MO
# prior 10 days open 11.33601
# close 12.52719
# change > 0.07, drop ECA
# BP has earning date, drop
# VZ has earning date, drop
# LUV has earning date, drop
# XOM has earning date, drop
# MHK has earning date, drop
# prior 10 days open 39.92173
# close 35.797990000000006
# change > 0.07, drop MAS
# prior 10 days open 59.31281
# close 50.48441
# change > 0.07, drop BMY
# prior 10 days open 144.19
# close 157.14
# change > 0.07, drop FFIV
# F has earning date, drop
# DWDP has earning date, drop
# S has earning date, drop
# prior 10 days open 51.41252
# close 47.38035
# change > 0.07, drop QCOM
# prior 10 days open 52.97812
# close 59.17049
# change > 0.07, drop HFC
# UPS has earning date, drop
# CME has earning date, drop
# prior 10 days open 95.64090999999999
# close 104.6368
# change > 0.07, drop VLO
# GD has earning date, drop
# ANTM has earning date, drop
# SHW has earning date, drop
# PEP has earning date, drop
# prior 10 days open 175.95
# close 156.43
# change > 0.07, drop URI
# CVX has earning date, drop
# ARNC has earning date, drop
# LMT has earning date, drop
# prior 10 days open 177.4167
# close 195.8797
# change > 0.07, drop PXD
# BIDU has earning date, drop
# CMCSA has earning date, drop
# CNP has earning date, drop
# ITW has earning date, drop
# TMUS has earning date, drop
# EW has earning date, drop
# prior 10 days open 71.73949
# close 77.64721999999999
# change > 0.07, drop MPC
# BAX has earning date, drop
# EXPE has earning date, drop
# TFX has earning date, drop
# SBUX has earning date, drop
# 2019-03-18 23:06:09.612383
# 2018-04-30
# prior 10 days open 72.31373
# close 78.08521
# change > 0.07, drop MPC
# prior 10 days open 183.1914
# close 198.7171
# change > 0.07, drop PXD
# ARNC has earning date, drop
# FTV has earning date, drop
# LKQ has earning date, drop
# S has earning date, drop
# TMUS has earning date, drop
# MHK has earning date, drop
# RTN has earning date, drop
# ORLY has earning date, drop
# prior 10 days open 11.55439
# close 12.6066
# change > 0.07, drop ECA
# T has earning date, drop
# SNE has earning date, drop
# SIVB has earning date, drop
# FDC has earning date, drop
# ITW has earning date, drop
# LUV has earning date, drop
# AAL has earning date, drop
# AMZN has earning date, drop
# MCD has earning date, drop
# CMG has earning date, drop
# CTXS has earning date, drop
# CHTR has earning date, drop
# V has earning date, drop
# MGM has earning date, drop
# ANDX has earning date, drop
# DPZ has earning date, drop
# WY has earning date, drop
# INTC has earning date, drop
# MSFT has earning date, drop
# NEM has earning date, drop
# AMD has earning date, drop
# PEG has earning date, drop
# RCL has earning date, drop
# prior 10 days open 61.616369999999996
# close 53.576119999999996
# change > 0.07, drop MO
# BIDU has earning date, drop
# VTR has earning date, drop
# prior 10 days open 30.59368
# close 34.21931
# change > 0.07, drop BHGE
# VZ has earning date, drop
# CVX has earning date, drop
# XOM has earning date, drop
# AWK has earning date, drop
# NDAQ has earning date, drop
# BP has earning date, drop
# MA has earning date, drop
# YUM has earning date, drop
# BAX has earning date, drop
# prior 10 days open 97.25457
# close 105.0137
# change > 0.07, drop VLO
# WDC has earning date, drop
# prior 10 days open 146.6
# close 157.07
# change > 0.07, drop FFIV
# NOW has earning date, drop
# AME has earning date, drop
# CME has earning date, drop
# UPS has earning date, drop
# prior 10 days open 68.77644000000001
# close 74.13329
# change > 0.07, drop OXY
# prior 10 days open 53.683580000000006
# close 58.42584
# change > 0.07, drop HFC
# SBUX has earning date, drop
# CL has earning date, drop
# AEP has earning date, drop
# L has earning date, drop
# EXPE has earning date, drop
# F has earning date, drop
# AAPL has earning date, drop
# IP has earning date, drop
# REG has earning date, drop
# SYK has earning date, drop
# DWDP has earning date, drop
# SBAC has earning date, drop
# CMCSA has earning date, drop
# EOG has earning date, drop
# TPR has earning date, drop
# PSX has earning date, drop
# 2019-03-18 23:06:18.523543
# 2018-05-01
# MCD has earning date, drop
# S has earning date, drop
# SIVB has earning date, drop
# TPR has earning date, drop
# PEG has earning date, drop
# VTR has earning date, drop
# SBAC has earning date, drop
# MHK has earning date, drop
# YUM has earning date, drop
# prior 10 days open 38.5
# close 30.42
# change > 0.07, drop LKQ
# prior 10 days open 153.8179
# close 138.535
# change > 0.07, drop ITW
# ANDX has earning date, drop
# CHTR has earning date, drop
# prior 10 days open 31.42212
# close 35.06723
# change > 0.07, drop BHGE
# ARNC has earning date, drop
# TDG has earning date, drop
# AAPL has earning date, drop
# MA has earning date, drop
# prior 10 days open 183.3513
# close 200.5454
# change > 0.07, drop PXD
# prior 10 days open 72.46944
# close 80.71302
# change > 0.07, drop MPC
# prior 10 days open 11.68344
# close 12.65623
# change > 0.07, drop ECA
# TMUS has earning date, drop
# DISH has earning date, drop
# YUMC has earning date, drop
# FDC has earning date, drop
# SNE has earning date, drop
# VNO has earning date, drop
# ADM has earning date, drop
# EPD has earning date, drop
# prior 10 days open 195.67
# close 210.03
# change > 0.07, drop WCG
# MTCH has earning date, drop
# AME has earning date, drop
# BP has earning date, drop
# CBS has earning date, drop
# NBIX has earning date, drop
# NEM has earning date, drop
# CTXS has earning date, drop
# RTN has earning date, drop
# VZ has earning date, drop
# XYL has earning date, drop
# FFIV has earning date, drop
# INTC has earning date, drop
# CMCSA has earning date, drop
# LUV has earning date, drop
# XOM has earning date, drop
# MSFT has earning date, drop
# T has earning date, drop
# PFE has earning date, drop
# AMZN has earning date, drop
# L has earning date, drop
# WDC has earning date, drop
# STX has earning date, drop
# EFX has earning date, drop
# FIS has earning date, drop
# BAX has earning date, drop
# prior 10 days open 50.34
# close 46.74
# change > 0.07, drop SQ
# V has earning date, drop
# LMT has earning date, drop
# AFL has earning date, drop
# NDAQ has earning date, drop
# prior 10 days open 97.93095
# close 107.7772
# change > 0.07, drop VLO
# SYK has earning date, drop
# prior 10 days open 100.1988
# close 109.1632
# change > 0.07, drop PSX
# RCL has earning date, drop
# prior 10 days open 27.66333
# close 30.2657
# change > 0.07, drop M
# CVX has earning date, drop
# GD has earning date, drop
# IP has earning date, drop
# AKAM has earning date, drop
# REGN has earning date, drop
# CL has earning date, drop
# WY has earning date, drop
# ICE has earning date, drop
# SHOP has earning date, drop
# 2019-03-18 23:06:27.565129
# 2018-05-02
# prior 10 days open 72.97555
# close 79.25312
# change > 0.07, drop MPC
# prior 10 days open 38.71
# close 34.74
# change > 0.07, drop DISH
# prior 10 days open 172.4048
# close 159.8854
# change > 0.07, drop AAPL
# prior 10 days open 31.763240000000003
# close 35.086729999999996
# change > 0.07, drop BHGE
# prior 10 days open 153.3966
# close 139.6714
# change > 0.07, drop ITW
# TAP has earning date, drop
# TMUS has earning date, drop
# YUMC has earning date, drop
# TDG has earning date, drop
# prior 10 days open 81.24
# close 69.25
# change > 0.07, drop LBRDA
# MCD has earning date, drop
# ANDX has earning date, drop
# CDW has earning date, drop
# EPD has earning date, drop
# MA has earning date, drop
# PEG has earning date, drop
# CBS has earning date, drop
# FDC has earning date, drop
# VNO has earning date, drop
# prior 10 days open 5.78
# close 6.5
# change > 0.07, drop S
# MTCH has earning date, drop
# TPR has earning date, drop
# SBAC has earning date, drop
# FLT has earning date, drop
# PXD has earning date, drop
# YUM has earning date, drop
# ARNC has earning date, drop
# BUD has earning date, drop
# PFE has earning date, drop
# FIS has earning date, drop
# prior 10 days open 61.91568
# close 68.42479
# change > 0.07, drop CVS
# PFG has earning date, drop
# LUV has earning date, drop
# prior 10 days open 38.55
# prior 10 days open 195.26
# close 209.22
# close 31.65
# change > 0.07, drop WCG
# change > 0.07, drop LKQ
# EFX has earning date, drop
# W has earning date, drop
# prior 10 days open 94.88141999999999
# close 102.5903
# change > 0.07, drop CTXS
# FFIV has earning date, drop
# XYL has earning date, drop
# IAC has earning date, drop
# JNPR has earning date, drop
# NEM has earning date, drop
# AME has earning date, drop
# ATO has earning date, drop
# ...
# close 289.81
# change > 0.07, drop WCG
# 2019-03-18 23:10:30.238783
# 2018-08-21
# TJX has earning date, drop
# 2019-03-18 23:10:31.369793
# 2018-08-22
# MDT has earning date, drop
# TGT has earning date, drop
# TJX has earning date, drop
# KSS has earning date, drop
# 2019-03-18 23:10:32.802772
# 2018-08-23
# prior 10 days open 10.68055
# close 9.512514
# change > 0.07, drop VIV
# MDT has earning date, drop
# JKHY has earning date, drop
# TGT has earning date, drop
# TJX has earning date, drop
# SNPS has earning date, drop
# 2019-03-18 23:10:34.703268
# 2018-08-24
# prior 10 days open 40.47749
# close 37.49922
# change > 0.07, drop BBL
# JKHY has earning date, drop
# TGT has earning date, drop
# SNPS has earning date, drop
# VEEV has earning date, drop
# ADSK has earning date, drop
# ROST has earning date, drop
# 2019-03-18 23:10:36.761164
# 2018-08-27
# prior 10 days open 81.8
# close 88.99
# change > 0.07, drop VEEV
# prior 10 days open 139.6393
# close 154.0536
# change > 0.07, drop JKHY
# SPLK has earning date, drop
# SNPS has earning date, drop
# ROST has earning date, drop
# ADSK has earning date, drop
# 2019-03-18 23:10:38.430653
# 2018-08-28
# ADSK has earning date, drop
# prior 10 days open 92.77
# close 100.69
# change > 0.07, drop SNPS
# prior 10 days open 82.57
# close 89.52
# prior 10 days open 19.09
# change > 0.07, drop VEEV
# prior 10 days open 6.665571000000001
# close 5.772247
# close 22.29
# change > 0.07, drop AMD
# change > 0.07, drop BBDO
# HEI has earning date, drop
# SPLK has earning date, drop
# 2019-03-18 23:10:40.462088
# 2018-08-29
# prior 10 days open 19.16
# close 23.98
# change > 0.07, drop AMD
# BMO has earning date, drop
# HEI has earning date, drop
# 2019-03-18 23:10:42.364445
# 2018-08-30
# BMO has earning date, drop
# HEI has earning date, drop
# 2019-03-18 23:10:44.388744
# 2018-08-31
# PVH has earning date, drop
# BMO has earning date, drop
# 2019-03-18 23:10:46.004208
# 2018-09-04
# 2019-03-18 23:10:47.265957
# 2018-09-05
# prior 10 days open 139.45
# close 153.81
# change > 0.07, drop WDAY
# 2019-03-18 23:10:48.553669
# 2018-09-06
# prior 10 days open 142.7
# close 154.54
# change > 0.07, drop WDAY
# 2019-03-18 23:10:50.346984
# 2018-09-07
# prior 10 days open 65.83788
# close 61.0636
# change > 0.07, drop FNV
# prior 10 days open 144
# close 156.69
# change > 0.07, drop WDAY
# 2019-03-18 23:10:52.052062
# 2018-09-10
# 2019-03-18 23:10:53.457660
# 2018-09-11
# 2019-03-18 23:10:54.690456
# 2018-09-12
# 2019-03-18 23:10:54.925314
# 2018-09-13
# 2019-03-18 23:10:55.209397
# 2018-09-14
# 2019-03-18 23:10:56.408044
# 2018-09-17
# 2019-03-18 23:10:56.621900
# 2018-09-18
# 2019-03-18 23:10:57.854789
# 2018-09-19
# CPRT has earning date, drop
# 2019-03-18 23:10:59.185046
# 2018-09-20
# CPRT has earning date, drop
# 2019-03-18 23:11:00.721259
# 2018-09-21
# CPRT has earning date, drop
# 2019-03-18 23:11:01.851548
# 2018-09-24
# 2019-03-18 23:11:02.048270
# 2018-09-25
# prior 10 days open 140.43
# close 151.47
# change > 0.07, drop EW
# 2019-03-18 23:11:03.270357
# 2018-09-26
# prior 10 days open 142.02
# close 153.68
# change > 0.07, drop EW
# CTAS has earning date, drop
# 2019-03-18 23:11:04.733444
# 2018-09-27
# prior 10 days open 142.25
# close 165.47
# change > 0.07, drop EW
# prior 10 days open 65.80305
# close 70.81908
# change > 0.07, drop ABT
# CTAS has earning date, drop
# 2019-03-18 23:11:06.295950
# 2018-09-28
# prior 10 days open 66.02115
# close 71.57247
# prior 10 days open 143.84
# change > 0.07, drop ABT
# close 168.35
# change > 0.07, drop EW
# prior 10 days open 60.33554
# close 64.75896
# change > 0.07, drop CUK
# CTAS has earning date, drop
# 2019-03-18 23:11:07.864878
# 2018-10-01
# prior 10 days open 66.64568
# close 72.20691
# change > 0.07, drop ABT
# 2019-03-18 23:11:09.108553
# 2018-10-02
# 2019-03-18 23:11:10.242198
# 2018-10-03
# PAYX has earning date, drop
# 2019-03-18 23:11:11.481224
# 2018-10-04
# prior 10 days open 22.90941
# close 25.13865
# change > 0.07, drop VST
# 2019-03-18 23:11:12.933976
# 2018-10-05
# prior 10 days open 23.227870000000003
# close 25.32774
# change > 0.07, drop VST
# COST has earning date, drop
# 2019-03-18 23:11:15.196608
# 2018-10-08
# prior 10 days open 8.574483
# close 9.980619
# change > 0.07, drop BSBR
# COST has earning date, drop
# 2019-03-18 23:11:16.962375
# 2018-10-09
# prior 10 days open 8.613814999999999
# close 9.990453
# change > 0.07, drop BSBR
# 2019-03-18 23:11:18.839887
# 2018-10-10
# prior 10 days open 55.1926
# close 49.4864
# change > 0.07, drop WRK
# prior 10 days open 8.849811
# close 10.04945
# change > 0.07, drop BSBR
# 2019-03-18 23:11:21.222486
# 2018-10-11
# prior 10 days open 54.5662
# close 48.08677
# change > 0.07, drop WRK
# PPG has earning date, drop
# 2019-03-18 23:11:22.672697
# 2018-10-12
# prior 10 days open 97.46
# close 86.17
# change > 0.07, drop SQ
# PNC has earning date, drop
# 2019-03-18 23:11:23.901971
# 2018-10-15
# HRS has earning date, drop
# PNC has earning date, drop
# LLL has earning date, drop
# 2019-03-18 23:11:25.238172
# 2018-10-16
# prior 10 days open 165.8472
# close 152.8442
# change > 0.07, drop HRS
# prior 10 days open 210.1612
# close 193.5693
# change > 0.07, drop LLL
# 2019-03-18 23:11:26.244910
# 2018-10-17
# prior 10 days open 52.63
# close 48.78
# change > 0.07, drop FMS
# prior 10 days open 168.4835
# close 153.4884
# change > 0.07, drop HRS
# prior 10 days open 467.0855
# close 421.1411
# change > 0.07, drop BLK
# prior 10 days open 212.0158
# close 194.1643
# change > 0.07, drop LLL
# 2019-03-18 23:11:27.877081
# 2018-10-18
# prior 10 days open 465.4412
# close 420.3927
# change > 0.07, drop BLK
# 2019-03-18 23:11:29.013113
# 2018-10-19
# prior 10 days open 87.4
# close 80.61
# change > 0.07, drop PYPL
# prior 10 days open 161.5
# close 141.22
# change > 0.07, drop URI
# GPC has earning date, drop
# ERIC has earning date, drop
# 2019-03-18 23:11:30.561456
# 2018-10-22
# prior 10 days open 165.16
# close 139.04
# change > 0.07, drop URI
# prior 10 days open 32.48881
# close 29.93815
# change > 0.07, drop CRH
# GPC has earning date, drop
# ERIC has earning date, drop
# 2019-03-18 23:11:32.107006
# 2018-10-23
# prior 10 days open 43.47
# close 40.04
# change > 0.07, drop CDNS
# prior 10 days open 32.11458
# close 28.047320000000003
# prior 10 days open 15.14966
# change > 0.07, drop CRH
# close 13.906770000000002
# change > 0.07, drop HBAN
# 2019-03-18 23:11:33.554768
# 2018-10-24
# prior 10 days open 14.973510000000001
# close 13.89698
# change > 0.07, drop HBAN
# prior 10 days open 31.523690000000002
# prior 10 days open 29.641070000000003
# close 27.87006
# close 31.794259999999998
# change > 0.07, drop CRH
# change > 0.07, drop NEM
# WEC has earning date, drop
# CDNS has earning date, drop
# MCD has earning date, drop
# VAR has earning date, drop
# ORLY has earning date, drop
# prior 10 days open 8.964602000000001
# close 10.50253
# change > 0.07, drop GOLD
# prior 10 days open 150.0226
# close 130.4806
# change > 0.07, drop CAT
# 2019-03-18 23:11:35.834629
# 2018-10-25
# prior 10 days open 15.15945
# close 13.3685
# change > 0.07, drop HBAN
# prior 10 days open 150.6742
# close 127.8873
# change > 0.07, drop CAT
# NEM has earning date, drop
# prior 10 days open 31.415370000000003
# close 27.328409999999998
# change > 0.07, drop CRH
# CDNS has earning date, drop
# DTE has earning date, drop
# HSY has earning date, drop
# ORLY has earning date, drop
# XLNX has earning date, drop
# prior 10 days open 8.956633
# close 10.430810000000001
# change > 0.07, drop GOLD
# VZ has earning date, drop
# WEC has earning date, drop
# 2019-03-18 23:11:38.531008
# 2018-10-26
# prior 10 days open 25.26509
# close 23.04524
# change > 0.07, drop EQT
# prior 10 days open 16.76679
# close 15.450429999999999
# change > 0.07, drop ET
# FTS has earning date, drop
# DTE has earning date, drop
# ESS has earning date, drop
# AEP has earning date, drop
# MHK has earning date, drop
# ORLY has earning date, drop
# XLNX has earning date, drop
# HSY has earning date, drop
# WEC has earning date, drop
# EFX has earning date, drop
# 2019-03-18 23:11:41.105563
# 2018-10-29
# prior 10 days open 16.334410000000002
# prior 10 days open 159
# close 14.7394
# close 147.51
# change > 0.07, drop ET
# change > 0.07, drop MHK
# prior 10 days open 24.59208
# close 21.95974
# change > 0.07, drop EQT
# ESS has earning date, drop
# EFX has earning date, drop
# FTS has earning date, drop
# AMZN has earning date, drop
# 2019-03-18 23:11:43.577155
# 2018-10-30
# prior 10 days open 25.053420000000003
# close 19.18085
# change > 0.07, drop EQT
# prior 10 days open 16.31519
# close 15.0757
# change > 0.07, drop ET
# FTS has earning date, drop
# ESS has earning date, drop
# MHK has earning date, drop
# AMZN has earning date, drop
# CMS has earning date, drop
# 2019-03-18 23:11:45.244147
# 2018-10-31
# prior 10 days open 16.37285
# close 14.85471
# change > 0.07, drop ET
# AMT has earning date, drop
# L has earning date, drop
# CMS has earning date, drop
# 2019-03-18 23:11:46.673884
# 2018-11-01
# prior 10 days open 16.45932
# close 14.25898
# change > 0.07, drop ET
# CDW has earning date, drop
# AMT has earning date, drop
# YUM has earning date, drop
# SBAC has earning date, drop
# CHD has earning date, drop
# 2019-03-18 23:11:48.210943
# 2018-11-02
# prior 10 days open 16.34402
# close 14.412720000000002
# change > 0.07, drop ET
# prior 10 days open 11.39
# close 10.43
# change > 0.07, drop CHU
# prior 10 days open 11.1841
# close 9.990066
# change > 0.07, drop ECA
# CHD has earning date, drop
# AAPL has earning date, drop
# AON has earning date, drop
# CDW has earning date, drop
# 2019-03-18 23:11:49.863999
# 2018-11-05
# prior 10 days open 11.02489
# close 10.18907
# prior 10 days open 16.27676
# close 14.93157
# change > 0.07, drop ECA
# change > 0.07, drop ET
# ZTS has earning date, drop
# AAPL has earning date, drop
# CHD has earning date, drop
# 2019-03-18 23:11:51.936396
# 2018-11-06
# prior 10 days open 59.99728
# close 64.42681
# change > 0.07, drop CHD
# ET has earning date, drop
# RL has earning date, drop
# AAPL has earning date, drop
# 2019-03-18 23:11:53.398306
# 2018-11-07
# prior 10 days open 16.3248
# prior 10 days open 123.508
# close 133.2082
# close 15.046879999999998
# change > 0.07, drop RL
# change > 0.07, drop ET
# BRK.B has earning date, drop
# 2019-03-18 23:11:54.742514
# 2018-11-08
# prior 10 days open 125.0286
# close 135.9612
# change > 0.07, drop RL
# ET has earning date, drop
# MOS has earning date, drop
# MYL has earning date, drop
# ANGI has earning date, drop
# 2019-03-18 23:11:56.192959
# 2018-11-09
# ET has earning date, drop
# prior 10 days open 69.13
# close 64.25
# change > 0.07, drop ATVI
# prior 10 days open 271.72
# close 291.79
# change > 0.07, drop ULTA
# IAC has earning date, drop
# HII has earning date, drop
# ANGI has earning date, drop
# TTWO has earning date, drop
# AZN has earning date, drop
# QCOM has earning date, drop
# 2019-03-18 23:11:57.956969
# 2018-11-12
# ANGI has earning date, drop
# prior 10 days open 116.83
# close 125.81
# change > 0.07, drop TTWO
# prior 10 days open 267.73
# close 290.51
# prior 10 days open 35.78317
# change > 0.07, drop ULTA
# close 38.37133
# change > 0.07, drop NRG
# AZN has earning date, drop
# ATVI has earning date, drop
# PCG has earning date, drop
# 2019-03-18 23:11:59.635446
# 2018-11-13
# ANGI has earning date, drop
# prior 10 days open 68.77955
# close 73.64405
# change > 0.07, drop RSG
# prior 10 days open 73.5023
# prior 10 days open 268.02
# close 80.8416
# change > 0.07, drop CINF
# close 304.49
# change > 0.07, drop ULTA
# prior 10 days open 36.40343
# close 39.75817
# change > 0.07, drop AZN
# NRG has earning date, drop
# 2019-03-18 23:12:02.210174
# 2018-11-14
# prior 10 days open 45.44793
# close 40.92863
# change > 0.07, drop BTI
# prior 10 days open 17.66657
# prior 10 days open 46.5
# close 19.501910000000002
# close 39.92
# change > 0.07, drop EQT
# prior 10 days open 67.62483
# change > 0.07, drop PCG
# close 60.34398
# change > 0.07, drop EIX
# AZN has earning date, drop
# ANGI has earning date, drop
# prior 10 days open 115.1311
# close 123.2124
# change > 0.07, drop BXP
# 2019-03-18 23:12:04.379457
# 2018-11-15
# prior 10 days open 16.78189
# close 18.817439999999998
# change > 0.07, drop EQT
# prior 10 days open 47.09
# close 32.98
# change > 0.07, drop PCG
# prior 10 days open 68.80203
# close 52.983990000000006
# change > 0.07, drop EIX
# HD has earning date, drop
# AAP has earning date, drop
# 2019-03-18 23:12:07.184314
# 2018-11-16
# prior 10 days open 46.77
# close 32.72
# change > 0.07, drop PCG
# prior 10 days open 67.51601
# close 54.9427
# change > 0.07, drop EIX
# NVDA has earning date, drop
# 2019-03-18 23:12:08.848443
# 2018-11-19
# prior 10 days open 46.84
# close 25.59
# change > 0.07, drop PCG
# prior 10 days open 68.60418
# close 53.290659999999995
# change > 0.07, drop EIX
# prior 10 days open 211.8694
# close 196.7901
# change > 0.07, drop NVDA
# 2019-03-18 23:12:10.608002
# 2018-11-20
# prior 10 days open 47.46
# close 17.74
# change > 0.07, drop PCG
# prior 10 days open 217.2884
# close 201.9795
# change > 0.07, drop NVDA
# 2019-03-18 23:12:12.062377
# 2018-11-21
# prior 10 days open 64.06345
# close 68.79456
# change > 0.07, drop EQR
# prior 10 days open 61.502669999999995
# close 66.0442
# change > 0.07, drop ES
# prior 10 days open 86.72408
# close 92.80739
# change > 0.07, drop AWK
# TGT has earning date, drop
# 2019-03-18 23:12:13.636123
# 2018-11-23
# prior 10 days open 18.72
# close 16.84
# change > 0.07, drop ANGI
# prior 10 days open 83.99253
# close 76.47213
# change > 0.07, drop TGT
# prior 10 days open 62.03465
# close 66.37914
# change > 0.07, drop ES
# 2019-03-18 23:12:15.199265
# 2018-11-26
# 2019-03-18 23:12:16.427831
# 2018-11-27
# 2019-03-18 23:12:17.787374
# 2018-11-28
# prior 10 days open 173.31
# close 148.32
# change > 0.07, drop BURL
# 2019-03-18 23:12:19.257082
# 2018-11-29
# prior 10 days open 172.01
# close 149.69
# change > 0.07, drop BURL
# CRM has earning date, drop
# TIF has earning date, drop
# 2019-03-18 23:12:20.914785
# 2018-11-30
# prior 10 days open 173.05
# close 148.56
# change > 0.07, drop BURL
# prior 10 days open 64.43066
# close 69.1889
# change > 0.07, drop A
# WDAY has earning date, drop
# TIF has earning date, drop
# VEEV has earning date, drop
# 2019-03-18 23:12:23.399941
# 2018-12-03
# prior 10 days open 136.21
# close 145.83
# change > 0.07, drop WDAY
# prior 10 days open 64.48054
# close 71.30367
# change > 0.07, drop A
# SPLK has earning date, drop
# 2019-03-18 23:12:25.990227
# 2018-12-04
# prior 10 days open 131.86
# close 145.3
# change > 0.07, drop WDAY
# prior 10 days open 126.1936
# close 137.6566
# change > 0.07, drop UHS
# 2019-03-18 23:12:27.658982
# 2018-12-06
# AZO has earning date, drop
# 2019-03-18 23:12:29.222362
# 2018-12-07
# prior 10 days open 12.25
# close 13.27
# change > 0.07, drop KEP
# AZO has earning date, drop
# 2019-03-18 23:12:30.782393
# 2018-12-10
# prior 10 days open 12.29
# close 13.61
# change > 0.07, drop KEP
# 2019-03-18 23:12:32.331555
# 2018-12-11
# prior 10 days open 12.44
# close 13.59
# change > 0.07, drop KEP
# 2019-03-18 23:12:33.873522
# 2018-12-12
# prior 10 days open 12.29
# close 13.75
# change > 0.07, drop KEP
# 2019-03-18 23:12:35.738865
# 2018-12-13
# prior 10 days open 12.96
# close 14.37
# change > 0.07, drop KEP
# prior 10 days open 73.4
# close 65.87
# change > 0.07, drop XPO
# prior 10 days open 27.44
# close 25.03
# change > 0.07, drop TLK
# 2019-03-18 23:12:37.609111
# 2018-12-14
# prior 10 days open 73.7
# close 66.69
# change > 0.07, drop XPO
# 2019-03-18 23:12:39.457485
# 2018-12-17
# prior 10 days open 5.47
# close 6.04
# change > 0.07, drop NOK
# prior 10 days open 73.52
# close 60.27
# change > 0.07, drop XPO
# prior 10 days open 38.721070000000005
# close 42.17848
# change > 0.07, drop NRG
# 2019-03-18 23:12:41.015628
# 2018-12-18
# prior 10 days open 75.97
# close 44.5
# change > 0.07, drop XPO
# 2019-03-18 23:12:42.526771
# 2018-12-19
# prior 10 days open 24.22
# close 22.21
# change > 0.07, drop TS
# prior 10 days open 225.6615
# close 183.4177
# change > 0.07, drop FDX
# prior 10 days open 144.3824
# close 132.1237
# change > 0.07, drop JNJ
# 2019-03-18 23:12:44.075386
# 2018-12-20
# prior 10 days open 26.89803
# close 22.60547
# change > 0.07, drop ALLY
# prior 10 days open 31.94715
# close 28.719759999999997
# change > 0.07, drop CAG
# prior 10 days open 13.38
# close 14.33
# change > 0.07, drop KEP
# prior 10 days open 231.0846
# close 181.5049
# change > 0.07, drop FDX
# prior 10 days open 300.8315
# close 266.1013
# change > 0.07, drop ROP
# 2019-03-18 23:12:45.511438
# 2018-12-21
# prior 10 days open 225.4629
# close 184.3143
# change > 0.07, drop FDX
# prior 10 days open 32.21445
# close 28.27427
# change > 0.07, drop CAG
# 2019-03-18 23:12:46.845463
# 2018-12-24
# prior 10 days open 13.49
# close 14.76
# change > 0.07, drop KEP
# prior 10 days open 31.74915
# close 28.798959999999997
# change > 0.07, drop CAG
# 2019-03-18 23:12:47.879851
# 2018-12-26
# 2019-03-18 23:12:48.096983
# 2018-12-27
# prior 10 days open 76.78
# close 68.39
# change > 0.07, drop IX
# 2019-03-18 23:12:49.332532
# 2018-12-28
# 2019-03-18 23:12:50.776437
# 2018-12-31
# prior 10 days open 25.016579999999998
# close 21.06919
# change > 0.07, drop WY

# %%
url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'

# %%
mytest = pd.read_csv(url.format('AAPL', '2018-03-20', '2018-03-20'))

# %%
#back test for 1-business day strategy
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['large']:
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = daterange1[daterange1.index(date) + 1]
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            portfolio = list(portfolio['Symbol'])
            invest = 0
            revenue = 0
            for item in portfolio:
                flag = True
                while flag:
                    try:
                        price = pd.read_csv(url.format(item, trading_day, trading_day))
                        flag = False
                    except ConnectionResetError:
                        print('API problem')
                        continue
                invest += price.loc[0, 'open']
                revenue += price.loc[0, 'close']
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            result = pd.DataFrame([], columns = ['Date', 'invest', 'hold(days)', 'portfolio_value', 'p&l', 'pct_change(%)', 'window'])
            if invest != 0:
                result.loc[0, ['Date', 'invest', 'hold(days)', 'portfolio_value',\
                           'p&l', 'pct_change(%)', 'window']] = [trading_day, invest, 1, revenue, revenue-invest, (revenue/invest - 1)*100, win]
            if not os.path.exists(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_1_day/'.format(date, cap, win))):
                os.makedirs(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_1_day/'.format(date, cap, win)))
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_1_day/{}_{}_cap_window_{}_hold_1_pl.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#Generate trading detail for 1-business day
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['large']:
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = daterange1[daterange1.index(date) + 1]
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            portfolio = list(portfolio['Symbol'])
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            result = pd.DataFrame([], columns = ['symbol', 'win_start', 'win_end', 'actual_pageview', 'average_pageview', \
                                                 'std_100days_rolling', 'actual_pageview_in_std', 'buy_date', 'sell_date', \
                                                 'buy_price', 'sell_price', 'p&l', 'pct_change(%)', 'window'])
            count = 0
            window_days = []
            while count < win:
                window_days.append(daterange1[daterange1.index(date) - count])
                count += 1
            window_days = window_days[::-1]
            win_start = window_days[0]
            win_end = window_days[-1]
            result['symbol'] = portfolio
            result['win_start'] = str(win_start)[:10]
            result['win_end'] = str(win_end)[:10]
            result['buy_date'] = trading_day
            result['sell_date'] = trading_day
            for i, item in enumerate(portfolio):
                try:
                    price = pd.read_csv(url.format(item, trading_day, trading_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'buy_price']= 'No Trading'
                    continue
                pageview_price = pd.read_csv('pageview_price/pageview_price_{}.csv'.format(item))
                temp = pageview_price['PageView']
                pageview_price['std_100days_rolling'] = (temp.rolling(100).std()).shift(win)
                pageview_price['mean_100days_rolling'] = (temp.rolling(100).mean()).shift(win)
                total_pageview = 0
                for each in window_days:
                    total_pageview += int(pageview_price.loc[pageview_price['Date'] == str(each)[:10]]['PageView'])
                result.loc[i, 'actual_pageview'] = total_pageview
                result.loc[i, 'average_pageview'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['mean_100days_rolling'])*win
                result.loc[i, 'std_100days_rolling'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['std_100days_rolling'])
                result.loc[i, 'actual_pageview_in_std'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['PageView_Change_in_Std_{}'.format(win)])
                result.loc[i, 'buy_price'] = price.loc[0, 'open']
                result.loc[i, 'sell_price'] = price.loc[0, 'close']
                result.loc[i, 'p&l'] = price.loc[0, 'close'] - price.loc[0, 'open']
                result.loc[i, 'pct_change(%)'] = (price.loc[0, 'close']/price.loc[0, 'open'] - 1)*100
                result.loc[i, 'window'] = win
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_1_day/{}_{}_cap_window_{}_hold_1_detail.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#to summary the 1-business day strategy results
for win in [1, 3]:
    for cap in ['large']:
        to_combine = pd.DataFrame([])
        for date in daterange2:
            trading_day = daterange1[daterange1.index(date) + 1]
            each = trading_day
            each = each[5:]
            each = each.replace('-', '')
            try:
                temp = pd.read_csv('leaderlist {}/{}_cap/window_{}_day/hold_1_day/{}_{}_cap_window_{}_hold_1_pl.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                continue
            to_combine = pd.concat([to_combine, temp], sort = False, ignore_index = True)
        to_combine.loc['total_p&l', 'p&l'] = sum(to_combine.loc[to_combine['window'] == win]['p&l'])
        to_combine.loc['average_pct_change', 'pct_change(%)'] = to_combine['pct_change(%)'].mean()
        to_combine.loc['total_p&l', 'Date'] = 'Total_P&L'
        to_combine.loc['average_pct_change', 'Date'] = 'Average_Pct_Change'
        if not os.path.exists(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win))):
            os.makedirs(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win)))
        to_combine.to_csv('{}_cap/window_{}_day/{}_cap_window_{}_hold_1_pl_summary.csv'.format(cap, win, cap, win), index = False)

# %%
daterange1[87]
# Out:
# '2018-03-29'

# %%
#back test for 3-business day strategy
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['large']:
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = daterange1[daterange1.index(date) + 1]
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            portfolio = list(portfolio['Symbol'])
            invest = 0
            revenue = 0
            for item in portfolio:
                buy_price = pd.read_csv(url.format(item, trading_day, trading_day))
                invest += buy_price.loc[0, 'open']
                sell_day = datetime.datetime.strptime(daterange1[daterange1.index(trading_day) + 2], "%Y-%m-%d")
                flag = True
                while flag:
                    try:
                        sell_price = pd.read_csv(url.format(item, sell_day, sell_day))
                        flag = False
                    except ConnectionResetError:
                        print('API problem')
                        continue
                revenue += sell_price.loc[0, 'close']
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            result = pd.DataFrame([], columns = ['Date', 'invest', 'hold(days)', 'portfolio_value', 'p&l', 'pct_change(%)', 'window'])
            if invest != 0:
                result.loc[0, ['Date', 'invest', 'hold(days)', 'portfolio_value',\
                           'p&l', 'pct_change(%)', 'window']] = [trading_day, invest, 3, revenue, revenue-invest, (revenue/invest - 1)*100, win]
            if not os.path.exists(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_3_day/'.format(date, cap, win))):
                os.makedirs(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_3_day/'.format(date, cap, win)))
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_3_day/{}_{}_cap_window_{}_hold_3_pl.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
mytest = pd.read_csv(url.format('JW.B', '2018-06-08', '2018-06-12'))

# %%
#Generate trading detail for 3-business day
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['large']:
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = daterange1[daterange1.index(date) + 1]
            portfolio = list(portfolio['Symbol'])
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            sell_day = datetime.datetime.strptime(daterange1[daterange1.index(trading_day) + 2], "%Y-%m-%d")
            result = pd.DataFrame([], columns = ['symbol', 'win_start', 'win_end', 'actual_pageview', 'average_pageview', \
                                                 'std_100days_rolling', 'actual_pageview_in_std', 'buy_date', 'sell_date', \
                                                 'buy_price', 'sell_price', 'p&l', 'pct_change(%)', 'window'])
            count = 0
            window_days = []
            while count < win:
                window_days.append(daterange1[daterange1.index(date) - count])
                count += 1
            window_days = window_days[::-1]
            win_start = window_days[0]
            win_end = window_days[-1]
            result['symbol'] = portfolio
            result['win_start'] = str(win_start)[:10]
            result['win_end'] = str(win_end)[:10]
            result['buy_date'] = trading_day
            result['sell_date'] = sell_day
            for i, item in enumerate(portfolio):
                try:
                    buy = pd.read_csv(url.format(item, trading_day, trading_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'buy_price'] = 'No Trading'
                    continue
                try:
                    sell = pd.read_csv(url.format(item, sell_day, sell_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'sell_price'] = 'No Trading'
                    continue
                pageview_price = pd.read_csv('pageview_price/pageview_price_{}.csv'.format(item))
                temp = pageview_price['PageView']
                pageview_price['std_100days_rolling'] = (temp.rolling(100).std()).shift(win)
                pageview_price['mean_100days_rolling'] = (temp.rolling(100).mean()).shift(win)
                total_pageview = 0
                for each in window_days:
                    total_pageview += int(pageview_price.loc[pageview_price['Date'] == str(each)[:10]]['PageView'])
                result.loc[i, 'actual_pageview'] = total_pageview
                result.loc[i, 'average_pageview'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['mean_100days_rolling'])*win
                result.loc[i, 'std_100days_rolling'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['std_100days_rolling'])
                result.loc[i, 'actual_pageview_in_std'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['PageView_Change_in_Std_{}'.format(win)])
                result.loc[i, 'buy_price'] = buy.loc[0, 'open']
                result.loc[i, 'sell_price'] = sell.loc[0, 'close']
                result.loc[i, 'p&l'] = sell.loc[0, 'close'] - buy.loc[0, 'open']
                result.loc[i, 'pct_change(%)'] = (sell.loc[0, 'close']/buy.loc[0, 'open'] - 1)*100
                result.loc[i, 'window'] = win
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_3_day/{}_{}_cap_window_{}_hold_3_detail.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#to summary the 3-business day strategy results
for win in [1, 3]:
    for cap in ['large']:
        to_combine = pd.DataFrame([])
        for date in daterange2:
            trading_day = daterange1[daterange1.index(date) + 1]
            each = trading_day
            each = each[5:]
            each = each.replace('-', '')
            try:
                temp = pd.read_csv('leaderlist {}/{}_cap/window_{}_day/hold_3_day/{}_{}_cap_window_{}_hold_3_pl.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                continue
            to_combine = pd.concat([to_combine, temp], sort = False, ignore_index = True)   
        to_combine.loc['total_p&l', 'p&l'] = sum(to_combine.loc[to_combine['window'] == win]['p&l'])
        to_combine.loc['average_pct_change', 'pct_change(%)'] = to_combine['pct_change(%)'].mean()
        to_combine.loc['total_p&l', 'Date'] = 'Total_P&L'
        to_combine.loc['average_pct_change', 'Date'] = 'Average_Pct_Change'
        if not os.path.exists(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win))):
            os.makedirs(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win)))
        to_combine.to_csv('{}_cap/window_{}_day/{}_cap_window_{}_hold_3_pl_summary.csv'.format(cap, win, cap, win), index = False)

# %%
#back test for buy close, hold one day, and sell close price tomorrow
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['large']:
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = date
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            portfolio = list(portfolio['Symbol'])
            invest = 0
            portfolio_value = 0
            for item in portfolio:
                buy_price = pd.read_csv(url.format(item, trading_day, trading_day))
                invest += buy_price.loc[0, 'close']
                sell_day = daterange1[daterange1.index(trading_day) + 1]
                flag = True
                while flag:
                    try:
                        sell_price = pd.read_csv(url.format(item, sell_day, sell_day))
                        flag = False
                    except ConnectionResetError:
                        print('API Problem')
                        continue
                portfolio_value += sell_price.loc[0, 'close']
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            result = pd.DataFrame([], columns = ['Date', 'invest', 'hold(days)', 'portfolio_value', 'p&l', 'pct_change(%)', 'window'])
            if invest != 0:
                result.loc[0, ['Date', 'invest', 'hold(days)', 'portfolio_value',\
                           'p&l', 'pct_change(%)', 'window']] = [trading_day, invest, 1, portfolio_value, portfolio_value-invest, (portfolio_value/invest - 1)*100, win]
            if not os.path.exists(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/'.format(date, cap, win))):
                os.makedirs(os.path.dirname('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/'.format(date, cap, win)))
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/{}_{}_cap_window_{}_hold_1b_pl.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#Generate trading detail for today close to next day close
for win in [1, 3]:
    for date in daterange2:
        print(date)
        for cap in ['large']:
            each = date
            each = each[5:]
            each = each.replace('-', '')
            try:
                portfolio = pd.read_csv\
            ('leaderlist {}/{}_cap/window_{}_day/{}_{}_cap_window_{}_symbols.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                break
            url = 'https://ondemand.websol.barchart.com/getHistory.csv?apikey=onDemand&symbol={}&startDate={}&endDate={}&type=daily&splits=true&nearby=1&jerq=true&exchange=NYSE%2CAMEX%2CNASDAQ'
            trading_day = date
            portfolio = list(portfolio['Symbol'])
            trading_each = trading_day
            trading_each = trading_each[5:]
            trading_each = trading_each.replace('-', '')
            sell_day = daterange1[daterange1.index(trading_day) + 1]
            result = pd.DataFrame([], columns = ['symbol', 'win_start', 'win_end', 'actual_pageview', 'average_pageview', \
                                                 'std_100days_rolling', 'actual_pageview_in_std', 'buy_date', 'sell_date', \
                                                 'buy_price', 'sell_price', 'p&l', 'pct_change(%)', 'window'])
            temp_win_date = datetime.datetime.strptime(date, "%Y-%m-%d")
            window_days = []
            count = 0
            while count < win:
                window_days.append(daterange1[daterange1.index(date) - count])
                count += 1
            window_days = window_days[::-1]
            win_start = window_days[0]
            win_end = window_days[-1]
            result['symbol'] = portfolio
            result['win_start'] = str(win_start)[:10]
            result['win_end'] = str(win_end)[:10]
            result['buy_date'] = trading_day
            result['sell_date'] = sell_day
            for i, item in enumerate(portfolio):
                try:
                    buy = pd.read_csv(url.format(item, trading_day, trading_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'buy_price'] == 'No Trading'
                    continue
                try:
                    sell = pd.read_csv(url.format(item, sell_day, sell_day))
                except EmptyDataError:
                    result.loc[result['symbol'] == item, 'sell_price'] == 'No Trading'
                    continue
                price = pd.read_csv(url.format(item, trading_day, sell_day))
                pageview_price = pd.read_csv('pageview_price/pageview_price_{}.csv'.format(item))
                temp = pageview_price['PageView']
                pageview_price['std_100days_rolling'] = (temp.rolling(100).std()).shift(win)
                pageview_price['mean_100days_rolling'] = (temp.rolling(100).mean()).shift(win)
                total_pageview = 0
                for each in window_days:
                    total_pageview += int(pageview_price.loc[pageview_price['Date'] == str(each)[:10]]['PageView'])
                result.loc[i, 'actual_pageview'] = total_pageview
                result.loc[i, 'average_pageview'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['mean_100days_rolling'])*win
                result.loc[i, 'std_100days_rolling'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['std_100days_rolling'])
                result.loc[i, 'actual_pageview_in_std'] = float(pageview_price.loc[pageview_price['Date'] == str(win_end)[:10]]['PageView_Change_in_Std_{}'.format(win)])
                result.loc[i, 'buy_price'] = price.loc[0, 'close']
                result.loc[i, 'sell_price'] = price.loc[1, 'close']
                result.loc[i, 'p&l'] = price.loc[1, 'close'] - price.loc[0, 'close']
                result.loc[i, 'pct_change(%)'] = (price.loc[1, 'close']/price.loc[0, 'close'] - 1)*100
                result.loc[i, 'window'] = win
            result.to_csv('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/{}_{}_cap_window_{}_hold_1b_detail.csv'.format(date, cap, win, trading_each, cap, win), index = False)
# Out:
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-19
# 2018-03-20
# 2018-03-21
# 2018-03-22
# 2018-03-23
# 2018-03-26
# 2018-03-27
# 2018-03-28
# 2018-03-29
# 2018-04-02
# 2018-04-03
# 2018-04-04
# 2018-04-05
# 2018-04-06
# 2018-04-09
# 2018-04-10
# 2018-04-11
# 2018-04-12
# 2018-04-13
# 2018-04-16
# 2018-04-17
# 2018-04-18
# 2018-04-19
# 2018-04-20
# 2018-04-23
# 2018-04-24
# 2018-04-25
# 2018-04-26
# 2018-04-27
# 2018-04-30
# 2018-05-01
# 2018-05-02
# 2018-05-03
# 2018-05-04
# 2018-05-07
# 2018-05-08
# 2018-05-09
# 2018-05-10
# 2018-05-11
# 2018-05-14
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-21
# 2018-05-22
# 2018-05-23
# 2018-05-24
# 2018-05-25
# 2018-05-29
# 2018-05-30
# 2018-05-31
# 2018-06-01
# 2018-06-04
# 2018-06-05
# 2018-06-06
# 2018-06-07
# 2018-06-08
# 2018-06-11
# 2018-06-12
# 2018-06-13
# 2018-06-14
# 2018-06-15
# 2018-06-18
# 2018-06-19
# 2018-06-20
# 2018-06-21
# 2018-06-22
# 2018-06-25
# 2018-06-26
# 2018-06-27
# 2018-06-28
# 2018-06-29
# 2018-07-02
# 2018-07-03
# 2018-07-05
# 2018-07-06
# 2018-07-09
# 2018-07-10
# 2018-07-11
# 2018-07-12
# 2018-07-13
# 2018-07-16
# 2018-07-17
# 2018-07-18
# 2018-07-19
# 2018-07-20
# 2018-07-23
# 2018-07-24
# 2018-07-25
# 2018-07-26
# 2018-07-27
# 2018-07-30
# 2018-07-31
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-10
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-27
# 2018-08-28
# 2018-08-29
# 2018-08-30
# 2018-08-31
# 2018-09-04
# 2018-09-05
# 2018-09-06
# 2018-09-07
# 2018-09-10
# 2018-09-11
# 2018-09-12
# 2018-09-13
# 2018-09-14
# 2018-09-17
# 2018-09-18
# 2018-09-19
# 2018-09-20
# 2018-09-21
# 2018-09-24
# 2018-09-25
# 2018-09-26
# 2018-09-27
# 2018-09-28
# 2018-10-01
# 2018-10-02
# 2018-10-03
# 2018-10-04
# 2018-10-05
# 2018-10-08
# 2018-10-09
# 2018-10-10
# 2018-10-11
# 2018-10-12
# 2018-10-15
# 2018-10-16
# 2018-10-17
# 2018-10-18
# 2018-10-19
# 2018-10-22
# 2018-10-23
# 2018-10-24
# 2018-10-25
# 2018-10-26
# 2018-10-29
# 2018-10-30
# 2018-10-31
# 2018-11-01
# 2018-11-02
# 2018-11-05
# 2018-11-06
# 2018-11-07
# 2018-11-08
# 2018-11-09
# 2018-11-12
# 2018-11-13
# 2018-11-14
# 2018-11-15
# 2018-11-16
# 2018-11-19
# 2018-11-20
# 2018-11-21
# 2018-11-23
# 2018-11-26
# 2018-11-27
# 2018-11-28
# 2018-11-29
# 2018-11-30
# 2018-12-03
# 2018-12-04
# 2018-12-06
# 2018-12-07
# 2018-12-10
# 2018-12-11
# 2018-12-12
# 2018-12-13
# 2018-12-14
# 2018-12-17
# 2018-12-18
# 2018-12-19
# 2018-12-20
# 2018-12-21
# 2018-12-24
# 2018-12-26
# 2018-12-27
# 2018-12-28
# 2018-12-31

# %%
#to summary the today's close to next close strategy results
for win in [1, 3]:
    for cap in ['large']:
        to_combine = pd.DataFrame([])
        for date in daterange2:
            trading_day = date
            each = trading_day
            each = each[5:]
            each = each.replace('-', '')
            try:
                temp = pd.read_csv('leaderlist {}/{}_cap/window_{}_day/hold_1b_day/{}_{}_cap_window_{}_hold_1b_pl.csv'.format(date, cap, win, each, cap, win))
            except FileNotFoundError:
                continue
            to_combine = pd.concat([to_combine, temp], sort = False, ignore_index = True)   
        to_combine.loc['total_p&l', 'p&l'] = sum(to_combine.loc[to_combine['window'] == win]['p&l'])
        to_combine.loc['average_pct_change', 'pct_change(%)'] = to_combine['pct_change(%)'].mean()
        to_combine.loc['total_p&l', 'Date'] = 'Total_P&L'
        to_combine.loc['average_pct_change', 'Date'] = 'Average_Pct_Change'
        if not os.path.exists(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win))):
            os.makedirs(os.path.dirname('{}_cap/window_{}_day/'.format(cap, win)))
        to_combine.to_csv('{}_cap/window_{}_day/{}_cap_window_{}_hold_1b_pl_summary.csv'.format(cap, win, cap, win), index = False)
